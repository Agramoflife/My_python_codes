# %%
# just to clear the fog we are talking about the indexing here

# %%
pwd
# Out:
# 'C:\\Users\\Deepu\\Documents\\My_Python_codes'

# %%
cd C:\Users\Deepu\Downloads
# Out:
# C:\Users\Deepu\Downloads

# %%
pwd
# Out:
# 'C:\\Users\\Deepu\\Downloads'

# %%
import numpy as np 
import pandas as pd
df = pd.read_csv('imdb_data.csv')
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
# lets clear the indexing and slicing part

# %%
df.iloc[:10,1:4] # follows simple sliciing
# Out:
#                                belongs_to_collection    budget  \
# 0  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2                                                NaN   3300000
# 3                                                NaN   1200000
# 4                                                NaN         0
# 5                                                NaN   8000000
# 6                                                NaN  14000000
# 7                                                NaN         0
# 8  [{'id': 256377, 'name': 'The Muppet Collection...         0
# 9                                                NaN   6000000
#
#                                               genres
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# ...

# %%
df.iloc[2,2] # single indexing this is not of a much use
# Out:
# 3300000

# %%
# Now lets use the df.loc[] which is used for label indexing 
df.loc[10:16,['original_title','popularity']] # mind the square brackets in the column
# Out:
#                                 original_title  popularity
# 10                                       Rocky   14.774066
# 11  Revenge of the Nerds II: Nerds in Paradise   10.543750
# 12                             American Beauty   20.726578
# 13                                     Be Cool   13.314233
# 14                             Minority Report   20.666063
# 15                                     Šišanje    1.018477
# 16                                     Red Eye    6.336927

# %%
df.loc[:,['original_title','popularity']] # gives you all the rows
# Out:
#                                 original_title  popularity
# 0                       Hot Tub Time Machine 2    6.575393
# 1     The Princess Diaries 2: Royal Engagement    8.248895
# 2                                     Whiplash   64.299990
# 3                                      Kahaani    3.174936
# 4                                         마린보이    1.148070
# ...                                        ...         ...
# 2995                                   Chasers    9.853270
# 2996                               Vi är bäst!    3.727996
# 2997                   The Long Kiss Goodnight   14.482345
# 2998                          Along Came Polly   15.725542
# 2999                                 Abduction   10.512109
#
# [3000 rows x 2 columns]

# %%
df.loc[2,['original_title']] # has the feature to extract single element from data frame
# Out:
# original_title    Whiplash
# Name: 2, dtype: object

# %% [markdown]
# # This is where the weird part starts, up untill now we were using iloc for integral slicing and indexing and loc for verbal slicing
#
# # but the table turns here and indexing begins to restore its form like it has it list indexing and slicing

# %%
#lets try the usual ways with which we did indexing in list
df[3] # so this does not work with single elelment
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 3
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df[3,4] # this does not work even by rows and columns it used to work in numpy
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (3, 4)
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df[1:10,1:10] # still does not work 
# we are taking rows and columns in the [] and it does not supports I guess
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:142, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(1, 10, None), slice(1, 10, None))' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 df[1:10,1:10]
#
# ...

# %%
df[1:10] # this works only on rows and in slicing form only
# Out:
#    id                              belongs_to_collection    budget  \
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
# 5   6                                                NaN   8000000
# 6   7                                                NaN  14000000
# 7   8                                                NaN         0
# 8   9  [{'id': 256377, 'name': 'The Muppet Collection...         0
# 9  10                                                NaN   6000000
#
#                                               genres  \
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# ...

# %%
df[:] # gives you all the columns. edit but if you comprehend it is actually showing all rows
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
df['original_title'] # oh it also works for column and it works indvidually
# Out:
# 0                         Hot Tub Time Machine 2
# 1       The Princess Diaries 2: Royal Engagement
# 2                                       Whiplash
# 3                                        Kahaani
# 4                                           마린보이
#                           ...
# 2995                                     Chasers
# 2996                                 Vi är bäst!
# 2997                     The Long Kiss Goodnight
# 2998                            Along Came Polly
# 2999                                   Abduction
# Name: original_title, Length: 3000, dtype: object

# %%
df['original_title','popularity']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('original_title', 'popularity')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df[['original_title','popularity']] # so to take 2 columns it takes double square brackets
# Out:
#                                 original_title  popularity
# 0                       Hot Tub Time Machine 2    6.575393
# 1     The Princess Diaries 2: Royal Engagement    8.248895
# 2                                     Whiplash   64.299990
# 3                                      Kahaani    3.174936
# 4                                         마린보이    1.148070
# ...                                        ...         ...
# 2995                                   Chasers    9.853270
# 2996                               Vi är bäst!    3.727996
# 2997                   The Long Kiss Goodnight   14.482345
# 2998                          Along Came Polly   15.725542
# 2999                                 Abduction   10.512109
#
# [3000 rows x 2 columns]

# %%
df[['original_title','popularity','budget']] # multiple column slicing in double square brackets
# Out:
#                                 original_title  popularity    budget
# 0                       Hot Tub Time Machine 2    6.575393  14000000
# 1     The Princess Diaries 2: Royal Engagement    8.248895  40000000
# 2                                     Whiplash   64.299990   3300000
# 3                                      Kahaani    3.174936   1200000
# 4                                         마린보이    1.148070         0
# ...                                        ...         ...       ...
# 2995                                   Chasers    9.853270         0
# 2996                               Vi är bäst!    3.727996         0
# 2997                   The Long Kiss Goodnight   14.482345  65000000
# 2998                          Along Came Polly   15.725542  42000000
# 2999                                 Abduction   10.512109  35000000
#
# [3000 rows x 3 columns]

# %% [markdown]
# **So lets just summarize what just happened here**
#
# **iloc method helps us to slice usign the numbers. The numbers correspond to rows and columns. we also get to pick the single element from the data frame using the row and column number of the elements just like we have in matrix**
#
#
# **loc method has also the same funcitionality but the numbers are replaced by labels we have seen this in our pandas 2 d arrar example.**
#
# **Now comming to the weird part the df [ ] - so this is basically for only slicing rows and column individually that means you can not pass rows and column in the argument at the same time look at the above example to make things more clear , you can not pick and individual element from the data frame remember slcicing and only slicing and that to rows and columns one at a time**

# %% [markdown]
# So if you are using df[ Number : ] you are basically doing operation on rows only
#
# if you are using df[ Name of the column ] or df[[ Name of the columns ]] you are basically doing operaion on columns only

# %% [markdown]
# # Just an update in the slicing part I have just come to know that we can also use boolean array in the df.loc function its was mentioned in the documentation. How did i come to know about it, simple I read the code in the data wrangling colab and saw a weird way of creating a data frame which got me off gaurd and than I interospected

# %%
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
## Traditionally if I have to create a data frame of long english movies this is how i will do it 
complete_df_of_long_english_movies=df[df['runtime'] >= 100]

# %%
long_english_movies_traditional = complete_df_of_long_english_movies.loc[0:,['imdb_id','original_language']]
display(long_english_movies_traditional)
# or you can also use this methods as well
#long_english_movies_traditional = complete_df_of_long_english_movies[['imdb_id','original_language']]
# Out:
#         imdb_id original_language
# 1     tt0368933                en
# 2     tt2582802                en
# 3     tt1821480                hi
# 4     tt1380152                ko
# 8     tt0117110                en
# ...         ...               ...
# 2994  tt0105327                en
# 2995  tt0109403                en
# 2996  tt2364975                sv
# 2997  tt0116908                en
# 2999  tt1600195                en
#
# [1820 rows x 2 columns]

# %% [markdown]
# ## The same output has an oneliner to it, that is by using the boolean array

# %%
long_english_movies = df.loc[df['runtime']>=100,['imdb_id','original_language']] 
display(long_english_movies)
# Out:
#         imdb_id original_language
# 1     tt0368933                en
# 2     tt2582802                en
# 3     tt1821480                hi
# 4     tt1380152                ko
# 8     tt0117110                en
# ...         ...               ...
# 2994  tt0105327                en
# 2995  tt0109403                en
# 2996  tt2364975                sv
# 2997  tt0116908                en
# 2999  tt1600195                en
#
# [1820 rows x 2 columns]
