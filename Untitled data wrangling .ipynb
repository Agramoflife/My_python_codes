# %%
pwd
# Out:
# 'C:\\Users\\Deepu\\Documents\\My_Python_codes'

# %%
cd C:\Users\Deepu\Downloads
# Out:
# C:\Users\Deepu\Downloads

# %%
import numpy as np
import pandas as pd

# %%
np.random.seed()
array2d = np.random.randint(1,10, size  = (4,3))
d1 = pd.DataFrame(array2d, index = ['a','b','c','d'], columns = ['alpha','beta','gamma'])
display(d1)
# Out:
#    alpha  beta  gamma
# a      2     5      2
# b      6     9      2
# c      3     8      1
# d      3     7      8

# %%
np.random.seed()
array2d_ = np.random.randint(1,10, size = (4,3))
d2 = pd.DataFrame(array2d_,index = ['a','b','c','d'], columns = ['alpha','beta','gamma'])
display(d2)
# Out:
#    alpha  beta  gamma
# a      1     2      1
# b      1     9      3
# c      8     8      5
# d      4     5      5

# %%
pd.concat([d1,d2])
# Out:
#    alpha  beta  gamma
# a      2     5      2
# b      6     9      2
# c      3     8      1
# d      3     7      8
# a      1     2      1
# b      1     9      3
# c      8     8      5
# d      4     5      5

# %%
pd.concat([d1,d2],axis = 1)
# Out:
#    alpha  beta  gamma  alpha  beta  gamma
# a      2     5      2      1     2      1
# b      6     9      2      1     9      3
# c      3     8      1      8     8      5
# d      3     7      8      4     5      5

# %%
d1 = pd.DataFrame(np.random.randint(1,30,size = (3,4)),index = ['a','b','c'], columns = ['alpha','beta','gamma','delta'])
d2 = pd.DataFrame(np.random.randint(1,30,size = (4,5)),index = [1,2,3,4],columns = ['a','b','c','d','beta'])
pd.concat([d1,d2],axis = 0)
# Out:
#    alpha  beta  gamma  delta     a     b     c     d
# a   23.0    22   13.0   11.0   NaN   NaN   NaN   NaN
# b   23.0    10    2.0   12.0   NaN   NaN   NaN   NaN
# c   27.0    14   24.0   26.0   NaN   NaN   NaN   NaN
# 1    NaN     5    NaN    NaN   4.0   3.0  27.0  15.0
# 2    NaN     5    NaN    NaN  25.0   4.0   5.0   1.0
# 3    NaN    14    NaN    NaN  21.0  26.0  18.0  20.0
# 4    NaN    16    NaN    NaN  25.0   1.0  23.0   2.0

# %%
pd.concat([d1,d2],axis = 1)
# Out:
#    alpha  beta  gamma  delta     a     b     c     d     e
# a    4.0  22.0    4.0   25.0   NaN   NaN   NaN   NaN   NaN
# b    1.0   7.0    8.0   19.0   NaN   NaN   NaN   NaN   NaN
# c    9.0  21.0    8.0    8.0   NaN   NaN   NaN   NaN   NaN
# 1    NaN   NaN    NaN    NaN  24.0   2.0   6.0  25.0   2.0
# 2    NaN   NaN    NaN    NaN  19.0  19.0  13.0  10.0   4.0
# 3    NaN   NaN    NaN    NaN  29.0  21.0  21.0  14.0  24.0
# 4    NaN   NaN    NaN    NaN  21.0  23.0  29.0  23.0  21.0

# %%
# create a sample DataFrame
df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie', 'Alice', 'Bob', 'Charlie'],
    'Year': [2019, 2019, 2019, 2020, 2020, 2020],
    'Sales': [100, 200, 150, 300, 250, 200]
})

# pivot the DataFrame
pivot_df = df.pivot_table(values='Sales', index='Name', columns='Year')

# print the pivoted DataFrame
print(pivot_df)
# Out:
# Year     2019  2020
# Name
# Alice     100   300
# Bob       200   250
# Charlie   150   200

# %%
d1 = pd.DataFrame(np.random.randint(1,10,size = (4,3)),index = [1,2,3,4],columns = ['alpha','beta','gamma'])
d2 = pd.DataFrame(np.random.randint(1,10,size = (4,3)),index = [1,2,3,4], columns = ['beta','delta','zeta'])

# %%
pd.concat([d1,d2])
# Out:
#    alpha  beta  gamma  delta  zeta
# 1    5.0     2    3.0    NaN   NaN
# 2    2.0     2    1.0    NaN   NaN
# 3    9.0     4    8.0    NaN   NaN
# 4    8.0     9    8.0    NaN   NaN
# 1    NaN     5    NaN    8.0   4.0
# 2    NaN     3    NaN    7.0   6.0
# 3    NaN     4    NaN    9.0   2.0
# 4    NaN     9    NaN    4.0   8.0

# %%
pd.concat([d1,d2],axis = 1)
# Out:
#    alpha  beta  gamma  beta  delta  zeta
# 1      5     2      3     5      8     4
# 2      2     2      1     3      7     6
# 3      9     4      8     4      9     2
# 4      8     9      8     9      4     8

# %% [markdown]
# # if there are common columns then there is a point to concat row-wise or coloumn-wise otherwise its not

# %%
array1 = np.random.randint(1,10,size = (4,3))
df1 = pd.DataFrame(array1,index = [1,2,3,4], columns = ['alpha','beta','gamma'])
array2 = np.random.randint(1,10,size = (4,3))
df2 = pd.DataFrame(array2,index = [1,2,3,4],columns = ['a','alpha','b'])

# %%
pd.concat([df1,df2], axis = 0)
# Out:
#    alpha  beta  gamma    a    b
# 1      6   3.0    4.0  NaN  NaN
# 2      7   5.0    7.0  NaN  NaN
# 3      7   9.0    5.0  NaN  NaN
# 4      9   3.0    5.0  NaN  NaN
# 1      4   NaN    NaN  5.0  7.0
# 2      2   NaN    NaN  1.0  8.0
# 3      3   NaN    NaN  9.0  3.0
# 4      8   NaN    NaN  9.0  5.0

# %%
pd.concat([df1,df2],axis = 1)
# Out:
#    alpha  beta  gamma  a  alpha  b
# 1      6     3      4  5      4  7
# 2      7     5      7  1      2  8
# 3      7     9      5  9      3  3
# 4      9     3      5  9      8  5

# %%
np.random.seed()
array1 = np.random.randint(1,20, size = (3,4))
df1 = pd.DataFrame(array1,index = [1,2,3], columns = ['alpha','beta','gamma','delta'])
df1
# Out:
#    alpha  beta  gamma  delta
# 1     18    11     14     18
# 2     18    12     15      3
# 3     11    12     11      2

# %%
np.random.seed()
array2 = np.random.randint(1,20,size = (3,4))
df2 = pd.DataFrame(array2, index = ['a','b','c'], columns = ['alpha','beta','gamma','delta'])
df2
# Out:
#    alpha  beta  gamma  delta
# a     15    19     12     10
# b     16    19     10      9
# c      1     8     17     16

# %%
pd.concat([df1,df2],axis = 0)
# Out:
#    alpha  beta  gamma  delta
# 1     18    11     14     18
# 2     18    12     15      3
# 3     11    12     11      2
# a     15    19     12     10
# b     16    19     10      9
# c      1     8     17     16

# %%
pd.concat([df1,df2],axis = 1)
# Out:
#    alpha  beta  gamma  delta  alpha  beta  gamma  delta
# 1   18.0  11.0   14.0   18.0    NaN   NaN    NaN    NaN
# 2   18.0  12.0   15.0    3.0    NaN   NaN    NaN    NaN
# 3   11.0  12.0   11.0    2.0    NaN   NaN    NaN    NaN
# a    NaN   NaN    NaN    NaN   15.0  19.0   12.0   10.0
# b    NaN   NaN    NaN    NaN   16.0  19.0   10.0    9.0
# c    NaN   NaN    NaN    NaN    1.0   8.0   17.0   16.0

# %%
np.random.seed(1)
array3 = np.random.randint(1,20, size = (3,4))
df3 = pd.DataFrame(array3,index = [1,2,3], columns = ['alpha','beta','gamma','delta'])
df3
# Out:
#    alpha  beta  gamma  delta
# 1      6    12     13      9
# 2     10    12      6     16
# 3      1    17      2     13

# %%
np.random.seed(1)
array4 = np.random.randint(1,20,size = (3,4))
df4 = pd.DataFrame(array4, index = [1,2,3], columns = ['alpha','beta','gamma','delta'])
df4
# Out:
#    alpha  beta  gamma  delta
# 1      6    12     13      9
# 2     10    12      6     16
# 3      1    17      2     13

# %%
pd.concat([df3,df4],axis = 0)
# Out:
#    alpha  beta  gamma  delta
# 1      6    12     13      9
# 2     10    12      6     16
# 3      1    17      2     13
# 1      6    12     13      9
# 2     10    12      6     16
# 3      1    17      2     13

# %%
pd.concat([df3,df4],axis = 1)
# Out:
#    alpha  beta  gamma  delta  alpha  beta  gamma  delta
# 1      6    12     13      9      6    12     13      9
# 2     10    12      6     16     10    12      6     16
# 3      1    17      2     13      1    17      2     13

# %%
np.random.seed(2)
array5 = np.random.randint(1,20,size = (3,4))
df5=pd.DataFrame(array5, index = [1,2,3], columns =  ['a','b','c','d'])
df5
# Out:
#     a   b   c   d
# 1   9  16  14   9
# 2  12  19  12   9
# 3   8   3  18  12

# %%
np.random.seed(3)
array6 = np.random.randint(1,20,size = (5,6))
df6 = pd.DataFrame(array6, index = [1,2,3,4,5], columns = ['alpha','beta','gamma','delta','epsilon','zeta'])
df6
# Out:
#    alpha  beta  gamma  delta  epsilon  zeta
# 1     11     4      9      1       11    12
# 2     10    11      7      1       13     8
# 3     15    18      3      3        2     6
# 4      9    15      2     11        8    12
# 5      2    16     17      6       18    15

# %%
pd.concat([df5,df6],axis = 0)
# Out:
#       a     b     c     d  alpha  beta  gamma  delta  epsilon  zeta
# 1   9.0  16.0  14.0   9.0    NaN   NaN    NaN    NaN      NaN   NaN
# 2  12.0  19.0  12.0   9.0    NaN   NaN    NaN    NaN      NaN   NaN
# 3   8.0   3.0  18.0  12.0    NaN   NaN    NaN    NaN      NaN   NaN
# 1   NaN   NaN   NaN   NaN   11.0   4.0    9.0    1.0     11.0  12.0
# 2   NaN   NaN   NaN   NaN   10.0  11.0    7.0    1.0     13.0   8.0
# 3   NaN   NaN   NaN   NaN   15.0  18.0    3.0    3.0      2.0   6.0
# 4   NaN   NaN   NaN   NaN    9.0  15.0    2.0   11.0      8.0  12.0
# 5   NaN   NaN   NaN   NaN    2.0  16.0   17.0    6.0     18.0  15.0

# %%
pd.concat([df5,df6],axis = 1)
# Out:
#       a     b     c     d  alpha  beta  gamma  delta  epsilon  zeta
# 1   9.0  16.0  14.0   9.0     11     4      9      1       11    12
# 2  12.0  19.0  12.0   9.0     10    11      7      1       13     8
# 3   8.0   3.0  18.0  12.0     15    18      3      3        2     6
# 4   NaN   NaN   NaN   NaN      9    15      2     11        8    12
# 5   NaN   NaN   NaN   NaN      2    16     17      6       18    15

# %% [markdown]
# Now note that the index were same here hence it overlapped the index,
#
# had it been distinct then it would have not made any sense to choose the axis of concatenation as it would have given us the
# same result

# %%
# inner join 
array7 = np.random.randint(1,10,size = (3,3))
df7 = pd.DataFrame(array7, index = [1,2,3], columns = ['alpha','beta','gamma'])
df7
# Out:
#    alpha  beta  gamma
# 1      5     4      1
# 2      1     1      1
# 3      3     3      8

# %%
array8 = np.random.randint(1,10,size = (3,3))
df8 = pd.DataFrame(array8 ,index = [1,2,3], columns = ['a','b','gamma'])
df8
# Out:
#    a  b  gamma
# 1  9  8      1
# 2  1  2      8
# 3  9  8      5

# %%
pd.merge(df7,df8,how = 'inner',left_on = 'gamma',right_on = 'gamma')
# Out:
#    alpha  beta  gamma  a  b
# 0      5     4      1  9  8
# 1      1     1      1  9  8
# 2      3     3      8  1  2

# %%
pd.merge(df7, df8, how = 'left', left_on = 'gamma',right_on = 'gamma')
# Out:
#    alpha  beta  gamma  a  b
# 0      5     4      1  9  8
# 1      1     1      1  9  8
# 2      3     3      8  1  2

# %%
pd.merge(df7,df8, how = 'right', left_on = 'gamma', right_on = 'gamma')
# Out:
#    alpha  beta  gamma  a  b
# 0    5.0   4.0      1  9  8
# 1    1.0   1.0      1  9  8
# 2    3.0   3.0      8  1  2
# 3    NaN   NaN      5  9  8

# %%
pd.merge(df7,df8, how = 'outer', left_on = 'gamma',right_on = 'gamma')
# Out:
#    alpha  beta  gamma  a  b
# 0    5.0   4.0      1  9  8
# 1    1.0   1.0      1  9  8
# 2    3.0   3.0      8  1  2
# 3    NaN   NaN      5  9  8

# %%
df9 = pd.DataFrame({'year':[2000,2002,2000,2001,2003,2001,2000,2000,2004,2002,2005],'runtime':[90,59,60,120,120,96,97,101,123,200,123]})
df9
# Out:
#     year  runtime
# 0   2000       90
# 1   2002       59
# 2   2000       60
# 3   2001      120
# 4   2003      120
# 5   2001       96
# 6   2000       97
# 7   2000      101
# 8   2004      123
# 9   2002      200
# 10  2005      123

# %%
df9.groupby('year')['runtime'].count().reset_index()
# Out:
#    year  runtime
# 0  2000        4
# 1  2001        2
# 2  2002        2
# 3  2003        1
# 4  2004        1
# 5  2005        1

# %%
df9.groupby('year',as_index = False).agg({'runtime':'count'})
# Out:
#    year  runtime
# 0  2000        4
# 1  2001        2
# 2  2002        2
# 3  2003        1
# 4  2004        1
# 5  2005        1

# %%
df9.groupby('year',as_index = True).agg({'runtime':'max'})
# Out:
#       runtime
# year
# 2000      101
# 2001      120
# 2002      200
# 2003      120
# 2004      123
# 2005      123

# %%
pwd
# Out:
# 'C:\\Users\\Deepu\\Documents\\My_Python_codes'

# %%
cd C:\\Users\\Deepu\Downloads
# Out:
# C:\Users\Deepu\Downloads

# %%
df = pd.read_csv('imdb_data.csv')

# %%
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
df['id']
# Out:
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 2995    2996
# 2996    2997
# 2997    2998
# 2998    2999
# 2999    3000
# Name: id, Length: 3000, dtype: int64

# %%
df.drop('id',axis = 1,inplace = True)

# %%
df.columns
# Out:
# Index(['belongs_to_collection', 'budget', 'genres', 'homepage', 'imdb_id',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'poster_path', 'production_companies', 'production_countries',
#        'release_date', 'runtime', 'spoken_languages', 'status', 'tagline',
#        'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
imdb_1=df[df['runtime'] >= 150]

# %%
imdb_2=df[(df['runtime'] > 100) & (df['runtime'] < 150)]

# %%
imdb_3=df[df.runtime <= 100]

# %%
imdb_1.shape,imdb_2.shape,imdb_3.shape
# Out:
# ((135, 22), (1586, 22), (1277, 22))

# %%
print('The shape of imdb_1 is',imdb_1.shape,end = ',')
print('The shape of imdb_2 is',imdb_2.shape,end = ',')
print('The shape of imdb_3 is', imdb_3.shape)
# Out:
# The shape of imdb_1 is (135, 22),The shape of imdb_2 is (1586, 22),The shape of imdb_3 is (1277, 22)

# %%
imdb_1.head()
# Out:
#     belongs_to_collection    budget  \
# 47                    NaN  44000000
# 51                    NaN  12000000
# 76                    NaN    500000
# 97                    NaN         0
# 107                   NaN  72000000
#
#                                                 genres  \
# 47   [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 51   [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...
# 76   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 97   [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...
# 107  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
#
#                         homepage    imdb_id original_language  \
# 47   http://thehatefuleight.com/  tt3460252                en
# 51                           NaN  tt0059243                en
# 76                           NaN  tt0242572                ta
# 97                           NaN  tt1772980                ru
# 107                          NaN  tt0112573                en
#
# ...

# %%
imdb_1['runtime'].min()
# Out:
# 150.0

# %%
imdb_1['runtime'].max()
# Out:
# 338.0

# %%
imdb_1.runtime.isnull().sum()
# Out:
# 0

# %%
imdb_2.runtime.isnull().sum()
# Out:
# 0

# %%
imdb_2.runtime.max(),imdb_2.runtime.min()
# Out:
# (149.0, 101.0)

# %%
imdb_3['runtime'].isnull().sum(),imdb_3.runtime.max(),imdb_3.runtime.min()
# Out:
# (0, 100.0, 0.0)

# %%
imdb_1.shape,imdb_2.shape,imdb_3.shape
# Out:
# ((135, 22), (1586, 22), (1277, 22))

# %%
135+1586+1277
# Out:
# 2998

# %%
all_rows = pd.concat([imdb_1,imdb_2,imdb_3],axis = 0)

# %%
all_columns = pd.concat([imdb_1,imdb_2,imdb_3],axis = 1)

# %%
all_rows.tail(5)
# Out:
#      belongs_to_collection    budget  \
# 2987                   NaN         0
# 2988                   NaN         0
# 2989                   NaN         0
# 2990                   NaN         0
# 2998                   NaN  42000000
#
#                                                  genres  \
# 2987  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 2988                      [{'id': 18, 'name': 'Drama'}]
# 2989  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 2990  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
#
#                             homepage    imdb_id original_language  \
# 2987                             NaN  tt0096246                en
# 2988                             NaN  tt0301978                fa
# 2989                             NaN  tt0206367                en
# 2990                             NaN  tt0118663                en
# ...

# %%
all_columns.tail(5)
# Out:
#      belongs_to_collection  budget genres homepage imdb_id original_language  \
# 2987                   NaN     NaN    NaN      NaN     NaN               NaN
# 2988                   NaN     NaN    NaN      NaN     NaN               NaN
# 2989                   NaN     NaN    NaN      NaN     NaN               NaN
# 2990                   NaN     NaN    NaN      NaN     NaN               NaN
# 2998                   NaN     NaN    NaN      NaN     NaN               NaN
#
#      original_title overview  popularity poster_path  ... release_date  \
# 2987            NaN      NaN         NaN         NaN  ...      1/20/89
# 2988            NaN      NaN         NaN         NaN  ...      5/20/02
# 2989            NaN      NaN         NaN         NaN  ...      5/11/01
# 2990            NaN      NaN         NaN         NaN  ...      3/28/97
# 2998            NaN      NaN         NaN         NaN  ...      1/16/04
#
# ...

# %%
pd.concat([imdb_1,imdb_2],axis = 0)
# Out:
#      belongs_to_collection    budget  \
# 47                     NaN  44000000
# 51                     NaN  12000000
# 76                     NaN    500000
# 97                     NaN         0
# 107                    NaN  72000000
# ...                    ...       ...
# 2994                   NaN         0
# 2995                   NaN         0
# 2996                   NaN         0
# 2997                   NaN  65000000
# 2999                   NaN  35000000
#
#                                                  genres  \
# 47    [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 51    [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...
# 76    [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 97    [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...
# 107   [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# ...                                                 ...
# 2994                      [{'id': 18, 'name': 'Drama'}]
# 2995  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# ...

# %%
imdb_1.shape,imdb_2.shape
# Out:
# ((135, 22), (1586, 22))

# %%
pd.concat([imdb_1,imdb_2],axis = 1)
# Out:
#      belongs_to_collection      budget  \
# 47                     NaN  44000000.0
# 51                     NaN  12000000.0
# 76                     NaN    500000.0
# 97                     NaN         0.0
# 107                    NaN  72000000.0
# ...                    ...         ...
# 2994                   NaN         NaN
# 2995                   NaN         NaN
# 2996                   NaN         NaN
# 2997                   NaN         NaN
# 2999                   NaN         NaN
#
#                                                  genres  \
# 47    [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 51    [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...
# 76    [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 97    [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...
# 107   [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# ...                                                 ...
# 2994                                                NaN
# ...

# %%
pd.concat([imdb_2,imdb_3],axis = 0)
# Out:
#                                   belongs_to_collection    budget  \
# 1     [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2                                                   NaN   3300000
# 3                                                   NaN   1200000
# 4                                                   NaN         0
# 10    [{'id': 1575, 'name': 'Rocky Collection', 'pos...   1000000
# ...                                                 ...       ...
# 2987                                                NaN         0
# 2988                                                NaN         0
# 2989                                                NaN         0
# 2990                                                NaN         0
# 2998                                                NaN  42000000
#
#                                                  genres  \
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                         [{'id': 18, 'name': 'Drama'}]
# ...

# %%
pd.concat([imdb_2,imdb_3],axis = 1)
# Out:
#                                   belongs_to_collection      budget  \
# 1     [{'id': 107674, 'name': 'The Princess Diaries ...  40000000.0
# 2                                                   NaN   3300000.0
# 3                                                   NaN   1200000.0
# 4                                                   NaN         0.0
# 10    [{'id': 1575, 'name': 'Rocky Collection', 'pos...   1000000.0
# ...                                                 ...         ...
# 2987                                                NaN         NaN
# 2988                                                NaN         NaN
# 2989                                                NaN         NaN
# 2990                                                NaN         NaN
# 2998                                                NaN         NaN
#
#                                                  genres  \
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# ...

# %%
import glob

# %%
pwd
# Out:
# 'C:\\Users\\Deepu\\Downloads'

# %%
cd C:\\Users\\Deepu\\Desktop
# Out:
# C:\Users\Deepu\Desktop

# %%
pwd
# Out:
# 'C:\\Users\\Deepu\\Desktop'

# %%
pattern = 'cat*'
glob.glob(pattern)
# Out:
# ['cat.png']

# %%
pattern = 'Book*'
glob.glob(pattern)
# Out:
# ['bookmark25.html', 'books']

# %%
pwd
# Out:
# 'C:\\Users\\Deepu\\Desktop'

# %%
cd C:\Users\Deepu\Desktop\data and excel\experiment
# Out:
# C:\Users\Deepu\Desktop\data and excel\experiment

# %%
pattern = 'Book*'
shelf=glob.glob(pattern)

# %%
shelf
# Out:
# ['Book1.csv', 'Book2.csv', 'Book3.csv']

# %%
df_a = []
for book in shelf:
    df = pd.read_csv(book)
    #display(df)
    df_a.append(df)
df_a
# Out:
# [   Row ID  Order ID             Name        Freight Mode
#  0       1         6   Stephen Cooper  Express Road Cargo
#  1       2       193  Charles Freeman  Express Road Cargo
#  2       3       322    Joshua George  Express Road Cargo
#  3       4       322    Joshua George  Express Road Cargo
#  4       5       358   Nicholas Perez           Air Cargo
#  5       6       358   Nicholas Perez  Express Road Cargo
#  6       7       359   Marie Morrison           Air Cargo
#  7       8       386  Victor Castillo  Express Road Cargo
#  8       9       386  Victor Castillo  Express Road Cargo
#  9      10       388    Billy Bradley  Express Road Cargo,
#                   Segment Region       Priority
#  0               Red Wine  North  Not Specified
#  1               Red Wine  South       Critical
#  2  Rose / Sparkling Wine   West       Critical
#  3               Red Wine   West       Critical
#  4             White Wine  South           High
# ...

# %%
shelf
# Out:
# ['Book1.csv', 'Book2.csv', 'Book3.csv']

# %%
empty_box = []
for book in shelf:
    df = pd.read_csv(book)
    empty_box.append(df)
consolidated_df=pd.concat(empty_box,axis = 1)
display(consolidated_df)
# Out:
#    Row ID  Order ID             Name        Freight Mode  \
# 0       1         6   Stephen Cooper  Express Road Cargo
# 1       2       193  Charles Freeman  Express Road Cargo
# 2       3       322    Joshua George  Express Road Cargo
# 3       4       322    Joshua George  Express Road Cargo
# 4       5       358   Nicholas Perez           Air Cargo
# 5       6       358   Nicholas Perez  Express Road Cargo
# 6       7       359   Marie Morrison           Air Cargo
# 7       8       386  Victor Castillo  Express Road Cargo
# 8       9       386  Victor Castillo  Express Road Cargo
# 9      10       388    Billy Bradley  Express Road Cargo
#
#                  Segment Region       Priority         Sub Segment    Country  \
# 0               Red Wine  North  Not Specified           Zinfandel  Australia
# 1               Red Wine  South       Critical  Cabernet Sauvignon  Australia
# 2  Rose / Sparkling Wine   West       Critical          Pinot Gris  Australia
# ...

# %% [markdown]
# Main function is glob
#
# First collect the files in a shelf and then run a loop on the selve, for empty box/(you don't need the empty df here) just do a
# normal append and run a concated method of the empty_box(which will now have all the dfs appended)

# %%
pwd
# Out:
# 'C:\\Users\\Deepu\\Desktop\\data and excel\\experiment'

# %%
cd C:\\Users\\Deepu\\Downloads
# Out:
# C:\Users\Deepu\Downloads

# %%
pd.read_excel('AirbnbNYC2019-210324-121446.xlsx')
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
import glob

# %%
pattern = 'Cat*'
glob.glob(pattern)
# Out:
# []

# %%
pwd
# Out:
# 'C:\\Users\\Deepu\\Documents\\My_Python_codes'

# %%
cd C:\\Users\\Deepu\\Downloads
# Out:
# C:\Users\Deepu\Downloads

# %%
cd C:\\Users\\Deepu\\Desktop
# Out:
# C:\Users\Deepu\Desktop

# %%
pattern = 'Cat*'
glob.glob(pattern)
# Out:
# ['cat.png']

# %%
cd C:\Users\Deepu\Desktop\data and excel\experiment
# Out:
# C:\Users\Deepu\Desktop\data and excel\experiment

# %%
pattern = 'Book*'
glob.glob(pattern)
# Out:
# ['Book1.csv', 'Book2.csv', 'Book3.csv']

# %%
shelf = glob.glob(pattern)

# %%
consolidated = []
for book in shelf:
    df = pd.read_csv(book)
    consolidated.append(df)
    
fdf = pd.concat(consolidated,axis = 1)    
display(fdf)
# Out:
#    Row ID  Order ID             Name        Freight Mode  \
# 0       1         6   Stephen Cooper  Express Road Cargo
# 1       2       193  Charles Freeman  Express Road Cargo
# 2       3       322    Joshua George  Express Road Cargo
# 3       4       322    Joshua George  Express Road Cargo
# 4       5       358   Nicholas Perez           Air Cargo
# 5       6       358   Nicholas Perez  Express Road Cargo
# 6       7       359   Marie Morrison           Air Cargo
# 7       8       386  Victor Castillo  Express Road Cargo
# 8       9       386  Victor Castillo  Express Road Cargo
# 9      10       388    Billy Bradley  Express Road Cargo
#
#                  Segment Region       Priority         Sub Segment    Country  \
# 0               Red Wine  North  Not Specified           Zinfandel  Australia
# 1               Red Wine  South       Critical  Cabernet Sauvignon  Australia
# 2  Rose / Sparkling Wine   West       Critical          Pinot Gris  Australia
# ...

# %%
import numpy as np
import pandas as pd

# %%
table1=pd.DataFrame({'Roll_no.':[1,2,3,4],'Name':['A','B','C','D'],'English_marks':[22,25,27,29]})
display(table1)
# Out:
#    Roll_no. Name  English_marks
# 0         1    A             22
# 1         2    B             25
# 2         3    C             27
# 3         4    D             29

# %%
# this is just to reset index 
table1.reset_index(drop = 'index')
# Out:
#    Roll_no. Name  English_marks
# 0         1    A             22
# 1         2    B             25
# 2         3    C             27
# 3         4    D             29

# %%
table2 = pd.DataFrame({'Roll_no.':[7,8,9,10,11,12],'Name':['G','H','I','J','K','L'], 'English_marks':[15,16,19,11,18,13]})
display(table2)
# Out:
#    Roll_no. Name  English_marks
# 0         7    G             15
# 1         8    H             16
# 2         9    I             19
# 3        10    J             11
# 4        11    K             18
# 5        12    L             13

# %%
pd.concat([table1,table2],axis = 0)
# Out:
#    Roll_no. Name  English_marks
# 0         1    A             22
# 1         2    B             25
# 2         3    C             27
# 3         4    D             29
# 0         7    G             15
# 1         8    H             16
# 2         9    I             19
# 3        10    J             11
# 4        11    K             18
# 5        12    L             13

# %%
pd.concat([table1,table2],axis = 1)
# Out:
#    Roll_no. Name  English_marks  Roll_no. Name  English_marks
# 0       1.0    A           22.0         7    G             15
# 1       2.0    B           25.0         8    H             16
# 2       3.0    C           27.0         9    I             19
# 3       4.0    D           29.0        10    J             11
# 4       NaN  NaN            NaN        11    K             18
# 5       NaN  NaN            NaN        12    L             13

# %%
pd.concat([table1,table2],axis = 0, ignore_index = True)
# Out:
#    Roll_no. Name  English_marks
# 0         1    A             22
# 1         2    B             25
# 2         3    C             27
# 3         4    D             29
# 4         7    G             15
# 5         8    H             16
# 6         9    I             19
# 7        10    J             11
# 8        11    K             18
# 9        12    L             13

# %%
pd.concat([table1,table2],axis = 1)
# Out:
#    Roll_no. Name  English_marks  Roll_no. Name  English_marks
# 0       1.0    A           22.0         7    G             15
# 1       2.0    B           25.0         8    H             16
# 2       3.0    C           27.0         9    I             19
# 3       4.0    D           29.0        10    J             11
# 4       NaN  NaN            NaN        11    K             18
# 5       NaN  NaN            NaN        12    L             13

# %%
emp_table1 = pd.DataFrame({'emp_id':[1,2,3,4,6,7,8,10],'emp_name':['Harry','Ram','Shyam','Sonal','Ravish','Omkar','Ishaan','Ivan'],
                          'salary':[5000,8000,9000,9500,6600,7800,5900,7000],'date':['2020-01-20','2020-3-09','2020-07-13','2020-01-20','2020-05-07',\
                            '2020-01-20','2020-03-26','2020-01-20']})
emp_table1
# Out:
#    emp_id emp_name  salary        date
# 0       1    Harry    5000  2020-01-20
# 1       2      Ram    8000   2020-3-09
# 2       3    Shyam    9000  2020-07-13
# 3       4    Sonal    9500  2020-01-20
# 4       6   Ravish    6600  2020-05-07
# 5       7    Omkar    7800  2020-01-20
# 6       8   Ishaan    5900  2020-03-26
# 7      10     Ivan    7000  2020-01-20

# %%
emp_table1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   emp_id    8 non-null      int64
#  1   emp_name  8 non-null      object
#  2   salary    8 non-null      int64
#  3   date      8 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 384.0+ bytes

# %%
emp_table1['date']=pd.to_datetime(emp_table1['date'])

# %%
emp_table1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   emp_id    8 non-null      int64
#  1   emp_name  8 non-null      object
#  2   salary    8 non-null      int64
#  3   date      8 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 384.0+ bytes

# %%
emp_table1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   emp_id    8 non-null      int64
#  1   emp_name  8 non-null      object
#  2   salary    8 non-null      int64
#  3   date      8 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 384.0+ bytes

# %%
from datetime import datetime

# %%
emp_table1.apply(lambda x: datetime.strptime(x['date'],'%Y-%m-%d'),axis = 1)
# Out:
# 0   2020-01-20
# 1   2020-03-09
# 2   2020-07-13
# 3   2020-01-20
# 4   2020-05-07
# 5   2020-01-20
# 6   2020-03-26
# 7   2020-01-20
# dtype: datetime64[ns]

# %%
def to_date(a):
    return datetime.strptime(a['date'],'%Y-%m-%d')

# %%
emp_table1.apply(to_date,axis = 1)
# Out:
# 0   2020-01-20
# 1   2020-03-09
# 2   2020-07-13
# 3   2020-01-20
# 4   2020-05-07
# 5   2020-01-20
# 6   2020-03-26
# 7   2020-01-20
# dtype: datetime64[ns]

# %%
def to_date_gen(a):
    return datetime.strptime(a,'%Y-%m-%d')

# %%
to_date_gen('2023-09-11')
# Out:
# datetime.datetime(2023, 9, 11, 0, 0)

# %%
emp_table1['date'] = pd.to_datetime(emp_table1['date'])

# %%
emp_table1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   emp_id    8 non-null      int64
#  1   emp_name  8 non-null      object
#  2   salary    8 non-null      int64
#  3   date      8 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 384.0+ bytes

# %%
emp_table2 = pd.DataFrame({'dept_id':['A78','A67','A78','A73','A67','A50'],'dept':['Operations','Data science','Operation',
              'Business Analysis','Data science','Human resource'],'emp_id':[1,3,5,6,8,2]})
emp_table2
# Out:
#   dept_id               dept  emp_id
# 0     A78         Operations       1
# 1     A67       Data science       3
# 2     A78          Operation       5
# 3     A73  Business Analysis       6
# 4     A67       Data science       8
# 5     A50     Human resource       2

# %%
display(emp_table1),display(emp_table2)
# Out:
#    emp_id emp_name  salary       date
# 0       1    Harry    5000 2020-01-20
# 1       2      Ram    8000 2020-03-09
# 2       3    Shyam    9000 2020-07-13
# 3       4    Sonal    9500 2020-01-20
# 4       6   Ravish    6600 2020-05-07
# 5       7    Omkar    7800 2020-01-20
# 6       8   Ishaan    5900 2020-03-26
# 7      10     Ivan    7000 2020-01-20
#   dept_id               dept  emp_id
# 0     A78         Operations       1
# 1     A67       Data science       3
# 2     A78          Operation       5
# 3     A73  Business Analysis       6
# 4     A67       Data science       8
# 5     A50     Human resource       2
# (None, None)

# %%
pd.merge(emp_table1,emp_table2, how = 'inner', left_on = 'emp_id', right_on = 'emp_id')
# Out:
#    emp_id emp_name  salary       date dept_id               dept
# 0       1    Harry    5000 2020-01-20     A78         Operations
# 1       2      Ram    8000 2020-03-09     A50     Human resource
# 2       3    Shyam    9000 2020-07-13     A67       Data science
# 3       6   Ravish    6600 2020-05-07     A73  Business Analysis
# 4       8   Ishaan    5900 2020-03-26     A67       Data science

# %%
df = pd.read_csv('imdb_data.csv')

# %%
imdb = df.copy()

# %%
imdb.drop('id',axis = 1,inplace = True)

# %%
len(imdb.columns),len(df.columns)
# Out:
# (22, 23)

# %%
df['id']
# Out:
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 2995    2996
# 2996    2997
# 2997    2998
# 2998    2999
# 2999    3000
# Name: id, Length: 3000, dtype: int64

# %%
english_movies = imdb[imdb['original_language'] == 'en']

# %%
imdb.loc[imdb['runtime'] >= 100,['imdb_id','runtime']]
# Out:
#         imdb_id  runtime
# 1     tt0368933    113.0
# 2     tt2582802    105.0
# 3     tt1821480    122.0
# 4     tt1380152    118.0
# 8     tt0117110    100.0
# ...         ...      ...
# 2994  tt0105327    106.0
# 2995  tt0109403    102.0
# 2996  tt2364975    102.0
# 2997  tt0116908    120.0
# 2999  tt1600195    106.0
#
# [1820 rows x 2 columns]

# %%
long_movies = imdb.loc[imdb['runtime']>= 100,['imdb_id','runtime']]
display(long_movies)
# Out:
#         imdb_id  runtime
# 1     tt0368933    113.0
# 2     tt2582802    105.0
# 3     tt1821480    122.0
# 4     tt1380152    118.0
# 8     tt0117110    100.0
# ...         ...      ...
# 2994  tt0105327    106.0
# 2995  tt0109403    102.0
# 2996  tt2364975    102.0
# 2997  tt0116908    120.0
# 2999  tt1600195    106.0
#
# [1820 rows x 2 columns]

# %%
english_movies.shape,long_movies.shape
# Out:
# ((2575, 22), (1820, 2))

# %%
pd.merge(english_movies,long_movies, how = 'inner', left_on = 'imdb_id', right_on = 'imdb_id')
# Out:
#                                   belongs_to_collection    budget  \
# 0     [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 1                                                   NaN   3300000
# 2     [{'id': 256377, 'name': 'The Muppet Collection...         0
# 3     [{'id': 1575, 'name': 'Rocky Collection', 'pos...   1000000
# 4                                                   NaN  15000000
# ...                                                 ...       ...
# 1523                                                NaN  60000000
# 1524                                                NaN         0
# 1525                                                NaN         0
# 1526                                                NaN  65000000
# 1527                                                NaN  35000000
#
#                                                  genres  \
# 0     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 1                         [{'id': 18, 'name': 'Drama'}]
# ...

# %%
# without using the boolean indexing 
imdb[imdb['runtime'] >= 100][['imdb_id','runtime']]
# Out:
#         imdb_id  runtime
# 1     tt0368933    113.0
# 2     tt2582802    105.0
# 3     tt1821480    122.0
# 4     tt1380152    118.0
# 8     tt0117110    100.0
# ...         ...      ...
# 2994  tt0105327    106.0
# 2995  tt0109403    102.0
# 2996  tt2364975    102.0
# 2997  tt0116908    120.0
# 2999  tt1600195    106.0
#
# [1820 rows x 2 columns]

# %%
pd.merge(english_movies,long_movies , how = 'inner', on = 'imdb_id')
# Out:
#                                   belongs_to_collection    budget  \
# 0     [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 1                                                   NaN   3300000
# 2     [{'id': 256377, 'name': 'The Muppet Collection...         0
# 3     [{'id': 1575, 'name': 'Rocky Collection', 'pos...   1000000
# 4                                                   NaN  15000000
# ...                                                 ...       ...
# 1523                                                NaN  60000000
# 1524                                                NaN         0
# 1525                                                NaN         0
# 1526                                                NaN  65000000
# 1527                                                NaN  35000000
#
#                                                  genres  \
# 0     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 1                         [{'id': 18, 'name': 'Drama'}]
# ...

# %%
imdb[(imdb['original_language'] == 'en') & (imdb['runtime'] >= 100)]
# Out:
#                                   belongs_to_collection    budget  \
# 1     [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2                                                   NaN   3300000
# 8     [{'id': 256377, 'name': 'The Muppet Collection...         0
# 10    [{'id': 1575, 'name': 'Rocky Collection', 'pos...   1000000
# 12                                                  NaN  15000000
# ...                                                 ...       ...
# 2993                                                NaN  60000000
# 2994                                                NaN         0
# 2995                                                NaN         0
# 2997                                                NaN  65000000
# 2999                                                NaN  35000000
#
#                                                  genres  \
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                         [{'id': 18, 'name': 'Drama'}]
# ...

# %%
display(emp_table1),display(emp_table2)
# Out:
#    emp_id emp_name  salary       date
# 0       1    Harry    5000 2020-01-20
# 1       2      Ram    8000 2020-03-09
# 2       3    Shyam    9000 2020-07-13
# 3       4    Sonal    9500 2020-01-20
# 4       6   Ravish    6600 2020-05-07
# 5       7    Omkar    7800 2020-01-20
# 6       8   Ishaan    5900 2020-03-26
# 7      10     Ivan    7000 2020-01-20
#   dept_id               dept  emp_id
# 0     A78         Operations       1
# 1     A67       Data science       3
# 2     A78          Operation       5
# 3     A73  Business Analysis       6
# 4     A67       Data science       8
# 5     A50     Human resource       2
# (None, None)

# %%
pd.merge(emp_table1,emp_table2, how = 'left', on = 'emp_id')
# Out:
#    emp_id emp_name  salary       date dept_id               dept
# 0       1    Harry    5000 2020-01-20     A78         Operations
# 1       2      Ram    8000 2020-03-09     A50     Human resource
# 2       3    Shyam    9000 2020-07-13     A67       Data science
# 3       4    Sonal    9500 2020-01-20     NaN                NaN
# 4       6   Ravish    6600 2020-05-07     A73  Business Analysis
# 5       7    Omkar    7800 2020-01-20     NaN                NaN
# 6       8   Ishaan    5900 2020-03-26     A67       Data science
# 7      10     Ivan    7000 2020-01-20     NaN                NaN

# %%
pd.merge(emp_table1,emp_table2, how = 'left', left_on = 'emp_id', right_on = 'emp_id')
# Out:
#    emp_id emp_name  salary       date dept_id               dept
# 0       1    Harry    5000 2020-01-20     A78         Operations
# 1       2      Ram    8000 2020-03-09     A50     Human resource
# 2       3    Shyam    9000 2020-07-13     A67       Data science
# 3       4    Sonal    9500 2020-01-20     NaN                NaN
# 4       6   Ravish    6600 2020-05-07     A73  Business Analysis
# 5       7    Omkar    7800 2020-01-20     NaN                NaN
# 6       8   Ishaan    5900 2020-03-26     A67       Data science
# 7      10     Ivan    7000 2020-01-20     NaN                NaN

# %%
pd.merge(english_movies,long_movies, how = 'left', left_on = 'imdb_id', right_on = 'imdb_id')
# Out:
#                                   belongs_to_collection    budget  \
# 0     [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1     [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2                                                   NaN   3300000
# 3                                                   NaN   8000000
# 4                                                   NaN  14000000
# ...                                                 ...       ...
# 2570                                                NaN         0
# 2571                                                NaN         0
# 2572                                                NaN  65000000
# 2573                                                NaN  42000000
# 2574                                                NaN  35000000
#
#                                                  genres  \
# 0                        [{'id': 35, 'name': 'Comedy'}]
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# ...

# %%
pd.merge(emp_table1,emp_table2, how = 'right', left_on = 'emp_id', right_on = 'emp_id')
# Out:
#    emp_id emp_name  salary       date dept_id               dept
# 0       1    Harry  5000.0 2020-01-20     A78         Operations
# 1       3    Shyam  9000.0 2020-07-13     A67       Data science
# 2       5      NaN     NaN        NaT     A78          Operation
# 3       6   Ravish  6600.0 2020-05-07     A73  Business Analysis
# 4       8   Ishaan  5900.0 2020-03-26     A67       Data science
# 5       2      Ram  8000.0 2020-03-09     A50     Human resource

# %%
pd.merge(emp_table1,emp_table2, how = 'right', on = 'emp_id')
# Out:
#    emp_id emp_name  salary       date dept_id               dept
# 0       1    Harry  5000.0 2020-01-20     A78         Operations
# 1       3    Shyam  9000.0 2020-07-13     A67       Data science
# 2       5      NaN     NaN        NaT     A78          Operation
# 3       6   Ravish  6600.0 2020-05-07     A73  Business Analysis
# 4       8   Ishaan  5900.0 2020-03-26     A67       Data science
# 5       2      Ram  8000.0 2020-03-09     A50     Human resource

# %%
pd.merge(english_movies,long_movies, how = 'right', left_on = 'imdb_id', right_on = 'imdb_id')
# Out:
#                                   belongs_to_collection      budget  \
# 0     [{'id': 107674, 'name': 'The Princess Diaries ...  40000000.0
# 1                                                   NaN   3300000.0
# 2                                                   NaN         NaN
# 3                                                   NaN         NaN
# 4     [{'id': 256377, 'name': 'The Muppet Collection...         0.0
# ...                                                 ...         ...
# 1815                                                NaN         0.0
# 1816                                                NaN         0.0
# 1817                                                NaN         NaN
# 1818                                                NaN  65000000.0
# 1819                                                NaN  35000000.0
#
#                                                  genres  \
# 0     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# ...

# %%
long_movies.shape
# Out:
# (1820, 2)

# %%
pd.merge(emp_table1,emp_table2, how = 'outer', on = 'emp_id')
# Out:
#    emp_id emp_name  salary       date dept_id               dept
# 0       1    Harry  5000.0 2020-01-20     A78         Operations
# 1       2      Ram  8000.0 2020-03-09     A50     Human resource
# 2       3    Shyam  9000.0 2020-07-13     A67       Data science
# 3       4    Sonal  9500.0 2020-01-20     NaN                NaN
# 4       6   Ravish  6600.0 2020-05-07     A73  Business Analysis
# 5       7    Omkar  7800.0 2020-01-20     NaN                NaN
# 6       8   Ishaan  5900.0 2020-03-26     A67       Data science
# 7      10     Ivan  7000.0 2020-01-20     NaN                NaN
# 8       5      NaN     NaN        NaT     A78          Operation

# %%
pd.merge(emp_table1,emp_table2, how = 'outer', left_on = 'emp_id', right_on = 'emp_id')
# Out:
#    emp_id emp_name  salary       date dept_id               dept
# 0       1    Harry  5000.0 2020-01-20     A78         Operations
# 1       2      Ram  8000.0 2020-03-09     A50     Human resource
# 2       3    Shyam  9000.0 2020-07-13     A67       Data science
# 3       4    Sonal  9500.0 2020-01-20     NaN                NaN
# 4       6   Ravish  6600.0 2020-05-07     A73  Business Analysis
# 5       7    Omkar  7800.0 2020-01-20     NaN                NaN
# 6       8   Ishaan  5900.0 2020-03-26     A67       Data science
# 7      10     Ivan  7000.0 2020-01-20     NaN                NaN
# 8       5      NaN     NaN        NaT     A78          Operation

# %%
pd.merge(english_movies, long_movies, how = 'outer', on = 'imdb_id')
# Out:
#                                   belongs_to_collection      budget  \
# 0     [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000.0
# 1     [{'id': 107674, 'name': 'The Princess Diaries ...  40000000.0
# 2                                                   NaN   3300000.0
# 3                                                   NaN   8000000.0
# 4                                                   NaN  14000000.0
# ...                                                 ...         ...
# 2862                                                NaN         NaN
# 2863                                                NaN         NaN
# 2864                                                NaN         NaN
# 2865                                                NaN         NaN
# 2866                                                NaN         NaN
#
#                                                  genres  \
# 0                        [{'id': 35, 'name': 'Comedy'}]
# ...

# %%
pd.merge(english_movies, long_movies, how = 'outer', left_on = 'imdb_id', right_on = 'imdb_id')
# Out:
#                                   belongs_to_collection      budget  \
# 0     [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000.0
# 1     [{'id': 107674, 'name': 'The Princess Diaries ...  40000000.0
# 2                                                   NaN   3300000.0
# 3                                                   NaN   8000000.0
# 4                                                   NaN  14000000.0
# ...                                                 ...         ...
# 2862                                                NaN         NaN
# 2863                                                NaN         NaN
# 2864                                                NaN         NaN
# 2865                                                NaN         NaN
# 2866                                                NaN         NaN
#
#                                                  genres  \
# 0                        [{'id': 35, 'name': 'Comedy'}]
# ...

# %%
df = pd.read_csv('imdb_data.csv')

# %%
imdb = df.copy()

# %%
def to_dts(a):
    return datetime.strptime(a['release_date'],'%m/%d/%y').year

# %%
imdb['un_year'] = imdb.apply(to_dts,axis = 1)

# %%
imdb['year'] = np.where(imdb.un_year > 2020,imdb.un_year - 100,imdb.un_year)

# %%
imdb['year'].min()
# Out:
# 1921

# %%
imdb['year'].value_counts()
# Out:
# 2013    141
# 2015    128
# 2010    126
# 2012    125
# 2016    125
#        ...
# 1935      1
# 1938      1
# 1930      1
# 1926      1
# 1924      1
# Name: year, Length: 90, dtype: int64

# %%
imdb.groupby('year')['runtime'].count().reset_index()
# Out:
#     year  runtime
# 0   1921        1
# 1   1924        1
# 2   1925        2
# 3   1926        1
# 4   1927        2
# ..   ...      ...
# 85  2013      141
# 86  2014      123
# 87  2015      128
# 88  2016      125
# 89  2017       40
#
# [90 rows x 2 columns]

# %%
imdb.groupby('year')['runtime'].mean().reset_index()
# Out:
#     year     runtime
# 0   1921   68.000000
# 1   1924  149.000000
# 2   1925  106.000000
# 3   1926   84.000000
# 4   1927   87.000000
# ..   ...         ...
# 85  2013  108.865248
# 86  2014  105.414634
# 87  2015  111.937500
# 88  2016  108.584000
# 89  2017  111.150000
#
# [90 rows x 2 columns]

# %%
imdb['runtime']
# Out:
# 0        93.0
# 1       113.0
# 2       105.0
# 3       122.0
# 4       118.0
#         ...
# 2995    102.0
# 2996    102.0
# 2997    120.0
# 2998     90.0
# 2999    106.0
# Name: runtime, Length: 3000, dtype: float64

# %%
imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
imdb['release_date']=pd.to_datetime(imdb['release_date'])

# %%
imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   datetime64[ns]
# ...

# %%
imdb.groupby('release_date')['runtime'].median()
# Out:
# release_date
# 1973-05-24    115.0
# 1973-06-15     93.0
# 1973-08-08     76.0
# 1973-10-02    110.0
# 1973-11-03     87.0
#               ...
# 2072-03-14    175.0
# 2072-06-29     88.0
# 2072-08-01     90.0
# 2072-09-13     98.0
# 2072-10-14    129.0
# Name: runtime, Length: 2398, dtype: float64

# %%
imdb.groupby('release_date')['imdb_id'].count()
# Out:
# release_date
# 1973-05-24    1
# 1973-06-15    1
# 1973-08-08    1
# 1973-10-02    1
# 1973-11-03    1
#              ..
# 2072-03-14    1
# 2072-06-29    1
# 2072-08-01    1
# 2072-09-13    1
# 2072-10-14    1
# Name: imdb_id, Length: 2398, dtype: int64

# %%
imdb.groupby('year')['imdb_id'].count().reset_index().tail(3)
# Out:
#     year  imdb_id
# 87  2015      128
# 88  2016      125
# 89  2017       40

# %%
imdb.groupby('year')['imdb_id'].count().median()
# Out:
# 8.0

# %%
imdb.groupby('year')['runtime'].mean().median()
# Out:
# 107.85119047619048

# %%
imdb.groupby('release_date').agg({'runtime':'mean'})
# Out:
#               runtime
# release_date
# 1973-05-24      115.0
# 1973-06-15       93.0
# 1973-08-08       76.0
# 1973-10-02      110.0
# 1973-11-03       87.0
# ...               ...
# 2072-03-14      175.0
# 2072-06-29       88.0
# 2072-08-01       90.0
# 2072-09-13       98.0
# 2072-10-14      129.0
#
# [2398 rows x 1 columns]

# %%
imdb.groupby('year',as_index = False).agg({'runtime':'median'}).sort_values('runtime',ascending = False)
# Out:
#     year  runtime
# 1   1924    149.0
# 34  1962    147.0
# 41  1969    145.0
# 24  1952    143.0
# 32  1960    137.0
# ..   ...      ...
# 3   1926     84.0
# 7   1931     80.5
# 0   1921     68.0
# 5   1928     65.0
# 6   1930     63.0
#
# [90 rows x 2 columns]

# %%
imdb.groupby('year',as_index = False).agg({'year':'mean'})
# Out:
#       year
# 0   1921.0
# 1   1924.0
# 2   1925.0
# 3   1926.0
# 4   1927.0
# ..     ...
# 85  2013.0
# 86  2014.0
# 87  2015.0
# 88  2016.0
# 89  2017.0
#
# [90 rows x 1 columns]

# %%
imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   datetime64[ns]
# ...

# %%
imdb.groupby(['year','runtime'],as_index = True).agg({'runtime':'median'})
# Out:
#               runtime
# year runtime
# 1921 68.0        68.0
# 1924 149.0      149.0
# 1925 75.0        75.0
#      137.0      137.0
# 1926 84.0        84.0
# ...               ...
# 2017 137.0      137.0
#      140.0      140.0
#      141.0      141.0
#      149.0      149.0
#      168.0      168.0
#
# [1784 rows x 1 columns]

# %%
imdb.groupby('original_language','year')['release_date'].count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:550, in NDFrame._get_axis_number(cls, axis)
#     549 try:
# --> 550     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     551 except KeyError:
#
# KeyError: 'year'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [160], in <cell line: 1>()
# ----> 1 imdb.groupby('original_language','year')['release_date'].count()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:7707, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7705 if level is None and by is None:
#    7706     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 7707 axis = self._get_axis_number(axis)
# ...

# %%
imdb.groupby(['year','original_language']).agg({'original_language':'count'})
# Out:
#                         original_language
# year original_language
# 1921 en                                 1
# 1924 en                                 1
# 1925 en                                 1
#      ru                                 1
# 1926 en                                 1
# ...                                   ...
# 2017 en                                35
#      es                                 2
#      fr                                 1
#      ru                                 1
#      ta                                 1
#
# [348 rows x 1 columns]

# %%
imdb.groupby(['year','original_language']).agg({'runtime':'median'})
# Out:
#                         runtime
# year original_language
# 1921 en                    68.0
# 1924 en                   149.0
# 1925 en                   137.0
#      ru                    75.0
# 1926 en                    84.0
# ...                         ...
# 2017 en                   109.0
#      es                    91.5
#      fr                    86.0
#      ru                   140.0
#      ta                   168.0
#
# [348 rows x 1 columns]

# %%
imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   datetime64[ns]
# ...

# %%
# We can find the maximum movie runtime across different years

# %%
imdb.groupby('year',as_index = False).agg({'runtime':'max'})
# Out:
#     year  runtime
# 0   1921     68.0
# 1   1924    149.0
# 2   1925    137.0
# 3   1926     84.0
# 4   1927     94.0
# ..   ...      ...
# 85  2013    186.0
# 86  2014    164.0
# 87  2015    193.0
# 88  2016    162.0
# 89  2017    168.0
#
# [90 rows x 2 columns]

# %%
imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   datetime64[ns]
# ...

# %%
imdb.budget.value_counts()
# Out:
# 0           812
# 15000000     72
# 40000000     71
# 25000000     71
# 5000000      68
#            ...
# 747000        1
# 1119000       1
# 65000         1
# 1750000       1
# 1135654       1
# Name: budget, Length: 406, dtype: int64

# %%
imdb.groupby(['year','budget'],as_index = False).agg({'year':'count','budget':'mean'}).sort_values(by = ['year'])
# Out:
#       year      budget
# 0        1    250000.0
# 1024     1  82500000.0
# 1023     1  80000000.0
# 1022     1  72500000.0
# 1021     1  70000000.0
# ...    ...         ...
# 1573    30         0.0
# 1322    37         0.0
# 1506    40         0.0
# 1447    43         0.0
# 1383    46         0.0
#
# [1665 rows x 2 columns]

# %%
imdb.groupby(['year']).agg({'runtime':'max'}).reset_index()
# Out:
#     year  runtime
# 0   1921     68.0
# 1   1924    149.0
# 2   1925    137.0
# 3   1926     84.0
# 4   1927     94.0
# ..   ...      ...
# 85  2013    186.0
# 86  2014    164.0
# 87  2015    193.0
# 88  2016    162.0
# 89  2017    168.0
#
# [90 rows x 2 columns]

# %%
imdb.groupby('year').agg({'runtime':'sum'})
# Out:
#       runtime
# year
# 1921     68.0
# 1924    149.0
# 1925    212.0
# 1926     84.0
# 1927    174.0
# ...       ...
# 2013  15350.0
# 2014  12966.0
# 2015  14328.0
# 2016  13573.0
# 2017   4446.0
#
# [90 rows x 1 columns]

# %%
imdb.groupby(['year','original_language']).agg({'release_date':'count','budget':'median'})
# Out:
#                         release_date      budget
# year original_language
# 1921 en                            1    250000.0
# 1924 en                            1   1135654.0
# 1925 en                            1       592.0
#      ru                            1         0.0
# 1926 en                            1    463455.0
# ...                              ...         ...
# 2017 en                           35  22000000.0
#      es                            2   2000000.0
#      fr                            1         0.0
#      ru                            1   7075038.0
#      ta                            1         0.0
#
# [348 rows x 2 columns]

# %%
a=imdb.groupby(['year','original_language'],as_index = False).agg({'budget':'count'})

# %%
a
# Out:
#      year original_language  budget
# 0    1921                en       1
# 1    1924                en       1
# 2    1925                en       1
# 3    1925                ru       1
# 4    1926                en       1
# ..    ...               ...     ...
# 343  2017                en      35
# 344  2017                es       2
# 345  2017                fr       1
# 346  2017                ru       1
# 347  2017                ta       1
#
# [348 rows x 3 columns]

# %%
a.rename(columns = {'year':'Release_year','original_language':'Language','budget':'count_budget'})
# Out:
#      Release_year Language  count_budget
# 0            1921       en             1
# 1            1924       en             1
# 2            1925       en             1
# 3            1925       ru             1
# 4            1926       en             1
# ..            ...      ...           ...
# 343          2017       en            35
# 344          2017       es             2
# 345          2017       fr             1
# 346          2017       ru             1
# 347          2017       ta             1
#
# [348 rows x 3 columns]

# %%
imdb.groupby(['year','original_language'],as_index = False).agg({'imdb_id':'count','budget':'mean','revenue':'mean'}).rename(
columns = {'year':'Release_year','original_language':'language','imdb_id':'count_movies','budget':'investment', 'revenue':
'returns'}).reset_index(drop = 'index').sort_values(by = ['Release_year', 'language'],ascending = False).reset_index(drop = 'index')
# Out:
#      Release_year language  count_movies    investment       returns
# 0            2017       ta             1  0.000000e+00  1.700000e+07
# 1            2017       ru             1  7.075038e+06  9.868942e+06
# 2            2017       fr             1  0.000000e+00  7.800000e+06
# 3            2017       es             2  2.000000e+06  3.220000e+06
# 4            2017       en            35  6.004334e+07  2.061442e+08
# ..            ...      ...           ...           ...           ...
# 343          1926       en             1  4.634550e+05  9.668780e+05
# 344          1925       ru             1  0.000000e+00  4.510000e+04
# 345          1925       en             1  5.920000e+02  1.000000e+00
# 346          1924       en             1  1.135654e+06  1.213880e+06
# 347          1921       en             1  2.500000e+05  2.500000e+06
#
# [348 rows x 5 columns]

# %%
eval(df.genres[0])[0]
# Out:
# {'id': 35, 'name': 'Comedy'}

# %%
imdb.apply(lambda x : eval(df.)  )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [270], in <cell line: 1>()
# ----> 1 imdb.apply(lambda x: eval(x.genres)[0],axis = 1)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:8839, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8828 from pandas.core.apply import frame_apply
#    8830 op = frame_apply(
#    8831     self,
#    8832     func=func,
#    (...)
#    8837     kwargs=kwargs,
#    8838 )
# -> 8839 return op.apply().__finalize__(self, method="apply")
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py:727, in FrameApply.apply(self)
#     724 elif self.raw:
#     725     return self.apply_raw()
# --> 727 return self.apply_standard()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py:851, in FrameApply.apply_standard(self)
#     850 def apply_standard(self):
# ...

# %%
gen=imdb['genres'][:5]
print(gen)
# Out:
# 0                       [{'id': 35, 'name': 'Comedy'}]
# 1    [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                        [{'id': 18, 'name': 'Drama'}]
# 3    [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4    [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# Name: genres, dtype: object

# %%
for i in gen:
    #print(i)
    for j in eval(i):
        print(j['name'])
# Out:
# Comedy
# Comedy
# Drama
# Family
# Romance
# Drama
# Thriller
# Drama
# Action
# Thriller

# %%
l = [[1,2,3],[3,4,5],[6,7,8]]

# %%
for i in l:
    for j in i:
        print(j)
# Out:
# 1
# 2
# 3
# 3
# 4
# 5
# 6
# 7
# 8

# %%
imdb.cast[0]
# Out:
# "[{'cast_id': 4, 'character': 'Lou', 'credit_id': '52fe4ee7c3a36847f82afae7', 'gender': 2, 'id': 52997, 'name': 'Rob Corddry', 'order': 0, 'profile_path': '/k2zJL0V1nEZuFT08xUdOd3ucfXz.jpg'}, {'cast_id': 5, 'character': 'Nick', 'credit_id': '52fe4ee7c3a36847f82afaeb', 'gender': 2, 'id': 64342, 'name': 'Craig Robinson', 'order': 1, 'profile_path': '/tVaRMkJXOEVhYxtnnFuhqW0Rjzz.jpg'}, {'cast_id': 6, 'character': 'Jacob', 'credit_id': '52fe4ee7c3a36847f82afaef', 'gender': 2, 'id': 54729, 'name': 'Clark Duke', 'order': 2, 'profile_path': '/oNzK0umwm5Wn0wyEbOy6TVJCSBn.jpg'}, {'cast_id': 7, 'character': 'Adam Jr.', 'credit_id': '52fe4ee7c3a36847f82afaf3', 'gender': 2, 'id': 36801, 'name': 'Adam Scott', 'order': 3, 'profile_path': '/5gb65xz8bzd42yjMAl4zwo4cvKw.jpg'}, {'cast_id': 8, 'character': 'Hot Tub Repairman', 'credit_id': '52fe4ee7c3a36847f82afaf7', 'gender': 2, 'id': 54812, 'name': 'Chevy Chase', 'order': 4, 'profile_path': '/svjpyYtPwtjvRxX9IZnOmOkhDOt.jpg'}, {'cast_id': 9, 'charact
# ...

# %%
import numpy as np
import pandas as pd

# %%
data1 = pd.DataFrame({'roll no.':[1,2,3,4],'name':['a','b','c','d'],'eng_marks':[22,25,27,29]})

# %%
data1
# Out:
#    roll no. name  eng_marks
# 0         1    a         22
# 1         2    b         25
# 2         3    c         27
# 3         4    d         29

# %%
data2 = pd.DataFrame({'roll no.':[7,8,9,10,11,12],'name':['g','h','i','j','k','l'],'eng_marks':[15,16,19,11,18,13]})

# %%
data2
# Out:
#    roll no. name  eng_marks
# 0         7    g         15
# 1         8    h         16
# 2         9    i         19
# 3        10    j         11
# 4        11    k         18
# 5        12    l         13

# %%
pd.concat([data1,data2],axis = 1)
# Out:
#    roll no. name  eng_marks  roll no. name  eng_marks
# 0       1.0    a       22.0         7    g         15
# 1       2.0    b       25.0         8    h         16
# 2       3.0    c       27.0         9    i         19
# 3       4.0    d       29.0        10    j         11
# 4       NaN  NaN        NaN        11    k         18
# 5       NaN  NaN        NaN        12    l         13
