# %%
import numpy as np 
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\Deepu\\Documents\\My_Python_codes'

# %%
cd C:\\Users\\Deepu\\Downloads
# Out:
# C:\Users\Deepu\Downloads

# %%
imdb_df = pd.read_csv('imdb_data.csv')

# %%
imdb_df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %% [markdown]
# # Which are the movies with the third-lowest and third-highest budget?

# %%
#lets first check if the budget has null values of not
imdb_df.budget.isnull().sum()
# Out:
# 0

# %%
# Lets check if the budget has value 0
imdb_df.budget == 0
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 2995     True
# 2996     True
# 2997    False
# 2998    False
# 2999    False
# Name: budget, Length: 3000, dtype: bool

# %%
zero_budget_df=imdb_df[imdb_df.budget == 0]
zero_budget_df
# Out:
#         id                              belongs_to_collection  budget  \
# 4        5                                                NaN       0
# 7        8                                                NaN       0
# 8        9  [{'id': 256377, 'name': 'The Muppet Collection...       0
# 11      12  [{'id': 48190, 'name': 'Revenge of the Nerds C...       0
# 17      18                                                NaN       0
# ...    ...                                                ...     ...
# 2989  2990                                                NaN       0
# 2990  2991                                                NaN       0
# 2994  2995                                                NaN       0
# 2995  2996                                                NaN       0
# 2996  2997                                                NaN       0
#
#                                                  genres homepage    imdb_id  \
# ...

# %%
zero_budget_df.revenue
# Out:
# 4        3923970
# 7        2586511
# 8       34327391
# 11      22642033
# 17       1234254
#           ...
# 2989      100202
# 2990     7240837
# 2994    14715067
# 2995     1596687
# 2996      180590
# Name: revenue, Length: 812, dtype: int64

# %%
imdb_df[imdb_df.budget == 1] # it also has 1, The lectures has take it to be true value as proceeded we will follow his way and
# than do it our way as well
# Out:
#         id belongs_to_collection  budget  \
# 334    335                   NaN       1
# 695    696                   NaN       1
# 849    850                   NaN       1
# 1346  1347                   NaN       1
# 2255  2256                   NaN       1
#
#                                                  genres homepage    imdb_id  \
# 334   [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...      NaN  tt0376144
# 695   [{'id': 10749, 'name': 'Romance'}, {'id': 53, ...      NaN  tt0374271
# 849   [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...      NaN  tt0027977
# 1346                      [{'id': 18, 'name': 'Drama'}]      NaN  tt0048028
# 2255  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...      NaN  tt0120836
#
#      original_language original_title  \
# 334                 ta          Saamy
# 695                 hi      Tere Naam
# 849                 en   Modern Times
# 1346                en   East of Eden
# 2255                en   Lost & Found
#
# ...

# %%
# Now we know that the budget columns has zero, 1 and 2 in the list so we are taking the 0 as error values and trating 1,2 as 
# face vales and not doing any thing

# %%
# lets replace the 0 budget with mean of budget

# %%
zero_budget_df
# Out:
#         id                              belongs_to_collection  budget  \
# 4        5                                                NaN       0
# 7        8                                                NaN       0
# 8        9  [{'id': 256377, 'name': 'The Muppet Collection...       0
# 11      12  [{'id': 48190, 'name': 'Revenge of the Nerds C...       0
# 17      18                                                NaN       0
# ...    ...                                                ...     ...
# 2989  2990                                                NaN       0
# 2990  2991                                                NaN       0
# 2994  2995                                                NaN       0
# 2995  2996                                                NaN       0
# 2996  2997                                                NaN       0
#
#                                                  genres homepage    imdb_id  \
# ...

# %%
imdb_df.budget.mean()
# Out:
# 22531334.11

# %%
lis.index(0)
# Out:
# 6

# %% [markdown]
# ### The below line of code basically replaces all the 0 values with mean of the list

# %% [markdown]
# ### This is highly not recommended as ti has a very bad spacetime complexity

# %%
lis = [7,2,5,6,7,9,0,0,0,0,4,5,1]
indi = []

# create a loop to get the index of all the zero values in the list
c = -1
for z in range(len(lis)):
    if lis[z] == 0:
        indi.append(z)
#print(indi)        

# using the index created to repalce the zero with mean and then rounding off the mean and converting it to int
for i in lis:
    if i == 0:
        #print(i)
        c = c + 1
        lis[indi[c]] = sum(lis)/len(lis)
        #print(lis[indi[c]])
        # print(indi[c])
        mean = int(round(lis[indi[c]],2))
        #print(mean)
        for c in indi:
            lis[c] = mean
            #print(lis[c])            
print(lis)
# Out:
# [7, 2, 5, 6, 7, 9, 3, 3, 3, 3, 4, 5, 1]

# %%
zero_budget_df.budget.replace(0,np.nan)
# Out:
# 4      NaN
# 7      NaN
# 8      NaN
# 11     NaN
# 17     NaN
#         ..
# 2989   NaN
# 2990   NaN
# 2994   NaN
# 2995   NaN
# 2996   NaN
# Name: budget, Length: 812, dtype: float64

# %%
zero_budget_df.fillna(np.nan,zero_budget_df.mean)
# Out:
# C:\Users\Deepu\AppData\Local\Temp\ipykernel_14616\886263773.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.fillna except for the argument 'value' will be keyword-only.
#   zero_budget_df.fillna(np.nan,zero_budget_df.mean)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [93], in <cell line: 1>()
# ----> 1 zero_budget_df.fillna(np.nan,zero_budget_df.mean)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...
