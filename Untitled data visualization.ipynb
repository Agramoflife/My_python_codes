# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %magic

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
pwd
# Out:
# 'C:\\Users\\Deepu\\Documents\\My_Python_codes'

# %%
cd C:\\Users\\Deepu\\Downloads
# Out:
# C:\Users\Deepu\Downloads

# %%
df_p = pd.read_csv('pp-2018.csv')

# %%
df_p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1024431 entries, 0 to 1024430
# Data columns (total 16 columns):
#  #   Column                                  Non-Null Count    Dtype
# ---  ------                                  --------------    -----
#  0   {666758D7-43A9-3363-E053-6B04A8C0D74E}  1024431 non-null  object
#  1   405000                                  1024431 non-null  int64
#  2   2018-01-25 00:00                        1024431 non-null  object
#  3   WR15 8LH                                1018506 non-null  object
#  4   D                                       1024431 non-null  object
#  5   N                                       1024431 non-null  object
#  6   F                                       1024431 non-null  object
#  7   RAMBLERS WAY                            1024431 non-null  object
#  8   Unnamed: 8                              140446 non-null   object
#  9   Unnamed: 9                              1004772 non-null  object
# ...

# %%
df = pd.read_csv(path + 'pp-2018.csv', names = ["TID","Price","Sale Date", "Postcode",
                                    "Property Type","New Build","Tenure",
                                    "PAON","SAON","Street","Locality",
                                    "Town/City","District","County",
                                    "PPD Category","Record Status"],
                            parse_dates= ["Sale Date"])

# %%
path = 'pp-2018.csv'
df = pd.read_csv(path, names = ["TID","Price","Sale Date","Postcode","Property Type","New Build","Tenure","PAON","SAON","Street"
                              ,"Locality","Town/City","District","County","PPD Category","Record Status"],
                                parse_dates = ["Sale Date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1024432 entries, 0 to 1024431
# Data columns (total 16 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   TID            1024432 non-null  object
#  1   Price          1024432 non-null  int64
#  2   Sale Date      1024432 non-null  datetime64[ns]
#  3   Postcode       1018507 non-null  object
#  4   Property Type  1024432 non-null  object
#  5   New Build      1024432 non-null  object
#  6   Tenure         1024432 non-null  object
#  7   PAON           1024432 non-null  object
#  8   SAON           140446 non-null   object
#  9   Street         1004772 non-null  object
#  10  Locality       386023 non-null   object
#  11  Town/City      1024432 non-null  object
#  12  District       1024428 non-null  object
#  13  County         1024432 non-null  object
#  14  PPD Category   1024432 non-null  object
#  15  Record Status  1024432 non-null  object
# ...

# %%
df['Sale Date'].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# # lets do a basic plot first

# %%
y = x**2 + 1

# %%
x=np.linspace(-10,10,100)
y = x**2 + 1

# %%
print(y)
# Out:
# [101.          97.00040812  93.08244057  89.24609734  85.49137843
#   81.81828385  78.22681359  74.71696766  71.28874605  67.94214876
#   64.6771758   61.49382716  58.39210285  55.37200286  52.43352719
#   49.57667585  46.80144883  44.10784614  41.49586777  38.96551372
#   36.516784    34.1496786   31.86419753  29.66034078  27.53810836
#   25.49750026  23.53851648  21.66115702  19.8654219   18.15131109
#   16.51882461  14.96796245  13.49872462  12.11111111  10.80512193
#    9.58075707   8.43801653   7.37690032   6.39740843   5.49954086
#    4.68329762   3.94867871   3.29568411   2.72431385   2.2345679
#    1.82644628   1.49994898   1.25507601   1.09182736   1.01020304
#    1.01020304   1.09182736   1.25507601   1.49994898   1.82644628
#    2.2345679    2.72431385   3.29568411   3.94867871   4.68329762
#    5.49954086   6.39740843   7.37690032   8.43801653   9.58075707
#   10.80512193  12.11111111  13.49872462  14.96796245  16.51882461
# ...

# %%
print(x)
# Out:
# [-10.          -9.7979798   -9.5959596   -9.39393939  -9.19191919
#   -8.98989899  -8.78787879  -8.58585859  -8.38383838  -8.18181818
#   -7.97979798  -7.77777778  -7.57575758  -7.37373737  -7.17171717
#   -6.96969697  -6.76767677  -6.56565657  -6.36363636  -6.16161616
#   -5.95959596  -5.75757576  -5.55555556  -5.35353535  -5.15151515
#   -4.94949495  -4.74747475  -4.54545455  -4.34343434  -4.14141414
#   -3.93939394  -3.73737374  -3.53535354  -3.33333333  -3.13131313
#   -2.92929293  -2.72727273  -2.52525253  -2.32323232  -2.12121212
#   -1.91919192  -1.71717172  -1.51515152  -1.31313131  -1.11111111
#   -0.90909091  -0.70707071  -0.50505051  -0.3030303   -0.1010101
#    0.1010101    0.3030303    0.50505051   0.70707071   0.90909091
#    1.11111111   1.31313131   1.51515152   1.71717172   1.91919192
#    2.12121212   2.32323232   2.52525253   2.72727273   2.92929293
#    3.13131313   3.33333333   3.53535354   3.73737374   3.93939394
# ...

# %%
# lets choose the size of the plot first
plt.figure(figsize = (6,4))

#plot the graph
plt.plot(x,y)

# label the axis 
plt.xlabel('x axis')
plt.ylabel('y axis')

# give a title to the graph
plt.title('Parabola')

# use this for good practise 
plt.show()

# %% [markdown]
# First objective : Obtain the trend of sales volume across months

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1024432 entries, 0 to 1024431
# Data columns (total 16 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   TID            1024432 non-null  object
#  1   Price          1024432 non-null  int64
#  2   Sale Date      1024432 non-null  datetime64[ns]
#  3   Postcode       1018507 non-null  object
#  4   Property Tye   1024432 non-null  object
#  5   New Build      1024432 non-null  object
#  6   Tenure         1024432 non-null  object
#  7   PAON           1024432 non-null  object
#  8   SAON           140446 non-null   object
#  9   Street         1004772 non-null  object
#  10  Locality       386023 non-null   object
#  11  Town/City      1024432 non-null  object
#  12  District       1024428 non-null  object
#  13  County         1024432 non-null  object
#  14  PPD Category   1024432 non-null  object
#  15  Record Status  1024432 non-null  object
# ...

# %%
df['Sale Date'][0].year
# Out:
# 2018

# %%
df['month']=df['Sale Date'].apply(lambda x: x.month)

# %%
df.groupby('month')['Price'].count()
# Out:
# month
# 1      70031
# 2      71579
# 3      84172
# 4      72322
# 5      81458
# 6      95790
# 7      88674
# 8     101485
# 9      82845
# 10     92577
# 11     98532
# 12     84967
# Name: Price, dtype: int64

# %%
plt.figure(figsize = (8,6))
plt.plot(df.groupby('month')['Price'].count())
plt.xlabel('month')
plt.ylabel('no. of sales')
plt.show()

# %%
df['Record Status'].value_counts()
# Out:
# A    1024432
# Name: Record Status, dtype: int64

# %%
df[df['Record Status'] == 'A']
# Out:
#                                             TID   Price  Sale Date  Postcode  \
# 0        {666758D7-43A9-3363-E053-6B04A8C0D74E}  405000 2018-01-25  WR15 8LH
# 1        {666758D7-43AA-3363-E053-6B04A8C0D74E}  315000 2018-01-23   SY7 8QA
# 2        {666758D7-43AD-3363-E053-6B04A8C0D74E}  165000 2018-01-19   SY1 2BF
# 3        {666758D7-43B0-3363-E053-6B04A8C0D74E}  370000 2018-01-22   SY8 4DF
# 4        {666758D7-43B3-3363-E053-6B04A8C0D74E}  320000 2018-01-19  TF10 7ET
# ...                                         ...     ...        ...       ...
# 1024427  {80E1AA98-9F64-7BF8-E053-6C04A8C00BF2}  382500 2018-12-10  BN22 0NF
# 1024428  {80E1AA98-9F67-7BF8-E053-6C04A8C00BF2}  394000 2018-12-20  BN16 2QE
# 1024429  {80E1AA98-9F69-7BF8-E053-6C04A8C00BF2}  350000 2018-12-14  RH12 2AG
# 1024430  {80E1AA98-9F6A-7BF8-E053-6C04A8C00BF2}  346000 2018-12-07  RH10 3AP
# 1024431  {80E1AA98-9F6B-7BF8-E053-6C04A8C00BF2}  348000 2018-12-11  BN13 3DY
#
# ...

# %%
df = df[df['Record Status'] == 'A']

# %%
df = df.loc[df['Record Status']=='A']

# %%
df['Property Type'].value_counts()
# Out:
# T    274610
# S    268026
# D    233324
# F    183043
# O     65429
# Name: Property Type, dtype: int64

# %%
df=df.loc[(df['Property Type'] != 'O')]

# %%
df=df.loc[(df['Sale Date'].dt.year == 2018)]

# %%
df
# Out:
#                                             TID   Price  Sale Date  Postcode  \
# 0        {666758D7-43A9-3363-E053-6B04A8C0D74E}  405000 2018-01-25  WR15 8LH
# 1        {666758D7-43AA-3363-E053-6B04A8C0D74E}  315000 2018-01-23   SY7 8QA
# 2        {666758D7-43AD-3363-E053-6B04A8C0D74E}  165000 2018-01-19   SY1 2BF
# 3        {666758D7-43B0-3363-E053-6B04A8C0D74E}  370000 2018-01-22   SY8 4DF
# 4        {666758D7-43B3-3363-E053-6B04A8C0D74E}  320000 2018-01-19  TF10 7ET
# ...                                         ...     ...        ...       ...
# 1024427  {80E1AA98-9F64-7BF8-E053-6C04A8C00BF2}  382500 2018-12-10  BN22 0NF
# 1024428  {80E1AA98-9F67-7BF8-E053-6C04A8C00BF2}  394000 2018-12-20  BN16 2QE
# 1024429  {80E1AA98-9F69-7BF8-E053-6C04A8C00BF2}  350000 2018-12-14  RH12 2AG
# 1024430  {80E1AA98-9F6A-7BF8-E053-6C04A8C00BF2}  346000 2018-12-07  RH10 3AP
# 1024431  {80E1AA98-9F6B-7BF8-E053-6C04A8C00BF2}  348000 2018-12-11  BN13 3DY
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 959003 entries, 0 to 1024431
# Data columns (total 16 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   TID            959003 non-null  object
#  1   Price          959003 non-null  int64
#  2   Sale Date      959003 non-null  datetime64[ns]
#  3   Postcode       958301 non-null  object
#  4   Property Type  959003 non-null  object
#  5   New Build      959003 non-null  object
#  6   Tenure         959003 non-null  object
#  7   PAON           959003 non-null  object
#  8   SAON           127930 non-null  object
#  9   Street         945361 non-null  object
#  10  Locality       359120 non-null  object
#  11  Town/City      959003 non-null  object
#  12  District       959001 non-null  object
#  13  County         959003 non-null  object
#  14  PPD Category   959003 non-null  object
#  15  Record Status  959003 non-null  object
# ...

# %%
plt.plot(df.groupby(df['Sale Date'].dt.month)['Price'].count())

# %%
print(df['Sale Date'].dt.month.value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of 0           1
# 1           1
# 2           1
# 3           1
# 4           1
#            ..
# 1024427    12
# 1024428    12
# 1024429    12
# 1024430    12
# 1024431    12
# Name: Sale Date, Length: 1024432, dtype: int64>

# %%
 df['Record Status'].value_counts()
# Out:
# A    1024432
# Name: Record Status, dtype: int64

# %%
df=df.loc[df['Record Status'] == 'A']

# %%
df=df.loc[df['Property Type'] != 'O']

# %%
df.shape
# Out:
# (959003, 16)

# %%
df.shape

# %%
df=df.loc[df['Record Status'] == 'A']

# %%
df = df.loc[df['Property Type'] != 'O']

# %%
df
# Out:
#                                             TID   Price  Sale Date  Postcode  \
# 0        {666758D7-43A9-3363-E053-6B04A8C0D74E}  405000 2018-01-25  WR15 8LH
# 1        {666758D7-43AA-3363-E053-6B04A8C0D74E}  315000 2018-01-23   SY7 8QA
# 2        {666758D7-43AD-3363-E053-6B04A8C0D74E}  165000 2018-01-19   SY1 2BF
# 3        {666758D7-43B0-3363-E053-6B04A8C0D74E}  370000 2018-01-22   SY8 4DF
# 4        {666758D7-43B3-3363-E053-6B04A8C0D74E}  320000 2018-01-19  TF10 7ET
# ...                                         ...     ...        ...       ...
# 1024427  {80E1AA98-9F64-7BF8-E053-6C04A8C00BF2}  382500 2018-12-10  BN22 0NF
# 1024428  {80E1AA98-9F67-7BF8-E053-6C04A8C00BF2}  394000 2018-12-20  BN16 2QE
# 1024429  {80E1AA98-9F69-7BF8-E053-6C04A8C00BF2}  350000 2018-12-14  RH12 2AG
# 1024430  {80E1AA98-9F6A-7BF8-E053-6C04A8C00BF2}  346000 2018-12-07  RH10 3AP
# 1024431  {80E1AA98-9F6B-7BF8-E053-6C04A8C00BF2}  348000 2018-12-11  BN13 3DY
#
# ...

# %%
df['Sale Date'].dt.year
# Out:
# 0          2018
# 1          2018
# 2          2018
# 3          2018
# 4          2018
#            ...
# 1024427    2018
# 1024428    2018
# 1024429    2018
# 1024430    2018
# 1024431    2018
# Name: Sale Date, Length: 959003, dtype: int64

# %%
df['Sale Date'][0]
# Out:
# Timestamp('2018-01-25 00:00:00')

# %%
from datetime import datetime as dt

# %%
dt.strftime(df['Sale Date'][0],'%Y-%m-%d')[:7]
# Out:
# '2018-01'

# %%
df['Sale Date'].dt.month.dtype
# Out:
# dtype('int64')

# %%
df['month']=df.apply(lambda x: dt.strftime(x['Sale Date'],'%Y-%m-%d')[:7],axis = 1)

# %%
trends=df.month.value_counts().sort_index()

# %%
plt.figure(figsize = (10,5))
plt.plot(trends,color = 'green',label = 'monthly sales')
plt.title('2018 sales trend',color = 'blue')
plt.xlabel('months',color = 'green')
plt.ylabel('no. of sales', color = 'green')
plt.show()

# %%
#while we are doing this lets also go through the graph of a normal function

# %%
# this should go second
y = 2*x**2 + 1

# %%
# as per the control flow this should go first 
x = np.linspace(-10,10,100)

# %%
y = 2*x**2 + 1

# %%
plt.plot(x,y,color = 'red')
plt.show()

# %%
aug_trend=df[df['month'] == '2018-08']['Sale Date'].value_counts().sort_index()

# %%
plt.figure(figsize = (10,5))
plt.plot(aug_trend)
plt.show()

# %%
julytrend=df[df['Sale Date'].dt.month == 7]['Sale Date'].value_counts()

# %%
julytrend
# Out:
# 2018-07-27    11145
# 2018-07-20     8802
# 2018-07-06     8400
# 2018-07-13     6561
# 2018-07-31     5047
# 2018-07-12     3568
# 2018-07-30     3429
# 2018-07-26     2965
# 2018-07-02     2931
# 2018-07-16     2883
# 2018-07-23     2742
# 2018-07-25     2710
# 2018-07-19     2571
# 2018-07-18     2438
# 2018-07-05     2358
# 2018-07-09     2259
# 2018-07-11     2165
# 2018-07-24     2116
# 2018-07-04     2064
# 2018-07-10     1985
# 2018-07-17     1933
# 2018-07-03     1828
# 2018-07-28       31
# 2018-07-14       25
# 2018-07-29       25
# 2018-07-21       21
# 2018-07-15       20
# 2018-07-07       18
# 2018-07-01       18
# 2018-07-22       13
# 2018-07-08       11
# Name: Sale Date, dtype: int64

# %%
plt.figure(figsize = (10,5))
julytrend.plot(color = 'indigo')
plt.title('July sales data')
plt.ylabel('sales count')
plt.xlabel('days')
plt.show()

# %%
property_type=df.groupby(['Sale Date','Property Type'])['Price'].sum()

# %%
property_type=property_type.unstack()

# %%
plt.figure(figsize = (20,10))
plt.plot(property_type)

# %%
# lets do it for only july

# %%
property_type=df[df['Sale Date'].dt.month == 7][['Sale Date','Property Type']].value_counts().unstack()

# %%
plt.figure(figsize = (20,5))
plt.plot(property_type)
[plt.show()

# %%
july_df=df[df['Sale Date'].dt.month == 7]

# %%
july_df.groupby(['Property Type'])['Property Type'].count().plot()
# Out:
# <AxesSubplot:xlabel='Property Type'>

# %%
july_df['Property Type'].value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
barh=df[df['Sale Date'].dt.month == 7]['Property Type'].value_counts()

# %%
barh.plot(kind = 'hbar')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [214], in <cell line: 1>()
# ----> 1 barh.plot(kind = 'hbar')
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py:905, in PlotAccessor.__call__(self, *args, **kwargs)
#     902     return plot_backend.plot(self._parent, x=x, y=y, kind=kind, **kwargs)
#     904 if kind not in self._all_kinds:
# --> 905     raise ValueError(f"{kind} is not a valid plot kind")
#     907 # The original data structured can be transformed before passed to the
#     908 # backend. For example, for DataFrame is common to set the index as the
#     909 # `x` parameter, and return a Series with the parameter `y` as values.
#     910 data = self._parent.copy()
#
# ValueError: hbar is not a valid plot kind

# %%
p=july_df['Property Type'].value_counts()

# %%
p.plot(kind = 'hbar')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [220], in <cell line: 1>()
# ----> 1 p.plot(kind = 'hbar')
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py:905, in PlotAccessor.__call__(self, *args, **kwargs)
#     902     return plot_backend.plot(self._parent, x=x, y=y, kind=kind, **kwargs)
#     904 if kind not in self._all_kinds:
# --> 905     raise ValueError(f"{kind} is not a valid plot kind")
#     907 # The original data structured can be transformed before passed to the
#     908 # backend. For example, for DataFrame is common to set the index as the
#     909 # `x` parameter, and return a Series with the parameter `y` as values.
#     910 data = self._parent.copy()
#
# ValueError: hbar is not a valid plot kind

# %%
df['Sale Date']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 df['Sale Date']
#
# NameError: name 'df' is not defined

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1024432 entries, 0 to 1024431
# Data columns (total 16 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   TID            1024432 non-null  object
#  1   Price          1024432 non-null  int64
#  2   Sale Date      1024432 non-null  datetime64[ns]
#  3   Postcode       1018507 non-null  object
#  4   Property Type  1024432 non-null  object
#  5   New Build      1024432 non-null  object
#  6   Tenure         1024432 non-null  object
#  7   PAON           1024432 non-null  object
#  8   SAON           140446 non-null   object
#  9   Street         1004772 non-null  object
#  10  Locality       386023 non-null   object
#  11  Town/City      1024432 non-null  object
#  12  District       1024428 non-null  object
#  13  County         1024432 non-null  object
#  14  PPD Category   1024432 non-null  object
#  15  Record Status  1024432 non-null  object
# ...

# %%
df=df[df['Record Status'] == "A"]

# %%
df=df.loc[df['Property Type'] != 'O']

# %%
df.shape
# Out:
# (959003, 16)

# %%
from datetime import datetime

# %%
df['month']=df['Sale Date'].apply(lambda x: datetime.strftime(x,'%Y-%m-%d')[0:7])

# %%
datetime.strftime(df['Sale Date'][0],'%Y-%m-%d')
# Out:
# '2018-01-25'

# %%
july_df=df.loc[df['month'] == '2018-07']

# %%
july_df['Sale Date'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 835       2018-07-20
# 1044      2018-07-27
# 1055      2018-07-30
# 1123      2018-07-25
# 1214      2018-07-26
#              ...
# 1024095   2018-07-30
# 1024231   2018-07-02
# 1024234   2018-07-20
# 1024267   2018-07-30
# 1024270   2018-07-20
# Name: Sale Date, Length: 83082, dtype: datetime64[ns]>

# %%
july_df.groupby('Property Type')['Sale Date'].count()
# Out:
# Property Type
# D    20406
# F    15545
# S    23501
# T    23630
# Name: Sale Date, dtype: int64

# %%
july_df['Property Type'].value_counts().plot(kind = 'bar',color = 'green')
# Out:
# <AxesSubplot:>

# %%
df.plot(barjuly,kind = 'bar')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [42], in <cell line: 1>()
# ----> 1 df.plot(barjuly,kind = 'bar')
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py:937, in PlotAccessor.__call__(self, *args, **kwargs)
#     935 if is_integer(x) and not data.columns.holds_integer():
#     936     x = data_cols[x]
# --> 937 elif not isinstance(data[x], ABCSeries):
#     938     raise ValueError("x must be a label or position")
#     939 data = data.set_index(x)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# ...

# %%
al=july_df.groupby(['Sale Date','Property Type']).agg({'Property Type': 'count'}).unstack()

# %%
plt.rcParams['figure.figsize'] = (10, 5)
plt.figure(figsize =(20,5))
al.plot()
plt.show()

# %%
july_df.groupby('Property Type')['Price'].mean().plot(kind = 'bar')
plt.title('Average Price of Property type in July',fontsize = 20)
plt.xlabel('Type',fontsize = '18')
plt.ylabel('Price',fontsize = '18')
plt.show()

# %%
plt.plot(july_df['Price'],kind = 'box')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [85], in <cell line: 1>()
# ----> 1 plt.plot(july_df['Price'],kind = 'box')
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py:2757, in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
#    1392
#    (...)
#    1629 (``'green'``) or hex strings (``'#008000'``).
#    1630 """
# ...

# %%
july_df['Price'].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
july_df.groupby(['Sale Date','Property Type'])['Price'].mean().unstack().plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
pwd
# Out:
# 'C:\\Users\\Deepu\\Downloads'

# %%
df = pd.read_csv('Speed Dating Data.csv',encoding = 'unicode_escape')

# %%
df
# Out:
#       iid    id  gender  idg  condtn  wave  round  position  positin1  order  \
# 0       1   1.0       0    1       1     1     10         7       NaN      4
# 1       1   1.0       0    1       1     1     10         7       NaN      3
# 2       1   1.0       0    1       1     1     10         7       NaN     10
# 3       1   1.0       0    1       1     1     10         7       NaN      5
# 4       1   1.0       0    1       1     1     10         7       NaN      7
# ...   ...   ...     ...  ...     ...   ...    ...       ...       ...    ...
# 8373  552  22.0       1   44       2    21     22        14      10.0      5
# 8374  552  22.0       1   44       2    21     22        13      10.0      4
# 8375  552  22.0       1   44       2    21     22        19      10.0     10
# 8376  552  22.0       1   44       2    21     22         3      10.0     16
# 8377  552   NaN       1   44       2    21     22         2      10.0     15
#
# ...

# %%
df.columns.values
# Out:
# array(['iid', 'id', 'gender', 'idg', 'condtn', 'wave', 'round',
#        'position', 'positin1', 'order', 'partner', 'pid', 'match',
#        'int_corr', 'samerace', 'age_o', 'race_o', 'pf_o_att', 'pf_o_sin',
#        'pf_o_int', 'pf_o_fun', 'pf_o_amb', 'pf_o_sha', 'dec_o', 'attr_o',
#        'sinc_o', 'intel_o', 'fun_o', 'amb_o', 'shar_o', 'like_o',
#        'prob_o', 'met_o', 'age', 'field', 'field_cd', 'undergra',
#        'mn_sat', 'tuition', 'race', 'imprace', 'imprelig', 'from',
#        'zipcode', 'income', 'goal', 'date', 'go_out', 'career',
#        'career_c', 'sports', 'tvsports', 'exercise', 'dining', 'museums',
#        'art', 'hiking', 'gaming', 'clubbing', 'reading', 'tv', 'theater',
#        'movies', 'concerts', 'music', 'shopping', 'yoga', 'exphappy',
#        'expnum', 'attr1_1', 'sinc1_1', 'intel1_1', 'fun1_1', 'amb1_1',
#        'shar1_1', 'attr4_1', 'sinc4_1', 'intel4_1', 'fun4_1', 'amb4_1',
# ...

# %%
df['age'].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
df.age.isnull().sum()
# Out:
# 95

# %%
df.age_o.isnull().sum()
# Out:
# 104

# %%
list(df.columns)
# Out:
# ['iid',
#  'id',
#  'gender',
#  'idg',
#  'condtn',
#  'wave',
#  'round',
#  'position',
#  'positin1',
#  'order',
#  'partner',
#  'pid',
#  'match',
#  'int_corr',
#  'samerace',
#  'age_o',
#  'race_o',
#  'pf_o_att',
#  'pf_o_sin',
#  'pf_o_int',
#  'pf_o_fun',
#  'pf_o_amb',
#  'pf_o_sha',
#  'dec_o',
#  'attr_o',
#  'sinc_o',
#  'intel_o',
#  'fun_o',
#  'amb_o',
#  'shar_o',
#  'like_o',
#  'prob_o',
#  'met_o',
#  'age',
#  'field',
#  'field_cd',
#  'undergra',
#  'mn_sat',
#  'tuition',
#  'race',
#  'imprace',
#  'imprelig',
#  'from',
#  'zipcode',
#  'income',
#  'goal',
#  'date',
#  'go_out',
#  'career',
#  'career_c',
#  'sports',
#  'tvsports',
#  'exercise',
#  'dining',
#  'museums',
#  'art',
#  'hiking',
#  'gaming',
#  'clubbing',
#  'reading',
#  'tv',
#  'theater',
#  'movies',
#  'concerts',
#  'music',
#  'shopping',
#  'yoga',
#  'exphappy',
#  'expnum',
#  'attr1_1',
#  'sinc1_1',
#  'intel1_1',
#  'fun1_1',
#  'amb1_1',
#  'shar1_1',
#  'attr4_1',
# ...

# %%
df.age.plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
plt.hist(df[df.age.notnull()]['age'],color = 'Green')

plt.title('Age distribution',size = '20')
plt.xlabel('age',size = '18')
plt.ylabel('frequency',size = '18')
plt.show()

# %%
sns.distplot(df.age,hist = True,color = 'Green')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
x = [1,2,3,4,5,6,7,8,9]
y = [1,2,3,4,5,6,7,8,9]

# %%
plt.plot(x,y)

# %%
sns.lmplot(data = pdf, x = 'X',y = 'Y')

# %%
pdf=pd.DataFrame({'X':x,'Y':y})

# %%
pdf.corr()
# Out:
#      X    Y
# X  1.0  1.0
# Y  1.0  1.0

# %%
sns.heatmap(pdf.corr())
# Out:
# <AxesSubplot:>

# %%
ndf = pd.DataFrame({'a':[1,2,3,4,5,6,7,8,9],'b':[9,8,7,6,5,4,3,2,1]})

# %%
sns.lmplot(data = ndf,x = 'a',y = 'b')

# %%
ndf.corr()
# Out:
#      a    b
# a  1.0 -1.0
# b -1.0  1.0

# %%
sns.heatmap(ndf.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(data = df[['gender','shopping','gaming','concerts','music']].corr())
# Out:
# <AxesSubplot:>

# %%
df[['gender','shopping','gaming','concerts','music']]
# Out:
#       gender  shopping  gaming  concerts  music
# 0          0       8.0     1.0      10.0    9.0
# 1          0       8.0     1.0      10.0    9.0
# 2          0       8.0     1.0      10.0    9.0
# 3          0       8.0     1.0      10.0    9.0
# 4          0       8.0     1.0      10.0    9.0
# ...      ...       ...     ...       ...    ...
# 8373       1       7.0     1.0      10.0   10.0
# 8374       1       7.0     1.0      10.0   10.0
# 8375       1       7.0     1.0      10.0   10.0
# 8376       1       7.0     1.0      10.0   10.0
# 8377       1       7.0     1.0      10.0   10.0
#
# [8378 rows x 5 columns]

# %%
plt.bar(x = ['a','b','c','d'], height = [11,22,33,55])
# Out:
# <BarContainer object of 4 artists>

# %%
sns.jointplot(x = 'X',y = 'Y',data = pdf)

# %%
dating_data_df = df[['gender', 'shopping', 'gaming', 'concerts', 'music']]

# %%
dating_data_df.corr()
# Out:
#             gender  shopping    gaming  concerts     music
# gender    1.000000 -0.330718  0.219619 -0.128339 -0.076850
# shopping -0.330718  1.000000  0.093467  0.205389  0.208329
# gaming    0.219619  0.093467  1.000000  0.098806  0.043301
# concerts -0.128339  0.205389  0.098806  1.000000  0.655728
# music    -0.076850  0.208329  0.043301  0.655728  1.000000

# %%
dating_data_df.head()
# Out:
#    gender  shopping  gaming  concerts  music
# 0       0       8.0     1.0      10.0    9.0
# 1       0       8.0     1.0      10.0    9.0
# 2       0       8.0     1.0      10.0    9.0
# 3       0       8.0     1.0      10.0    9.0
# 4       0       8.0     1.0      10.0    9.0

# %%
pwd
# Out:
# 'C:\\Users\\Deepu\\Documents\\My_Python_codes'

# %%
cd C:\\Users\\Deepu\\Downloads
# Out:
# C:\Users\Deepu\Downloads

# %%
df = pd.read_csv('pp-2018.csv', names = ["TID","Price","Sale Date", "Postcode",
                                    "Property Type","New Build","Tenure",
                                    "PAON","SAON","Street","Locality",
                                    "Town/City","District","County",
                                    "PPD Category","Record Status"],
                            parse_dates= ["Sale Date"])

# %%
df
# Out:
#                                             TID   Price  Sale Date  Postcode  \
# 0        {666758D7-43A9-3363-E053-6B04A8C0D74E}  405000 2018-01-25  WR15 8LH
# 1        {666758D7-43AA-3363-E053-6B04A8C0D74E}  315000 2018-01-23   SY7 8QA
# 2        {666758D7-43AD-3363-E053-6B04A8C0D74E}  165000 2018-01-19   SY1 2BF
# 3        {666758D7-43B0-3363-E053-6B04A8C0D74E}  370000 2018-01-22   SY8 4DF
# 4        {666758D7-43B3-3363-E053-6B04A8C0D74E}  320000 2018-01-19  TF10 7ET
# ...                                         ...     ...        ...       ...
# 1024427  {80E1AA98-9F64-7BF8-E053-6C04A8C00BF2}  382500 2018-12-10  BN22 0NF
# 1024428  {80E1AA98-9F67-7BF8-E053-6C04A8C00BF2}  394000 2018-12-20  BN16 2QE
# 1024429  {80E1AA98-9F69-7BF8-E053-6C04A8C00BF2}  350000 2018-12-14  RH12 2AG
# 1024430  {80E1AA98-9F6A-7BF8-E053-6C04A8C00BF2}  346000 2018-12-07  RH10 3AP
# 1024431  {80E1AA98-9F6B-7BF8-E053-6C04A8C00BF2}  348000 2018-12-11  BN13 3DY
#
# ...

# %%
df.columns
# Out:
# Index(['TID', 'Price', 'Sale Date', 'Postcode', 'Property Type', 'New Build',
#        'Tenure', 'PAON', 'SAON', 'Street', 'Locality', 'Town/City', 'District',
#        'County', 'PPD Category', 'Record Status'],
#       dtype='object')

# %%
df = pd.read_csv('company_sales_data.csv')

# %%
df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df[['month_number','total_profit']].plot()
# Out:
# <AxesSubplot:>

# %%
df[['month_number','total_profit']]
# Out:
#     month_number  total_profit
# 0              1        211000
# 1              2        183300
# 2              3        224700
# 3              4        222700
# 4              5        209600
# 5              6        201400
# 6              7        295500
# 7              8        361400
# 8              9        234000
# 9             10        266700
# 10            11        412800
# 11            12        300200

# %%
sale_by_month=df.groupby('month_number')['total_profit'].sum().sort_index()

# %%
plt.figure(figsize = (8,6))
plt.plot(sale_by_month,color = 'red')
plt.title('profit distribution',color = 'blue',size = 15)
plt.xlabel('month',size = 12)
plt.ylabel('profit',size = 12)
plt.show()

# %%
df[['facecream','facewash','total_profit']]
# Out:
#     facecream  facewash  total_profit
# 0        2500      1500        211000
# 1        2630      1200        183300
# 2        2140      1340        224700
# 3        3400      1130        222700
# 4        3600      1740        209600
# 5        2760      1555        201400
# 6        2980      1120        295500
# 7        3700      1400        361400
# 8        3540      1780        234000
# 9        1990      1890        266700
# 10       2340      2100        412800
# 11       2900      1760        300200

# %%
plt.rcParams['figure.figsize'] = (10,5)
df.groupby('month_number').agg({'facecream':'sum','facewash':'sum'}).plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='month_number'>

# %%
df.columns
# Out:
# Index(['month_number', 'facecream', 'facewash', 'toothpaste', 'bathingsoap',
#        'shampoo', 'moisturizer', 'total_units', 'total_profit'],
#       dtype='object')

# %%
products=df.groupby('month_number').agg({'facecream':'sum','facewash':'sum','toothpaste':'sum','bathingsoap':'sum','shampoo':'sum','moisturizer':'sum'})

# %%
#plt.rcParams['figure.figsize'] = (10, 5)
plt.rcParams['figure.figsize'] = (20,10)
products.plot()
plt.show()
