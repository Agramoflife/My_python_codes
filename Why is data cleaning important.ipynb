# %%
import numpy as np 
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\Deepu\\Documents\\My_Python_codes'

# %%
cd C:\\Users\\Deepu\\Downloads
# Out:
# C:\Users\Deepu\Downloads

# %%
df = pd.read_csv('Speed Dating Data.csv',encoding = 'unicode_escape')

# %%
df
# Out:
#       iid    id  gender  idg  condtn  wave  round  position  positin1  order  \
# 0       1   1.0       0    1       1     1     10         7       NaN      4
# 1       1   1.0       0    1       1     1     10         7       NaN      3
# 2       1   1.0       0    1       1     1     10         7       NaN     10
# 3       1   1.0       0    1       1     1     10         7       NaN      5
# 4       1   1.0       0    1       1     1     10         7       NaN      7
# ...   ...   ...     ...  ...     ...   ...    ...       ...       ...    ...
# 8373  552  22.0       1   44       2    21     22        14      10.0      5
# 8374  552  22.0       1   44       2    21     22        13      10.0      4
# 8375  552  22.0       1   44       2    21     22        19      10.0     10
# 8376  552  22.0       1   44       2    21     22         3      10.0     16
# 8377  552   NaN       1   44       2    21     22         2      10.0     15
#
# ...

# %%
print(df.income.dtype)
# Out:
# object

# %%
stringed = '12,3433'
c = -1
for i in stringed:
    c+=1
    if i == ',':
        cat = stringed[:c] + stringed[c+1:]
        floated = float(cat)
print(floated)
# Out:
# 123433.0

# %%
def strval(stringed):
    c = -1
    for i in stringed:
        c += 1
        if i == ',':
            cat = stringed[:c] + stringed[c+1:]
            floated = float(cat)
    return floated

# %%
strval('23,456')
# Out:
# 23456.0

# %%
df.apply(lambda x: strval(x.income),axis = 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 df.apply(lambda x: strval(x.income),axis = 1)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:8839, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8828 from pandas.core.apply import frame_apply
#    8830 op = frame_apply(
#    8831     self,
#    8832     func=func,
#    (...)
#    8837     kwargs=kwargs,
#    8838 )
# -> 8839 return op.apply().__finalize__(self, method="apply")
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py:727, in FrameApply.apply(self)
#     724 elif self.raw:
#     725     return self.apply_raw()
# --> 727 return self.apply_standard()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py:851, in FrameApply.apply_standard(self)
#     850 def apply_standard(self):
# ...

# %%
df.income.isnull().sum()
# Out:
# 4099

# %%
df.income.notnull().sum()
# Out:
# 4279

# %%
(~df.income.isnull()).sum()
# Out:
# 4279

# %%
df_non_null_income=df[(~df.income.isnull())]

# %%
df_non_null_income
# Out:
#       iid    id  gender  idg  condtn  wave  round  position  positin1  order  \
# 0       1   1.0       0    1       1     1     10         7       NaN      4
# 1       1   1.0       0    1       1     1     10         7       NaN      3
# 2       1   1.0       0    1       1     1     10         7       NaN     10
# 3       1   1.0       0    1       1     1     10         7       NaN      5
# 4       1   1.0       0    1       1     1     10         7       NaN      7
# ...   ...   ...     ...  ...     ...   ...    ...       ...       ...    ...
# 8351  551  21.0       1   42       2    21     22        14      21.0     16
# 8352  551  21.0       1   42       2    21     22        13      21.0     15
# 8353  551  21.0       1   42       2    21     22        19      21.0     21
# 8354  551  21.0       1   42       2    21     22         3      21.0      5
# 8355  551  21.0       1   42       2    21     22         2      21.0      4
#
# ...

# %%
df_non_null_income.apply(lambda x: strval(x.income),axis = 1)
# Out:
# 0       69487.0
# 1       69487.0
# 2       69487.0
# 3       69487.0
# 4       69487.0
#          ...
# 8351    55138.0
# 8352    55138.0
# 8353    55138.0
# 8354    55138.0
# 8355    55138.0
# Length: 4279, dtype: float64
