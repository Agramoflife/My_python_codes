# %%
import numpy as np
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\Deepu\\Documents\\My_Python_codes'

# %%
cd C:\\Users\\Deepu\\Downloads
# Out:
# C:\Users\Deepu\Downloads

# %%
df=pd.read_csv('imdb_data.csv')

# %%
display(df)
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
df.shape
# Out:
# (3000, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
df.describe()
# Out:
#                 id        budget   popularity      runtime       revenue
# count  3000.000000  3.000000e+03  3000.000000  2998.000000  3.000000e+03
# mean   1500.500000  2.253133e+07     8.463274   107.856571  6.672585e+07
# std     866.169729  3.702609e+07    12.104000    22.086434  1.375323e+08
# min       1.000000  0.000000e+00     0.000001     0.000000  1.000000e+00
# 25%     750.750000  0.000000e+00     4.018053    94.000000  2.379808e+06
# 50%    1500.500000  8.000000e+06     7.374861   104.000000  1.680707e+07
# 75%    2250.250000  2.900000e+07    10.890983   118.000000  6.891920e+07
# max    3000.000000  3.800000e+08   294.337037   338.000000  1.519558e+09

# %%
df.head(5)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
df.iloc[0:2,0:]
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
#
#                                               genres homepage    imdb_id  \
# 0                     [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      NaN  tt0368933
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
#
#   release_date runtime                          spoken_languages    status  \
# ...

# %%
df.loc[0:2,['id','budget']]
# Out:
#    id    budget
# 0   1  14000000
# 1   2  40000000
# 2   3   3300000

# %%
df.loc[0:,'budget']
# Out:
# 0       14000000
# 1       40000000
# 2        3300000
# 3        1200000
# 4              0
#           ...
# 2995           0
# 2996           0
# 2997    65000000
# 2998    42000000
# 2999    35000000
# Name: budget, Length: 3000, dtype: int64

# %%
df.iloc[0:,2]
# Out:
# 0       14000000
# 1       40000000
# 2        3300000
# 3        1200000
# 4              0
#           ...
# 2995           0
# 2996           0
# 2997    65000000
# 2998    42000000
# 2999    35000000
# Name: budget, Length: 3000, dtype: int64

# %%
df['budget']
# Out:
# 0       14000000
# 1       40000000
# 2        3300000
# 3        1200000
# 4              0
#           ...
# 2995           0
# 2996           0
# 2997    65000000
# 2998    42000000
# 2999    35000000
# Name: budget, Length: 3000, dtype: int64

# %%
display(df.loc[0:,'budget':])
# Out:
#         budget                                             genres  \
# 0     14000000                     [{'id': 35, 'name': 'Comedy'}]
# 1     40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2      3300000                      [{'id': 18, 'name': 'Drama'}]
# 3      1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4            0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# ...        ...                                                ...
# 2995         0  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996         0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997  65000000  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  42000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  35000000  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                                homepage    imdb_id original_language  \
# 0                                   NaN  tt2637294                en
# ...

# %%
df.loc[0:,['budget']]
# Out:
#         budget
# 0     14000000
# 1     40000000
# 2      3300000
# 3      1200000
# 4            0
# ...        ...
# 2995         0
# 2996         0
# 2997  65000000
# 2998  42000000
# 2999  35000000
#
# [3000 rows x 1 columns]

# %%
df[['id','budget']]
# Out:
#         id    budget
# 0        1  14000000
# 1        2  40000000
# 2        3   3300000
# 3        4   1200000
# 4        5         0
# ...    ...       ...
# 2995  2996         0
# 2996  2997         0
# 2997  2998  65000000
# 2998  2999  42000000
# 2999  3000  35000000
#
# [3000 rows x 2 columns]

# %%
df.loc[0:,['id','budget']]
# Out:
#         id    budget
# 0        1  14000000
# 1        2  40000000
# 2        3   3300000
# 3        4   1200000
# 4        5         0
# ...    ...       ...
# 2995  2996         0
# 2996  2997         0
# 2997  2998  65000000
# 2998  2999  42000000
# 2999  3000  35000000
#
# [3000 rows x 2 columns]

# %%
my_df=pd.DataFrame(np.random.uniform(20,45,size = (4,4)),index = [1,2,3,4],columns = ['alpha','beta','gamma','delta'])

# %%
my_df
# Out:
#        alpha       beta      gamma      delta
# 1  34.624462  24.268721  39.230985  21.330094
# 2  43.063739  22.079452  38.848348  40.250301
# 3  26.460759  40.185966  39.510983  35.219134
# 4  27.160654  44.185124  28.372344  34.924127

# %%
my_df_change=my_df.rename(columns = {'delta':'bazinga'},inplace = False)

# %%
my_df_change
# Out:
#        alpha       beta      gamma    bazinga
# 1  34.624462  24.268721  39.230985  21.330094
# 2  43.063739  22.079452  38.848348  40.250301
# 3  26.460759  40.185966  39.510983  35.219134
# 4  27.160654  44.185124  28.372344  34.924127

# %%
my_df
# Out:
#        alpha       beta      gamma      delta
# 1  34.624462  24.268721  39.230985  21.330094
# 2  43.063739  22.079452  38.848348  40.250301
# 3  26.460759  40.185966  39.510983  35.219134
# 4  27.160654  44.185124  28.372344  34.924127

# %%
my_df.rename({'delta':'bazinga'},axis = 1, inplace = True) # this is same as x = x +1 i.e reassigning the values

# %%
my_df
# Out:
#        alpha       beta      gamma    bazinga
# 1  34.624462  24.268721  39.230985  21.330094
# 2  43.063739  22.079452  38.848348  40.250301
# 3  26.460759  40.185966  39.510983  35.219134
# 4  27.160654  44.185124  28.372344  34.924127

# %%
del my_df_change

# %%
df.iloc[1:6,:6]# returns as per the index
# Out:
#    id                              belongs_to_collection    budget  \
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
# 5   6                                                NaN   8000000
#
#                                               genres  \
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 5  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
#
#                             homepage    imdb_id
# 1                                NaN  tt0368933
# 2  http://sonyclassics.com/whiplash/  tt2582802
# 3         http://kahaanithefilm.com/  tt1821480
# ...

# %%
df.loc[1:6,'id':'homepage'] # returns as is mentioned in the code
# Out:
#    id                              belongs_to_collection    budget  \
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
# 5   6                                                NaN   8000000
# 6   7                                                NaN  14000000
#
#                                               genres  \
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 5  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 6  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
#
#                              homepage
# 1                                 NaN
# 2   http://sonyclassics.com/whiplash/
# ...

# %%
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
df[2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df[2:]
# Out:
#         id belongs_to_collection    budget  \
# 2        3                   NaN   3300000
# 3        4                   NaN   1200000
# 4        5                   NaN         0
# 5        6                   NaN   8000000
# 6        7                   NaN  14000000
# ...    ...                   ...       ...
# 2995  2996                   NaN         0
# 2996  2997                   NaN         0
# 2997  2998                   NaN  65000000
# 2998  2999                   NaN  42000000
# 2999  3000                   NaN  35000000
#
#                                                  genres  \
# 2                         [{'id': 18, 'name': 'Drama'}]
# 3     [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4     [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 5     [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 6     [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# ...                                                 ...
# ...

# %%
df['budget']
# Out:
# 0       14000000
# 1       40000000
# 2        3300000
# 3        1200000
# 4              0
#           ...
# 2995           0
# 2996           0
# 2997    65000000
# 2998    42000000
# 2999    35000000
# Name: budget, Length: 3000, dtype: int64

# %%
df[['budget','id']]
# Out:
#         budget    id
# 0     14000000     1
# 1     40000000     2
# 2      3300000     3
# 3      1200000     4
# 4            0     5
# ...        ...   ...
# 2995         0  2996
# 2996         0  2997
# 2997  65000000  2998
# 2998  42000000  2999
# 2999  35000000  3000
#
# [3000 rows x 2 columns]

# %%
df_2 = pd.DataFrame(np.random.uniform(20,60,size = (4,6)),index = ['r1','r2','r3','r4'],columns = ['alpha','beta','gamma','delta','zeta','phi'])

# %%
df_2
# Out:
#         alpha       beta      gamma      delta       zeta        phi
# r1  41.603765  51.809745  45.391310  26.083033  57.005051  58.501307
# r2  27.310502  31.807899  44.993722  49.723638  29.755913  35.275470
# r3  36.680854  36.613829  38.260626  42.688763  49.349918  26.780496
# r4  59.215008  33.062911  27.163184  48.447063  27.838120  41.717432

# %%
df_2.loc['r2':,'beta':]
# Out:
#          beta      gamma      delta       zeta        phi
# r2  31.807899  44.993722  49.723638  29.755913  35.275470
# r3  36.613829  38.260626  42.688763  49.349918  26.780496
# r4  33.062911  27.163184  48.447063  27.838120  41.717432

# %%
df_2.iloc[1:,1:]
# Out:
#          beta      gamma      delta       zeta        phi
# r2  31.807899  44.993722  49.723638  29.755913  35.275470
# r3  36.613829  38.260626  42.688763  49.349918  26.780496
# r4  33.062911  27.163184  48.447063  27.838120  41.717432

# %%
df_2['beta']
# Out:
# r1    51.809745
# r2    31.807899
# r3    36.613829
# r4    33.062911
# Name: beta, dtype: float64

# %%
df_2[['beta','alpha']]
# Out:
#          beta      alpha
# r1  51.809745  41.603765
# r2  31.807899  27.310502
# r3  36.613829  36.680854
# r4  33.062911  59.215008

# %%
df_2['r1':'r2']
# Out:
#         alpha       beta      gamma      delta       zeta        phi
# r1  41.603765  51.809745  45.391310  26.083033  57.005051  58.501307
# r2  27.310502  31.807899  44.993722  49.723638  29.755913  35.275470

# %%
df_2.loc['r1','beta']
# Out:
# 51.80974493344169

# %%
df.loc[10:20,'budget':]
# Out:
#        budget                                             genres  \
# 10    1000000                      [{'id': 18, 'name': 'Drama'}]
# 11          0                     [{'id': 35, 'name': 'Comedy'}]
# 12   15000000                      [{'id': 18, 'name': 'Drama'}]
# 13   53000000  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# 14  102000000  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 15     500000  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 16   26000000  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 17          0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 18    8000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 19   32000000  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 20   80000000  [{'id': 12, 'name': 'Adventure'}, {'id': 10751...
#
#                                  homepage    imdb_id original_language  \
# 10                                    NaN  tt0075148                en
# ...

# %%
df.loc[10,'title']
# Out:
# 'Rocky'

# %%
display(df.loc[10,['title']])
# Out:
# title    Rocky
# Name: 10, dtype: object

# %%
df[:]
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
df['original_language'] == 'en' and
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 2995     True
# 2996    False
# 2997     True
# 2998     True
# 2999     True
# Name: original_language, Length: 3000, dtype: bool

# %%
df.original_language == 'en'
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 2995     True
# 2996    False
# 2997     True
# 2998     True
# 2999     True
# Name: original_language, Length: 3000, dtype: bool

# %%
df[df.original_language == 'en']
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 5        6                                                NaN   8000000
# 6        7                                                NaN  14000000
# ...    ...                                                ...       ...
# 2994  2995                                                NaN         0
# 2995  2996                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
english_movies = df[df.original_language == 'en']

# %%
english_movies
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 5        6                                                NaN   8000000
# 6        7                                                NaN  14000000
# ...    ...                                                ...       ...
# 2994  2995                                                NaN         0
# 2995  2996                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
english_movies.shape,df.shape
# Out:
# ((2575, 23), (3000, 23))

# %%
(df.original_language == 'en') | (df.original_language == 'hi')
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4       False
#         ...
# 2995     True
# 2996    False
# 2997     True
# 2998     True
# 2999     True
# Name: original_language, Length: 3000, dtype: bool

# %%
df.max()
# Out:
# C:\Users\Deepu\AppData\Local\Temp\ipykernel_11460\1151452817.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.max()
# id                         3000
# budget                380000000
# imdb_id               tt6673840
# original_language            zh
# original_title              회사원
# popularity           294.337037
# release_date             9/9/93
# runtime                   338.0
# status                  Rumored
# title                   Королёв
# revenue              1519557910
# dtype: object

# %%
df[df.original_language == 'en'].original_language.count()
# Out:
# 2575

# %%
df[df.original_language == 'hi'].original_language.count()
# Out:
# 42

# %%
df[df['original_language'] != 'en']['original_language'].count()
# Out:
# 425

# %%
roi=df.loc[df.original_language == 'en',['original_title','budget','revenue']].sort_values('revenue',ascending = False).head(5)

# %%
roi['returns'] = roi['revenue'] - roi['budget']

# %%
roi.sort_values('returns',ascending = False)
# Out:
#                       original_title     budget     revenue     returns
# 1761                       Furious 7  190000000  1506249360  1316249360
# 1126                    The Avengers  220000000  1519557910  1299557910
# 2770         Avengers: Age of Ultron  280000000  1405403694  1125403694
# 684             Beauty and the Beast  160000000  1262886337  1102886337
# 2322  Transformers: Dark of the Moon  195000000  1123746996   928746996

# %%
df['original_language'] == 'en'
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 2995     True
# 2996    False
# 2997     True
# 2998     True
# 2999     True
# Name: original_language, Length: 3000, dtype: bool

# %%
df[df.original_language == 'en']
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 5        6                                                NaN   8000000
# 6        7                                                NaN  14000000
# ...    ...                                                ...       ...
# 2994  2995                                                NaN         0
# 2995  2996                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
english_movies = df[df.original_language == 'en']

# %%
english_movies
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 5        6                                                NaN   8000000
# 6        7                                                NaN  14000000
# ...    ...                                                ...       ...
# 2994  2995                                                NaN         0
# 2995  2996                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
english_movies.shape
# Out:
# (2575, 23)

# %%
df.original_language == 'hi'
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 2995    False
# 2996    False
# 2997    False
# 2998    False
# 2999    False
# Name: original_language, Length: 3000, dtype: bool

# %%
df['budget'] == 40000000
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 2995    False
# 2996    False
# 2997    False
# 2998    False
# 2999    False
# Name: budget, Length: 3000, dtype: bool

# %%
zero_df=df[(df.budget == 0) & (df['revenue'] == 0)]

# %%
zero_df[['budget','revenue']]
# Out:
# Empty DataFrame
# Columns: [budget, revenue]
# Index: []

# %%
df.budget.max()
# Out:
# 380000000

# %%
df[df.budget == 380000000]
# Out:
#         id                              belongs_to_collection     budget  \
# 2135  2136  [{'id': 295, 'name': 'Pirates of the Caribbean...  380000000
#
#                                                  genres  \
# 2135  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
#
#                                                homepage    imdb_id  \
# 2135  http://disney.go.com/pirates/index-on-stranger...  tt1298650
#
#      original_language                               original_title  \
# 2135                en  Pirates of the Caribbean: On Stranger Tides
#
#                                                overview  popularity  ...  \
# 2135  Captain Jack Sparrow crosses paths with a woma...    27.88772  ...
#
#      release_date runtime                                   spoken_languages  \
# 2135      5/14/11   136.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
#
#         status                      tagline  \
# 2135  Released  Live Forever Or Die Trying.
#
# ...

# %%
df.runtime > 120
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 2995    False
# 2996    False
# 2997    False
# 2998    False
# 2999    False
# Name: runtime, Length: 3000, dtype: bool

# %%
long_movies=df[df.runtime >= 120]

# %%
long_movies.shape
# Out:
# (705, 23)

# %%
long_movies[['original_language','original_title','runtime']].sort_values('runtime',ascending = False)
# Out:
#      original_language           original_title  runtime
# 1211                en                   Carlos    338.0
# 1922                en                Cleopatra    248.0
# 523                 en     The Ten Commandments    220.0
# 1302                en            Heaven's Gate    219.0
# 1914                en        Gods and Generals    214.0
# ...                ...                      ...      ...
# 1821                es                 Balseros    120.0
# 2867                en             Halo Legends    120.0
# 2871                en           Antwone Fisher    120.0
# 2750                ko                     올드보이    120.0
# 2997                en  The Long Kiss Goodnight    120.0
#
# [705 rows x 3 columns]

# %%
long_hindi=df[(df.original_language == 'hi') & (df['runtime'] >= 120)]

# %%
long_hindi.shape
# Out:
# (41, 23)

# %%
long_hindi[['original_title','runtime']].sort_values('runtime',ascending = False)
# Out:
#                   original_title  runtime
# 2353                Jodhaa Akbar    213.0
# 2563          कभी अलविदा ना कहना    193.0
# 1987                 कल हो ना हो    186.0
# 1640          Bhaag Milkha Bhaag    186.0
# 1572                     Ghajini    183.0
# 2239                       धूम ३    172.0
# 2807                       Fanaa    168.0
# 1729                      दिल से    163.0
# 2538                        Josh    162.0
# 585                         दंगल    161.0
# 1766                     Tum Bin    158.0
# 2390               Khatta Meetha    155.0
# 419         Atithi Tum Kab Jaoge    155.0
# 401   The Legend of Bhagat Singh    155.0
# 1719                      Barfi!    155.0
# 671              Anjaana Anjaani    151.0
# 2287               बॉम्बे वेलवेट    151.0
# 2828             Bajirao Mastani    150.0
# 2436                Dear Zindagi    149.0
# 481       Chandni Chowk To China    149.0
# 970                    Heropanti    146.0
# ...

# %%
long_hindi[['original_title','runtime','budget','revenue']]
# Out:
#                   original_title  runtime    budget    revenue
# 3                        Kahaani    122.0   1200000   16000000
# 213                  राउडी राठौर    143.0   6700000   31000000
# 371                    Thank You    140.0  13100000    4100000
# 401   The Legend of Bhagat Singh    155.0   3000000    6000000
# 419         Atithi Tum Kab Jaoge    155.0   3750000    5000000
# 481       Chandni Chowk To China    149.0  10500000    9400000
# 585                         दंगल    161.0  10400000  310000000
# 627                          Fan    142.0  16000000   29251596
# 671              Anjaana Anjaani    151.0   6400000    5900000
# 695                    Tere Naam    132.0         1          2
# 771                      Kaminey    135.0   9000000   18130000
# 840                        नीरजा    122.0  10721568    2978994
# 848                     रान्झाना    140.0   6400000   18000000
# 970                    Heropanti    146.0   4200000   10000000
# ...

# %%
long_hindi['roi'] = np.around(long_hindi['revenue'] / long_hindi['budget'],2)
# Out:
# C:\Users\Deepu\AppData\Local\Temp\ipykernel_11460\2988194680.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_hindi['roi'] = np.around(long_hindi['revenue'] / long_hindi['budget'],2)

# %%
long_hindi['roi']
# Out:
# 3       13.33
# 213      4.63
# 371      0.31
# 401      2.00
# 419      1.33
# 481      0.90
# 585     29.81
# 627      1.83
# 671      0.92
# 695      2.00
# 771      2.01
# 840      0.28
# 848      2.81
# 970      2.38
# 1491     4.03
# 1572     8.35
# 1640     5.43
# 1656     3.44
# 1694     1.94
# 1719     0.63
# 1729     2.50
# 1732     8.55
# 1766      inf
# 1948      inf
# 1987      inf
# 1989     3.11
# 2239     4.67
# 2251     0.06
# 2287     0.08
# 2353     1.55
# 2390     1.33
# 2436     0.79
# 2480     2.94
# 2538     2.17
# 2563     2.30
# 2567     3.73
# 2807     4.18
# 2828     2.87
# 2857     1.20
# 2859     8.18
# 2959     2.00
# Name: roi, dtype: float64

# %%
long_hindi[['original_title','roi']]
# Out:
#                   original_title    roi
# 3                        Kahaani  13.33
# 213                  राउडी राठौर   4.63
# 371                    Thank You   0.31
# 401   The Legend of Bhagat Singh   2.00
# 419         Atithi Tum Kab Jaoge   1.33
# 481       Chandni Chowk To China   0.90
# 585                         दंगल  29.81
# 627                          Fan   1.83
# 671              Anjaana Anjaani   0.92
# 695                    Tere Naam   2.00
# 771                      Kaminey   2.01
# 840                        नीरजा   0.28
# 848                     रान्झाना   2.81
# 970                    Heropanti   2.38
# 1491                        Piku   4.03
# 1572                     Ghajini   8.35
# 1640          Bhaag Milkha Bhaag   5.43
# 1656             Chennai Express   3.44
# 1694                रमन राघव २.०   1.94
# 1719                      Barfi!   0.63
# 1729                      दिल से   2.50
# 1732                 Grand Masti   8.55
# ...

# %%
pop_eng_long=df[(df.original_language == 'en') & (df.popularity > 10) & (df.runtime >= 120)]

# %%
pop_eng_long.loc[12, 'budget'] = pop_eng_long.budget.mean()

# %%
pop_eng_long
# Out:
#         id belongs_to_collection        budget  \
# 12      13                   NaN  6.748502e+07
# 14      15                   NaN  1.020000e+08
# 20      21                   NaN  8.000000e+07
# 37      38                   NaN  5.000000e+07
# 47      48                   NaN  4.400000e+07
# ...    ...                   ...           ...
# 2962  2963                   NaN  2.000000e+07
# 2965  2966                   NaN  6.100000e+07
# 2969  2970                   NaN  1.980000e+07
# 2993  2994                   NaN  6.000000e+07
# 2997  2998                   NaN  6.500000e+07
#
#                                                  genres  \
# 12                        [{'id': 18, 'name': 'Drama'}]
# 14    [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 20    [{'id': 12, 'name': 'Adventure'}, {'id': 10751...
# 37    [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 47    [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# ...

# %%
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
df[(df['original_language'] == 'en') & (df['runtime'] >= 120)]
# Out:
#         id                              belongs_to_collection     budget  \
# 12      13                                                NaN   15000000
# 14      15                                                NaN  102000000
# 20      21                                                NaN   80000000
# 33      34  [{'id': 207632, 'name': 'The ABCs of Death Col...          0
# 37      38                                                NaN   50000000
# ...    ...                                                ...        ...
# 2969  2970                                                NaN   19800000
# 2970  2971                                                NaN   25000000
# 2992  2993                                                NaN    1135654
# 2993  2994                                                NaN   60000000
# 2997  2998                                                NaN   65000000
#
#                                                  genres  \
# ...

# %%
df[(df['original_language'] == 'en') & (df['runtime'] == 120)].shape
# Out:
# (36, 23)

# %%
pop_10_eng=df[(df.original_language == 'en') & (df.runtime == 120) & (df.popularity > 10)]

# %%
pop_10_eng.reset_index(drop = True,inplace = True)

# %%
pop_10_eng
# Out:
#       id                              belongs_to_collection     budget  \
# 0    280                                                NaN   65000000
# 1    352  [{'id': 645, 'name': 'James Bond Collection', ...    7200000
# 2    552                                                NaN   49000000
# 3    597  [{'id': 107725, 'name': 'Creepshow Collection'...    8000000
# 4    713                                                NaN   40000000
# 5    838  [{'id': 8945, 'name': 'Mad Max Collection', 'p...  150000000
# 6    847                                                NaN   20000000
# 7    955                                                NaN          0
# 8   1090                                                NaN          0
# 9   1587                                                NaN   44500000
# 10  1760  [{'id': 31562, 'name': 'The Bourne Collection'...  130000000
# 11  1996                                                NaN   65000000
# ...

# %%
pop_10_eng
# Out:
#       id                              belongs_to_collection     budget  \
# 0    280                                                NaN   65000000
# 1    352  [{'id': 645, 'name': 'James Bond Collection', ...    7200000
# 2    552                                                NaN   49000000
# 3    597  [{'id': 107725, 'name': 'Creepshow Collection'...    8000000
# 4    713                                                NaN   40000000
# 5    838  [{'id': 8945, 'name': 'Mad Max Collection', 'p...  150000000
# 6    847                                                NaN   20000000
# 7    955                                                NaN          0
# 8   1090                                                NaN          0
# 9   1587                                                NaN   44500000
# 10  1760  [{'id': 31562, 'name': 'The Bourne Collection'...  130000000
# 11  1996                                                NaN   65000000
# ...

# %%
df.genres.unique()
# Out:
# array(["[{'id': 35, 'name': 'Comedy'}]",
#        "[{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}, {'id': 10751, 'name': 'Family'}, {'id': 10749, 'name': 'Romance'}]",
#        "[{'id': 18, 'name': 'Drama'}]",
#        "[{'id': 53, 'name': 'Thriller'}, {'id': 18, 'name': 'Drama'}]",
#        "[{'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}]",
#        "[{'id': 16, 'name': 'Animation'}, {'id': 12, 'name': 'Adventure'}, {'id': 10751, 'name': 'Family'}]",
#        "[{'id': 27, 'name': 'Horror'}, {'id': 53, 'name': 'Thriller'}]",
#        "[{'id': 99, 'name': 'Documentary'}]",
#        "[{'id': 28, 'name': 'Action'}, {'id': 35, 'name': 'Comedy'}, {'id': 10402, 'name': 'Music'}, {'id': 10751, 'name': 'Family'}, {'id': 12, 'name': 'Adventure'}]",
#        "[{'id': 35, 'name': 'Comedy'}, {'id': 10402, 'name': 'Music'}]",
#        "[{'id': 35, 'name': 'Comedy'}, {'id': 80, 'name': 'Crime'}]",
# ...

# %%
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
pop_10_eng.iloc[:6,2:3] = np.nan
# Out:
# C:\Users\Deepu\AppData\Local\Temp\ipykernel_12868\1547739722.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pop_10_eng.iloc[:6,2:3] = np.nan

# %%
pop_10_eng
# Out:
#       id                              belongs_to_collection       budget  \
# 0    280                                                NaN          NaN
# 1    352  [{'id': 645, 'name': 'James Bond Collection', ...          NaN
# 2    552                                                NaN          NaN
# 3    597  [{'id': 107725, 'name': 'Creepshow Collection'...          NaN
# 4    713                                                NaN          NaN
# 5    838  [{'id': 8945, 'name': 'Mad Max Collection', 'p...          NaN
# 6    847                                                NaN   20000000.0
# 7    955                                                NaN          0.0
# 8   1090                                                NaN          0.0
# 9   1587                                                NaN   44500000.0
# 10  1760  [{'id': 31562, 'name': 'The Bourne Collection'...  130000000.0
# 11  1996                                                NaN   65000000.0
# ...

# %%
pop_10_eng.loc[:6,['budget']] = pop_10_eng.budget.mean()

# %%
np.around(pop_10_eng)
# Out:
#       id                              belongs_to_collection       budget  \
# 0    280                                                NaN   39916667.0
# 1    352  [{'id': 645, 'name': 'James Bond Collection', ...   39916667.0
# 2    552                                                NaN   39916667.0
# 3    597  [{'id': 107725, 'name': 'Creepshow Collection'...   39916667.0
# 4    713                                                NaN   39916667.0
# 5    838  [{'id': 8945, 'name': 'Mad Max Collection', 'p...   39916667.0
# 6    847                                                NaN   39916667.0
# 7    955                                                NaN          0.0
# 8   1090                                                NaN          0.0
# 9   1587                                                NaN   44500000.0
# 10  1760  [{'id': 31562, 'name': 'The Bourne Collection'...  130000000.0
# 11  1996                                                NaN   65000000.0
# ...

# %%
df[(df.original_language == 'hi') & (df.popularity >= 15)]
# Out:
# Empty DataFrame
# Columns: [id, belongs_to_collection, budget, genres, homepage, imdb_id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date, runtime, spoken_languages, status, tagline, title, Keywords, cast, crew, revenue]
# Index: []
#
# [0 rows x 23 columns]

# %%
df['profit'] = df['revenue'] - df['budget']

# %%
df.profit
# Out:
# 0        -1685349
# 1        55149435
# 2         9792000
# 3        14800000
# 4         3923970
#           ...
# 2995      1596687
# 2996       180590
# 2997     24456761
# 2998    129963386
# 2999     47087155
# Name: profit, Length: 3000, dtype: int64

# %%
df.loc[:,['original_title','profit']].sort_values('profit',ascending = False)
# Out:
#                                    original_title      profit
# 1761                                    Furious 7  1316249360
# 1126                                 The Avengers  1299557910
# 2770                      Avengers: Age of Ultron  1125403694
# 684                          Beauty and the Beast  1102886337
# 2322               Transformers: Dark of the Moon   928746996
# ...                                           ...         ...
# 776                                     Australia   -80445998
# 307                                 Live by Night   -85321445
# 251                              Cutthroat Island   -87982678
# 2278                 The Adventures of Pluto Nash   -92896027
# 2623  Valerian and the City of a Thousand Planets  -107447384
#
# [3000 rows x 2 columns]

# %%
df.drop(['profit'],axis = 1,inplace = True)

# %%
df['profit_percent'] = ((df['revenue'] - df['budget'])/df['budget']) * 100

# %%
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue',
#        'profit_percent'],
#       dtype='object')

# %%
df.drop(['profit_percent'],axis = 1, inplace = True)

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
df['half_time'] = df['runtime']*0.5

# %%
df['half_time']
# Out:
# 0       46.5
# 1       56.5
# 2       52.5
# 3       61.0
# 4       59.0
#         ...
# 2995    51.0
# 2996    51.0
# 2997    60.0
# 2998    45.0
# 2999    53.0
# Name: half_time, Length: 3000, dtype: float64

# %%
df.drop(['half_time'],axis = 1, inplace = True)

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
hindi_movies=df[df['original_language'] == 'hi']

# %%
hindi_movies['roi'] = hindi_movies['revenue']/hindi_movies['budget']
# Out:
# C:\Users\Deepu\AppData\Local\Temp\ipykernel_12868\3569847400.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hindi_movies['roi'] = hindi_movies['revenue']/hindi_movies['budget']

# %%
hindi_movies.drop(['roi'],axis = 1,inplace = True)
# Out:
# C:\Users\Deepu\AppData\Local\Temp\ipykernel_12868\613255103.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hindi_movies.drop(['roi'],axis = 1,inplace = True)

# %%
hindi_movies.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
df[df.original_language == 'en'].shape
# Out:
# (2575, 23)

# %%
df[df.original_language == 'hi'].shape
# Out:
# (42, 23)

# %%
df[(df.original_language == 'en') | (df.original_language == 'hi')].shape
# Out:
# (2617, 23)

# %%
df.original_title
# Out:
# 0                         Hot Tub Time Machine 2
# 1       The Princess Diaries 2: Royal Engagement
# 2                                       Whiplash
# 3                                        Kahaani
# 4                                           마린보이
#                           ...
# 2995                                     Chasers
# 2996                                 Vi är bäst!
# 2997                     The Long Kiss Goodnight
# 2998                            Along Came Polly
# 2999                                   Abduction
# Name: original_title, Length: 3000, dtype: object

# %%
df.revenue.sum()
# Out:
# 200177555666

# %%
df.revenue.mean()
# Out:
# 66725851.88866667

# %%
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
df.iloc[0,4] = 'https://www.hbo.com/movies/hot-tub-time-machine'

# %%
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
df.iloc[1,4] = 'https://www.imdb.com/title/tt0247638/'

# %%
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
df.iloc[:2,4:5] = np.nan

# %%
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
df.iloc[:2,4:5] = [ 'https://www.hbo.com/movies/hot-tub-time-machine','https://www.imdb.com/title/tt0247638/']

# %%
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
df.loc[df.original_language != 'en',['original_language','original_title','revenue','budget']].reset_index(drop = 'index')
# Out:
#     original_language   original_title    revenue    budget
# 0                  hi          Kahaani   16000000   1200000
# 1                  ko             마린보이    3923970         0
# 2                  sr          Šišanje        198    500000
# 3                  fr     Intouchables  426480871  13000000
# 4                  fr            Caché   36000000         0
# ..                ...              ...        ...       ...
# 420                ja               恋空   44038000         0
# 421                cn              龍虎門    8685526         0
# 422                ml  ആക്ഷൻ ഹീറോ ബിജു    2500000    300000
# 423                fa               ده     105656         0
# 424                sv      Vi är bäst!     180590         0
#
# [425 rows x 4 columns]

# %%
df.original_title
# Out:
# 0                         Hot Tub Time Machine 2
# 1       The Princess Diaries 2: Royal Engagement
# 2                                       Whiplash
# 3                                        Kahaani
# 4                                           마린보이
#                           ...
# 2995                                     Chasers
# 2996                                 Vi är bäst!
# 2997                     The Long Kiss Goodnight
# 2998                            Along Came Polly
# 2999                                   Abduction
# Name: original_title, Length: 3000, dtype: object

# %%
def caps(x):
    return x.upper()

# %%
y = 'deepu'
caps(y)
# Out:
# 'DEEPU'

# %%
y = lambda x: x + 1

# %%
a = 1
y(a)
# Out:
# 2

# %%
y = lambda x,y,z: x+y+z

# %%
y = lambda a,b,c,d,e: a+b+c+d+e
z = y(1,2,3,4,5)
z
# Out:
# 15

# %%
def caps(arg):
    return arg.upper()

# %%
y = 'deepu'
caps(y)
# Out:
# 'DEEPU'

# %%
z = lambda y : caps(y)
a = 'sanjay'
z(a)
# Out:
# 'SANJAY'

# %%
a = lambda x : x.upper()
a('rahul')
# Out:
# 'RAHUL'

# %%
a = lambda x: x[0].upper()+x[1:]

# %%
a('jai shree ram')
# Out:
# 'Jai shree ram'

# %%
def caps(p):
    return p.upper()

# %%
df['original_language'].apply(lambda x: caps(x))
# Out:
# 0       EN
# 1       EN
# 2       EN
# 3       HI
# 4       KO
#         ..
# 2995    EN
# 2996    SV
# 2997    EN
# 2998    EN
# 2999    EN
# Name: original_language, Length: 3000, dtype: object

# %%
df.apply(lambda x:caps(x.original_title),axis = 1)
# Out:
# 0                         HOT TUB TIME MACHINE 2
# 1       THE PRINCESS DIARIES 2: ROYAL ENGAGEMENT
# 2                                       WHIPLASH
# 3                                        KAHAANI
# 4                                           마린보이
#                           ...
# 2995                                     CHASERS
# 2996                                 VI ÄR BÄST!
# 2997                     THE LONG KISS GOODNIGHT
# 2998                            ALONG CAME POLLY
# 2999                                   ABDUCTION
# Length: 3000, dtype: object

# %%
df.apply(lambda x: x.original_title.upper(),axis = 1)
# Out:
# 0                         HOT TUB TIME MACHINE 2
# 1       THE PRINCESS DIARIES 2: ROYAL ENGAGEMENT
# 2                                       WHIPLASH
# 3                                        KAHAANI
# 4                                           마린보이
#                           ...
# 2995                                     CHASERS
# 2996                                 VI ÄR BÄST!
# 2997                     THE LONG KISS GOODNIGHT
# 2998                            ALONG CAME POLLY
# 2999                                   ABDUCTION
# Length: 3000, dtype: object

# %%
np.random.seed(0)
d = np.random.randint(0,25,size = (10,2))
print(d)
# Out:
# [[12 15]
#  [21  0]
#  [ 3  3]
#  [ 7  9]
#  [19 21]
#  [18  4]
#  [23  6]
#  [24 24]
#  [12  1]
#  [ 6  7]]

# %%
dataf = pd.DataFrame(d,columns = ['selling price','cost price'])

# %%
dataf
# Out:
#    selling price  cost price
# 0             12          15
# 1             21           0
# 2              3           3
# 3              7           9
# 4             19          21
# 5             18           4
# 6             23           6
# 7             24          24
# 8             12           1
# 9              6           7

# %%
def pp(cp,sp):
    profit_percent = ((sp-cp)/cp)*100
    return profit_percent

# %%
def pp(a):
    try:
        profit_percent = ((a[1]-a[0])/a[1])*100
        return profit_percent
        
    except:
        profit_percent = np.nan
        return profit_percent

# %%
pp(100,120)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [85], in <cell line: 1>()
# ----> 1 pp(100,120)
#
# TypeError: pp() takes 1 positional argument but 2 were given

# %%
dataf.apply(pp)
# Out:
# C:\Users\Deepu\AppData\Local\Temp\ipykernel_5152\4185637166.py:3: RuntimeWarning: divide by zero encountered in long_scalars
#   profit_percent = ((a[1]-a[0])/a[1])*100
# selling price    42.857143
# cost price            -inf
# dtype: float64

# %%
df.budget
# Out:
# 0       14000000
# 1       40000000
# 2        3300000
# 3        1200000
# 4              0
#           ...
# 2995           0
# 2996           0
# 2997    65000000
# 2998    42000000
# 2999    35000000
# Name: budget, Length: 3000, dtype: int64

# %%
a = 78
b = 6

try:
    c=a/b
except:
    c = np.nan
print(c)
# Out:
# 13.0

# %%
df.apply(lambda x: x.original_language.upper(),axis = 1)
# Out:
# 0       EN
# 1       EN
# 2       EN
# 3       HI
# 4       KO
#         ..
# 2995    EN
# 2996    SV
# 2997    EN
# 2998    EN
# 2999    EN
# Length: 3000, dtype: object

# %%
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
def caps(col):
    return col.upper()

# %%
caps('deepu')
# Out:
# 'DEEPU'

# %%
#lets apply on individual columns

# %%
df['caps_title']=df.original_title.apply(caps)

# %%
df.caps_title
# Out:
# 0                         HOT TUB TIME MACHINE 2
# 1       THE PRINCESS DIARIES 2: ROYAL ENGAGEMENT
# 2                                       WHIPLASH
# 3                                        KAHAANI
# 4                                           마린보이
#                           ...
# 2995                                     CHASERS
# 2996                                 VI ÄR BÄST!
# 2997                     THE LONG KISS GOODNIGHT
# 2998                            ALONG CAME POLLY
# 2999                                   ABDUCTION
# Name: caps_title, Length: 3000, dtype: object

# %%
df[['original_title','caps_title']]
# Out:
#                                 original_title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                         마린보이
# ...                                        ...
# 2995                                   Chasers
# 2996                               Vi är bäst!
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                     caps_title
# 0                       HOT TUB TIME MACHINE 2
# 1     THE PRINCESS DIARIES 2: ROYAL ENGAGEMENT
# 2                                     WHIPLASH
# 3                                      KAHAANI
# 4                                         마린보이
# ...                                        ...
# 2995                                   CHASERS
# ...

# %%
# What if you don't want to specify at the begining that is just df and not df.original_title

# %%
df.apply(caps(df.original_title),axis =1) # you are passing series here
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 df.apply(caps(df.original_title),axis =1)
#
# Input In [7], in caps(col)
#       1 def caps(col):
# ----> 2     return col.upper()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'upper'

# %%
df.apply(lambda x: caps(x.original_title)) # lambda kind of iterates the series
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 df.apply(lambda x: caps(x.original_title))
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:8839, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8828 from pandas.core.apply import frame_apply
#    8830 op = frame_apply(
#    8831     self,
#    8832     func=func,
#    (...)
#    8837     kwargs=kwargs,
#    8838 )
# -> 8839 return op.apply().__finalize__(self, method="apply")
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py:727, in FrameApply.apply(self)
#     724 elif self.raw:
#     725     return self.apply_raw()
# --> 727 return self.apply_standard()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py:851, in FrameApply.apply_standard(self)
#     850 def apply_standard(self):
# ...

# %%
df.apply(lambda x: caps(x.original_language),axis = 1)
# Out:
# 0       EN
# 1       EN
# 2       EN
# 3       HI
# 4       KO
#         ..
# 2995    EN
# 2996    SV
# 2997    EN
# 2998    EN
# 2999    EN
# Length: 3000, dtype: object

# %%
lets perform profit percent
# Out:
#   Input In [24]
#     lets perform profit percent
#          ^
# SyntaxError: invalid syntax

# %%
df.drop(['caps_title'],axis = 1 ,inplace = True)

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
dataf
# Out:
#    selling price  cost price
# 0             12          15
# 1             21           0
# 2              3           3
# 3              7           9
# 4             19          21
# 5             18           4
# 6             23           6
# 7             24          24
# 8             12           1
# 9              6           7

# %%
def profit_percent(sp,cp):
    pp = ((sp-cp)/cp)*100
    return round(pp,2)

# %%
profit_percent(120,34)
# Out:
# 252.94

# %%
dataf.apply(lambda x:profit_percent(dataf[0],dataf[1]),axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
def profit_percent(sp,cp):
    try:
        pp = ((sp-cp)/cp)*100
        return round(pp,2)
    except:
        pp = np.nan
        return pp

# %%
profit_percent(120,0)
# Out:
# nan

# %%
dataf.apply(profit_percent(dataf[1],dataf[0]),axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
dataf
# Out:
#    selling price  cost price
# 0             12          15
# 1             21           0
# 2              3           3
# 3              7           9
# 4             19          21
# 5             18           4
# 6             23           6
# 7             24          24
# 8             12           1
# 9              6           7

# %%
def profit(a,b):
    try:
        percent = (a-b)/a * 100
        return percent
    except:
        t = 0
        return t

# %%
profit(1,2)
# Out:
# -100.0

# %%
profit(0,3
      )
# Out:
# 0

# %%
def profit(a,b):
    percent = ((b-a)/b)*100
    return percent

# %%
dataf.apply(lambda x: profit(x['cost price'],x['selling price']) if x['cost price'] != 0 else np.nan,axis = 1)
# Out:
# 0   -25.000000
# 1          NaN
# 2     0.000000
# 3   -28.571429
# 4   -10.526316
# 5    77.777778
# 6    73.913043
# 7     0.000000
# 8    91.666667
# 9   -16.666667
# dtype: float64

# %%
df.apply(lambda x: profit(x.budget,x.revenue),axis = 1)
# Out:
# 0         12.038207
# 1       -137.873588
# 2       -296.727273
# 3      -1233.333333
# 4          0.000000
#            ...
# 2995       0.000000
# 2996       0.000000
# 2997     -37.625786
# 2998    -309.436633
# 2999    -134.534729
# Length: 3000, dtype: float64

# %%
df.original_titles.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [77], in <cell line: 1>()
# ----> 1 df.original_titles.upper()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'original_titles'

# %%
df.apply(caps(df.original_language),axis = 1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [82], in <cell line: 1>()
# ----> 1 df.apply(caps(df.original_language),axis = 1)
#
# Input In [7], in caps(col)
#       1 def caps(col):
# ----> 2     return col.upper()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'upper'

# %%
df.original_title.apply(caps)
# Out:
# 0                         HOT TUB TIME MACHINE 2
# 1       THE PRINCESS DIARIES 2: ROYAL ENGAGEMENT
# 2                                       WHIPLASH
# 3                                        KAHAANI
# 4                                           마린보이
#                           ...
# 2995                                     CHASERS
# 2996                                 VI ÄR BÄST!
# 2997                     THE LONG KISS GOODNIGHT
# 2998                            ALONG CAME POLLY
# 2999                                   ABDUCTION
# Name: original_title, Length: 3000, dtype: object

# %%
df.apply(caps(df.original_language),axis = 1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [85], in <cell line: 1>()
# ----> 1 df.apply(caps(df.original_language),axis = 1)
#
# Input In [7], in caps(col)
#       1 def caps(col):
# ----> 2     return col.upper()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'upper'

# %%
df.apply(lambda x: caps(x.original_title),axis = 1)
# Out:
# 0                         HOT TUB TIME MACHINE 2
# 1       THE PRINCESS DIARIES 2: ROYAL ENGAGEMENT
# 2                                       WHIPLASH
# 3                                        KAHAANI
# 4                                           마린보이
#                           ...
# 2995                                     CHASERS
# 2996                                 VI ÄR BÄST!
# 2997                     THE LONG KISS GOODNIGHT
# 2998                            ALONG CAME POLLY
# 2999                                   ABDUCTION
# Length: 3000, dtype: object

# %%
df.get_loc('id',axis = 1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [88], in <cell line: 1>()
# ----> 1 df.get_loc('id',axis = 1)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'get_loc'

# %%
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
df.set_index('imdb_id')['tt2637294':'tt2582802']
# Out:
#            id                              belongs_to_collection    budget  \
# imdb_id
# tt2637294   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# tt0368933   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# tt2582802   3                                                NaN   3300000
#
#                                                       genres  \
# imdb_id
# tt2637294                     [{'id': 35, 'name': 'Comedy'}]
# tt0368933  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# tt2582802                      [{'id': 18, 'name': 'Drama'}]
#
#                                     homepage original_language  \
# imdb_id
# tt2637294                                NaN                en
# tt0368933                                NaN                en
# tt2582802  http://sonyclassics.com/whiplash/                en
#
#                                      original_title  \
# imdb_id
# tt2637294                    Hot Tub Time Machine 2
# ...

# %%
df.set_index('imdb_id').reset_index()
# Out:
#         imdb_id    id                              belongs_to_collection  \
# 0     tt2637294     1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...
# 1     tt0368933     2  [{'id': 107674, 'name': 'The Princess Diaries ...
# 2     tt2582802     3                                                NaN
# 3     tt1821480     4                                                NaN
# 4     tt1380152     5                                                NaN
# ...         ...   ...                                                ...
# 2995  tt0109403  2996                                                NaN
# 2996  tt2364975  2997                                                NaN
# 2997  tt0116908  2998                                                NaN
# 2998  tt0343135  2999                                                NaN
# 2999  tt1600195  3000                                                NaN
#
#         budget                                             genres  \
# ...

# %%
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
dataf.set_index('selling price')
# Out:
#                cost price
# selling price
# 12                     15
# 21                      0
# 3                       3
# 7                       9
# 19                     21
# 18                      4
# 23                      6
# 24                     24
# 12                      1
# 6                       7

# %%
dataf
# Out:
#    selling price  cost price
# 0             12          15
# 1             21           0
# 2              3           3
# 3              7           9
# 4             19          21
# 5             18           4
# 6             23           6
# 7             24          24
# 8             12           1
# 9              6           7

# %%
dataf.reset_index(drop = 'index', inplace = True)

# %%
dataf
# Out:
#    selling price  cost price
# 0             12          15
# 1             21           0
# 2              3           3
# 3              7           9
# 4             19          21
# 5             18           4
# 6             23           6
# 7             24          24
# 8             12           1
# 9              6           7

# %%
df.apply(lambda x: ((x['revenue']-x['budget'])/x['budget'])*100)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 df.apply(lambda x: ((x['revenue']-x['budget'])/x['budget'])*100)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:8839, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8828 from pandas.core.apply import frame_apply
#    8830 op = frame_apply(
#    8831     self,
#    8832     func=func,
#    (...)
#    8837     kwargs=kwargs,
#    8838 )
# -> 8839 return op.apply().__finalize__(self, method="apply")
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py:727, in FrameApply.apply(self)
#     724 elif self.raw:
#     725     return self.apply_raw()
# --> 727 return self.apply_standard()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py:851, in FrameApply.apply_standard(self)
# ...

# %%
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
def profit_percent(a):
    try:
        pp = ((a['revenue'] - a['budget'])/a['budget'])*100
        return round(pp,2)
    except:
        return np.nan

# %%
df.apply(profit_percent,axis = 1)
# Out:
# 0        -12.04
# 1        137.87
# 2        296.73
# 3       1233.33
# 4           NaN
#          ...
# 2995        NaN
# 2996        NaN
# 2997      37.63
# 2998     309.44
# 2999     134.53
# Length: 3000, dtype: float64

# %%
def pp(cp,sp):
    profit = ((sp-cp)/cp) * 100
    return round(profit,2)

# %%
pp(100,120)
# Out:
# 20.0

# %%
df.apply(lambda x: pp(x['budget'],x['revenue']) if x['budget'] != 0 else np.nan,axis = 1)
# Out:
# 0        -12.04
# 1        137.87
# 2        296.73
# 3       1233.33
# 4           NaN
#          ...
# 2995        NaN
# 2996        NaN
# 2997      37.63
# 2998     309.44
# 2999     134.53
# Length: 3000, dtype: float64

# %%
def profit_p(cp,sp):
    try:
        profit = ((cp-sp)/cp)*100
        return round(profit,2)
    except:
        profit = np.nan
        return profit

# %%
df.apply(lambda x: profit_p(x.budget,x.revenue),axis = 1)
# Out:
# 0         12.04
# 1       -137.87
# 2       -296.73
# 3      -1233.33
# 4           NaN
#          ...
# 2995        NaN
# 2996        NaN
# 2997     -37.63
# 2998    -309.44
# 2999    -134.53
# Length: 3000, dtype: float64

# %%
df.original_title.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 df.original_title.upper()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'upper'

# %%
df.original_language.apply(upper())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 df.original_language.apply(upper())
#
# NameError: name 'upper' is not defined

# %%
def caps(a):
    return a.upper()

# %%
caps('deepu ')
# Out:
# 'DEEPU '

# %%
df.original_language.apply(caps)
# Out:
# 0       EN
# 1       EN
# 2       EN
# 3       HI
# 4       KO
#         ..
# 2995    EN
# 2996    SV
# 2997    EN
# 2998    EN
# 2999    EN
# Name: original_language, Length: 3000, dtype: object

# %% [markdown]
# One more method which comes in handy to find the index of the columns in dataframe is

# %%
df.columns.get_loc('budget')
# Out:
# 2

# %%
df.columns.get_loc('revenue')
# Out:
# 22

# %% [markdown]
# So when writing the customize funciton you can directy use index as well

# %%
print(df.release_date.dtype)
# Out:
# object

# %%
from datetime import datetime,time

# %%
s = datetime.now()
s
# Out:
# datetime.datetime(2023, 4, 18, 16, 7, 20, 894683)

# %%
time.time()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [62], in <cell line: 1>()
# ----> 1 time.time()
#
# AttributeError: type object 'datetime.time' has no attribute 'time'

# %%
df.apply(lambda x: ((x[22] - x[2])/x[2])*100 if x[2] != 0 else np.nan,axis = 1)
# Out:
# 0        -12.038207
# 1        137.873588
# 2        296.727273
# 3       1233.333333
# 4               NaN
#            ...
# 2995            NaN
# 2996            NaN
# 2997      37.625786
# 2998     309.436633
# 2999     134.534729
# Length: 3000, dtype: float64

# %%
def profit(a):
    try:
        p = ((a[22]-a[2])/a[2])*100
        return round(p,2)
    except:
        p = np.nan
        return p

# %%
df.apply(profit,axis = 1)
# Out:
# 0        -12.04
# 1        137.87
# 2        296.73
# 3       1233.33
# 4           NaN
#          ...
# 2995        NaN
# 2996        NaN
# 2997      37.63
# 2998     309.44
# 2999     134.53
# Length: 3000, dtype: float64

# %%
print(df['release_date'].dtype)
# Out:
# object

# %%
type(df.release_date[0])
# Out:
# str

# %%
from datetime import date

# %%
date.date_now()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 date.date_now()
#
# AttributeError: type object 'datetime.date' has no attribute 'date_now'

# %%
from datetime import time

# %%
time.time()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 time.time()
#
# AttributeError: type object 'datetime.time' has no attribute 'time'

# %%
print(date(1994,11,30))
# Out:
# 1994-11-30

# %%
from datetime import date

# %%
my_first_date = date(1993,12,30)
print(my_first_date)
# Out:
# 1993-12-30

# %%
print('my sencond date is',date(2022,11,30))
# Out:
# my sencond date is 2022-11-30

# %%
print('Today date in',date(2023,4,20))
# Out:
# Today date in 2023-04-20

# %%
print(date.today())
# Out:
# 2023-04-20

# %%
date.today().year
# Out:
# 2023

# %%
date.today().month
# Out:
# 4

# %%
date.today().day
# Out:
# 20

# %%
my_date = date.today()
my_date_string = date.strftime(my_date,'%y/%m/%d')
print(my_date_string)
print(type(my_date))
print(type(my_date_string))
# Out:
# 23/04/20
# <class 'datetime.date'>
# <class 'str'>

# %%
date.today()
# Out:
# datetime.date(2023, 4, 20)

# %%
my_date = date(2022,11,30)

# %%
my_date.year
# Out:
# 2022

# %%
my_date.month
# Out:
# 11

# %%
my_date.day
# Out:
# 30

# %%
x = date(2002,11,30)

# %%
print(x)
# Out:
# 2002-11-30

# %%
string_date = date.strftime(x,'%y-%m-%d')

# %%
string_date
# Out:
# '02-11-30'

# %%
stringed = date.strftime(x,'%Y/%m/%d')

# %%
stringed
# Out:
# '2002/11/30'

# %%
y = date(2025,11,30)

# %%
date.isoformat(y)
# Out:
# '2025-11-30'

# %%
from datetime import time

# %%
import time
time.localtime()
# Out:
# time.struct_time(tm_year=2023, tm_mon=4, tm_mday=20, tm_hour=13, tm_min=4, tm_sec=47, tm_wday=3, tm_yday=110, tm_isdst=0)

# %%
from datetime import time

# %%
print(time(1,23))
# Out:
# 01:23:00

# %%
samay = time(1,23,0)
print(samay)
# Out:
# 01:23:00

# %%
samay.hour
# Out:
# 1

# %%
samay.minute
# Out:
# 23

# %%
samay.second
# Out:
# 0

# %%
print(type(samay))
# Out:
# <class 'datetime.time'>

# %%
import time 
time = time.localtime()

# %%
from datetime import time 
t = time(1,31,2)

# %%
from datetime import time

# %%
time.strftime(t,"%H:%M:%S")
# Out:
# '01:31:02'

# %%
mytime = time(1,25,9)

# %%
print(mytime)
# Out:
# 01:25:09

# %%
mytime.hour
# Out:
# 1

# %%
mytime.minute
# Out:
# 25

# %%
mytime.second
# Out:
# 9

# %%
import time
time.localtime()
# Out:
# time.struct_time(tm_year=2023, tm_mon=4, tm_mday=20, tm_hour=13, tm_min=36, tm_sec=53, tm_wday=3, tm_yday=110, tm_isdst=0)

# %%
from datetime import time
time.strftime(mytime,'%H:%M:%S')
# Out:
# '01:25:09'

# %%
import time

t = time.localtime()
format_time = time.strftime('%H:%M:%S',t)
print(format_time)
# current_time = time.strftime("%H:%M:%S", t)
#print(t)
# Out:
# 13:39:46

# %%
x = time.localtime()
timed = time.strftime('%H:%M:%S',x)

# %%
timed
# Out:
# '13:40:33'

# %%
from datetime import date

# %%
date.today()
# Out:
# datetime.date(2023, 4, 20)

# %%
print(date(1993,11,29))
# Out:
# 1993-11-29

# %%
d = date(1994,12,31)

# %%
d.year
# Out:
# 1994

# %%
d.month
# Out:
# 12

# %%
d.day
# Out:
# 31

# %%
a=date.today()

# %%
print(date.strftime(a,'%Y/%m/%d'))
# Out:
# 2023/04/20

# %%
date.isoformat(a)
# Out:
# '2023-04-20'

# %%
from datetime import time

# %%
time(1,23,1)
# Out:
# datetime.time(1, 23, 1)

# %%
print(time(1,23,1))
# Out:
# 01:23:01

# %%
t = time(1,23,1)

# %%
t.hour
# Out:
# 1

# %%
t.minute
# Out:
# 23

# %%
t.second
# Out:
# 1

# %%
time.strftime(t,'%H:%M:%S')
# Out:
# '01:23:01'

# %%
import time

# %%
a=time.localtime()

# %%
time.strftime('%H:%M:%S')
# Out:
# '13:54:25'

# %%
import datetime

# %%
print(datetime.datetime.now().time())
# Out:
# 14:28:14.001768

# %%
datetime(2022,11,20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [142], in <cell line: 1>()
# ----> 1 datetime(2022,11,20)
#
# TypeError: 'module' object is not callable

# %%
from datetime import datetime

# %%
datetime(2022,11,20)
# Out:
# datetime.datetime(2022, 11, 20, 0, 0)

# %%
date = datetime(2022,2,21)

# %%
print(date)
# Out:
# 2022-02-21 00:00:00

# %%
import datetime
datetime.datetime.now().time()
# Out:
# datetime.time(14, 32, 39, 953184)

# %%
from datetime import datetime

# %%
datetime.datetime.now()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [151], in <cell line: 1>()
# ----> 1 datetime.datetime.now()
#
# AttributeError: type object 'datetime.datetime' has no attribute 'datetime'

# %%
datetime.now()
# Out:
# datetime.datetime(2023, 4, 20, 14, 33, 24, 789198)

# %%
datetime.now().time()
# Out:
# datetime.time(14, 33, 37, 41905)

# %%
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2023, 4, 20, 14, 38, 5, 920705)

# %%
datetime.now().time()
# Out:
# datetime.time(14, 38, 16, 978629)

# %%
datetime.now().date()
# Out:
# datetime.date(2023, 4, 20)

# %%
y = datetime(2023,4,20,2,45,0)

# %%
print(y)
# Out:
# 2023-04-20 02:45:00

# %%
stringed = '2023-04-20 02:45:00'

datetime.strftime(y,'%Y/%m/%d')
# Out:
# '2023/04/20'

# %%
datetime.strftime(y,'%y/%m/%d %H:%M:%S')
# Out:
# '23/04/20 02:45:00'

# %%
datetime.isoformat(y)
# Out:
# '2023-04-20T02:45:00'

# %%
y = datetime.now()

# %%
y.year
# Out:
# 2023

# %%
y.month
# Out:
# 4

# %%
y.day
# Out:
# 20

# %%
y.hour
# Out:
# 14

# %%
y.minute
# Out:
# 53

# %%
y.second
# Out:
# 7

# %%
t = datetime(1994,11,30,2,54,0)

# %%
print(t)
# Out:
# 1994-11-30 02:54:00

# %%
t.year,t.month,t.day,t.hour,t.minute,t.second
# Out:
# (1994, 11, 30, 2, 54, 0)

# %%
datetime.now()
# Out:
# datetime.datetime(2023, 4, 20, 14, 55, 29, 898323)

# %%
datetime.now().date()
# Out:
# datetime.date(2023, 4, 20)

# %%
datetime.now().time()
# Out:
# datetime.time(14, 55, 48, 865712)

# %%
a = datetime.now()

# %%
datetime.strftime(a,"%Y/%m/%d %H:%T:%S")
# Out:
# '2023/04/20 14:14:57:05:05'

# %%
a ='2023/04/20 14:14:57:05:05'
datetime.strptime(a,'%Y/%m/%d %H:%T:%S')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [204], in <cell line: 2>()
#       1 a ='2023/04/20 14:14:57:05:05'
# ----> 2 datetime.strptime(a,'%Y/%m/%d %H:%T:%S')
#
# File C:\ProgramData\Anaconda3\lib\_strptime.py:568, in _strptime_datetime(cls, data_string, format)
#     565 def _strptime_datetime(cls, data_string, format="%a %b %d %H:%M:%S %Y"):
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# File C:\ProgramData\Anaconda3\lib\_strptime.py:341, in _strptime(data_string, format)
#     339         bad_directive = "%"
#     340     del err
# --> 341     raise ValueError("'%s' is a bad directive in format '%s'" %
# ...

# %%
from datetime import datetime

# %%
y = '2002/02/22'
datetime.strptime(y,'%Y/%m/%d')
# Out:
# datetime.datetime(2002, 2, 22, 0, 0)

# %%
y = '2002/02/22 3:14:23'

# %%
print(datetime.strptime(y,'%Y/%m/%d %H:%M:%S'))
# Out:
# 2002-02-22 03:14:23

# %%
current = datetime.now()
d1 = datetime(2022,11,30)
d2 = datetime(1994,11,30)

# %%
d1-d2
# Out:
# datetime.timedelta(days=10227)

# %%
from datetime import timedelta

# %%
d1 + timedelta(days = 720)
# Out:
# datetime.datetime(2024, 11, 19, 0, 0)

# %%
d2 + timedelta(days = 365)
# Out:
# datetime.datetime(1995, 11, 30, 0, 0)

# %%
current + timedelta(days = 2)
# Out:
# datetime.datetime(2023, 4, 22, 15, 32, 46, 352229)

# %%
current + timedelta(days = 1,hours = 2,minutes = 45)
# Out:
# datetime.datetime(2023, 4, 21, 18, 17, 46, 352229)

# %%
df.release_date[0:5]
# Out:
# 0     2/20/15
# 1      8/6/04
# 2    10/10/14
# 3      3/9/12
# 4      2/5/09
# Name: release_date, dtype: object

# %%
df.release_date.apply(lambda x: datetime.strptime(x,'%m/%d/%y'))
# Out:
# 0      2015-02-20
# 1      2004-08-06
# 2      2014-10-10
# 3      2012-03-09
# 4      2009-02-05
#           ...
# 2995   1994-04-22
# 2996   2013-03-28
# 2997   1996-10-11
# 2998   2004-01-16
# 2999   2011-09-22
# Name: release_date, Length: 3000, dtype: datetime64[ns]

# %%
type(df.apply(lambda x: datetime.strptime(x.release_date,'%m/%d/%y'),axis = 1)[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
def caps(a):
    return a.upper()

# %%
caps('depu')
# Out:
# 'DEPU'

# %%
df.original_title.apply(caps)
# Out:
# 0                         HOT TUB TIME MACHINE 2
# 1       THE PRINCESS DIARIES 2: ROYAL ENGAGEMENT
# 2                                       WHIPLASH
# 3                                        KAHAANI
# 4                                           마린보이
#                           ...
# 2995                                     CHASERS
# 2996                                 VI ÄR BÄST!
# 2997                     THE LONG KISS GOODNIGHT
# 2998                            ALONG CAME POLLY
# 2999                                   ABDUCTION
# Name: original_title, Length: 3000, dtype: object

# %%
def x(a):
    return (datetime.strptime(a,'%m/%d/%y'))

# %%
df.release_date(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [236], in <cell line: 1>()
# ----> 1 df.release_date(x)
#
# TypeError: 'Series' object is not callable

# %%
df.status.unique()
# Out:
# array(['Released', 'Rumored'], dtype=object)

# %%
df.status.nunique()
# Out:
# 2

# %%
df.status.value_counts()
# Out:
# Released    2996
# Rumored        4
# Name: status, dtype: int64

# %%
df.homepage.isnull().sum()
# Out:
# 2054

# %% [markdown]
# # Datetime module

# %%
#date

# %%
from datetime import date

# %%
d = date(2023,11,29)
print(d)
# Out:
# 2023-11-29

# %%
d.year,d.month,d.day
# Out:
# (2023, 11, 29)

# %%
x = '2023-11-29'
dt = date.strftime(d,'%Y-%m-%d')

# %%
dt
# Out:
# '2023-11-29'

# %%
dt1 = date.isoformat(d)

# %%
dt1
# Out:
# '2023-11-29'

# %%
date.today()
# Out:
# datetime.date(2023, 4, 21)

# %%
from datetime import time

# %%
time.localtime()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 time.localtime()
#
# AttributeError: type object 'datetime.time' has no attribute 'localtime'

# %%
import time 
time.localtime()
# Out:
# time.struct_time(tm_year=2023, tm_mon=4, tm_mday=21, tm_hour=13, tm_min=41, tm_sec=27, tm_wday=4, tm_yday=111, tm_isdst=0)

# %%
from datetime import time
print(time(1,44,5))
# Out:
# 01:44:05

# %%
t = time(2,9,3)

# %%
t.hour,t.minute,t.second
# Out:
# (2, 9, 3)

# %%
t = time(2)

# %%
t
# Out:
# datetime.time(2, 0)

# %%
print(t)
# Out:
# 02:00:00

# %%
time(minute = 23)
# Out:
# datetime.time(0, 23)

# %%
import time

# %%
a=time.localtime()

# %%
time.strftime('%H:%M:%S',a)
# Out:
# '14:12:17'

# %%
from datetime import time 
t = time(2,13,0)

# %%
time.strftime(t,'%H:%M:%S')
# Out:
# '02:13:00'

# %%
from datetime import datetime

# %%
dt = datetime(2023,4,21,2,23,4,99)

# %%
print(dt)
# Out:
# 2023-04-21 02:23:04.000099

# %%
dt.year,dt.month,dt.day,dt.hour,dt.minute,dt.second
# Out:
# (2023, 4, 21, 2, 23, 4)

# %%
datetime.now()
# Out:
# datetime.datetime(2023, 4, 21, 14, 24, 42, 959872)

# %%
datetime.now().date()
# Out:
# datetime.date(2023, 4, 21)

# %%
datetime.now().time()
# Out:
# datetime.time(14, 25, 17, 867115)

# %%
datetime.strftime(dt,'%Y-%m-%d')
# Out:
# '2023-04-21'

# %%
b=datetime.strftime(dt,'%Y-%m-%d %H:%M:%S')

# %%
c=datetime.now()

# %%
datetime.strptime(b,'%Y-%m-%d %H:%M:%S')
# Out:
# datetime.datetime(2023, 4, 21, 2, 23, 4)

# %%
d1 = date(2023,4,21)
d2 = date(2022,4,21)
d1-d2
# Out:
# datetime.timedelta(days=365)

# %%
from datetime import timedelta

# %%
c=datetime.now()

# %%
a = c + timedelta(days = 365)
print(a)
# Out:
# 2024-04-20 14:32:15.499110

# %%
b = c - timedelta(hours = 2)
print(b)
# Out:
# 2023-04-21 12:32:15.499110

# %%
df['release_date']
# Out:
# 0        2/20/15
# 1         8/6/04
# 2       10/10/14
# 3         3/9/12
# 4         2/5/09
#           ...
# 2995     4/22/94
# 2996     3/28/13
# 2997    10/11/96
# 2998     1/16/04
# 2999     9/22/11
# Name: release_date, Length: 3000, dtype: object

# %%
from datetime import datetime
def to_date(x):
    y = datetime.strptime(x,'%m/%d/%y')
    return y

# %%
x = '2/20/15'
to_date(x)
# Out:
# datetime.datetime(2015, 2, 20, 0, 0)

# %%
df['Date']=df.apply(lambda x : to_date(x.release_date),axis = 1)

# %%
df[['release_date','Date']]
# Out:
#      release_date       Date
# 0         2/20/15 2015-02-20
# 1          8/6/04 2004-08-06
# 2        10/10/14 2014-10-10
# 3          3/9/12 2012-03-09
# 4          2/5/09 2009-02-05
# ...           ...        ...
# 2995      4/22/94 1994-04-22
# 2996      3/28/13 2013-03-28
# 2997     10/11/96 1996-10-11
# 2998      1/16/04 2004-01-16
# 2999      9/22/11 2011-09-22
#
# [3000 rows x 2 columns]

# %%
df.drop({'Date'},axis = 1)
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
df['Year'] = df.apply(lambda x: datetime.strptime(x.release_date,'%m/%d/%y').year,axis = 1)

# %%
df.Year
# Out:
# 0       2015
# 1       2004
# 2       2014
# 3       2012
# 4       2009
#         ...
# 2995    1994
# 2996    2013
# 2997    1996
# 2998    2004
# 2999    2011
# Name: Year, Length: 3000, dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue',
#        'Date', 'month', 'Year'],
#       dtype='object')

# %%
df.drop({'Year','month'},axis = 1,inplace = True)

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue',
#        'Date'],
#       dtype='object')

# %%
def gen_date(x):
    date_f = datetime.strptime(x,'%m/%d/%y')
    return date_f

# %%
df.release_date.apply(gen_date)
# Out:
# 0      2015-02-20
# 1      2004-08-06
# 2      2014-10-10
# 3      2012-03-09
# 4      2009-02-05
#           ...
# 2995   1994-04-22
# 2996   2013-03-28
# 2997   1996-10-11
# 2998   2004-01-16
# 2999   2011-09-22
# Name: release_date, Length: 3000, dtype: datetime64[ns]

# %%
df.apply(lambda x: gen_date(x.release_date),axis = 1)
# Out:
# 0      2015-02-20
# 1      2004-08-06
# 2      2014-10-10
# 3      2012-03-09
# 4      2009-02-05
#           ...
# 2995   1994-04-22
# 2996   2013-03-28
# 2997   1996-10-11
# 2998   2004-01-16
# 2999   2011-09-22
# Length: 3000, dtype: datetime64[ns]

# %%
def cust_date(a):
    y = datetime.strptime(a.release_date,'%m/%d/%y')
    return y

# %%
df.apply(cust_date,axis = 1)
# Out:
# 0      2015-02-20
# 1      2004-08-06
# 2      2014-10-10
# 3      2012-03-09
# 4      2009-02-05
#           ...
# 2995   1994-04-22
# 2996   2013-03-28
# 2997   1996-10-11
# 2998   2004-01-16
# 2999   2011-09-22
# Length: 3000, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
df.Date.dtype
# Out:
# dtype('<M8[ns]')

# %%
df.Date[1]
# Out:
# Timestamp('2004-08-06 00:00:00')

# %%
df.drop({'Date'},axis =1,inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
df['date'] = df.apply(lambda x : datetime.strptime(x.release_date,'%m/%d/%y').date(),axis = 1)

# %%
df['date'][1]
# Out:
# datetime.date(2004, 8, 6)

# %%
#Create the data
data = {'TimeStamp': [pd._libs.tslibs.timestamps.Timestamp('2013-01-03 00:00:00', tz=None), pd._libs.tslibs.timestamps.Timestamp('2013-01-04 00:00:00', tz=None), pd._libs.tslibs.timestamps.Timestamp('2013-01-03 00:00:00', tz=None)]}

#convert to df
dfs=pd.DataFrame(data,index = [1,2,3])
display(dfs)
dfs['Date'] = dfs['TimeStamp'].apply(lambda x: datetime.date(x.year,x.month,x.day))
display(dfs)
# Out:
#    TimeStamp
# 1 2013-01-03
# 2 2013-01-04
# 3 2013-01-03
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [117], in <cell line: 7>()
#       5 dfs=pd.DataFrame(data,index = [1,2,3])
#       6 display(dfs)
# ----> 7 dfs['Date'] = dfs['TimeStamp'].apply(lambda x: datetime.date(x.year,x.month,x.day))
#       8 display(dfs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# ...

# %%
#Another way to create the same dataframe 
#Create the data
data = {1: pd._libs.tslibs.timestamps.Timestamp('2013-01-03 00:00:00', tz=None), 2: pd._libs.tslibs.timestamps.Timestamp('2013-01-04 00:00:00', tz=None), 3: pd._libs.tslibs.timestamps.Timestamp('2013-01-03 00:00:00', tz=None)}

#convert to df
df = pd.DataFrame.from_dict(data, orient = 'index')# defining index
df.columns = ['timestamp'] # defining column

#generate the datetime
df['datetime'] = df['timestamp'].apply(lambda x: datetime.date(x.year,x.month,x.day)) # converting time stamp into date
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [118], in <cell line: 10>()
#       7 df.columns = ['timestamp'] # defining column
#       9 #generate the datetime
# ---> 10 df['datetime'] = df['timestamp'].apply(lambda x: datetime.date(x.year,x.month,x.day))
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py:1082, in SeriesApply.apply(self)
# ...

# %%
import time

# %%
t=time.localtime()

# %%
from datetime import time 
time.strftime(t,'%H:%M:%S')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [126], in <cell line: 2>()
#       1 from datetime import time
# ----> 2 time.strftime(t,'%H:%M:%S')
#
# TypeError: descriptor 'strftime' for 'datetime.time' objects doesn't apply to a 'time.struct_time' object

# %%
t
# Out:
# time.struct_time(tm_year=2023, tm_mon=4, tm_mday=21, tm_hour=16, tm_min=15, tm_sec=53, tm_wday=4, tm_yday=111, tm_isdst=0)

# %%
time.strftime(t)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [131], in <cell line: 1>()
# ----> 1 time.strftime(t)
#
# TypeError: descriptor 'strftime' for 'datetime.time' objects doesn't apply to a 'time.struct_time' object

# %%
ts = pd.Timestamp('2016-12-19')
ts
# Out:
# Timestamp('2016-12-19 00:00:00')

# %%
pd.to_datetime(df.release_date)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [136], in <cell line: 1>()
# ----> 1 pd.to_datetime(df.release_date)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'release_date'

# %%
df
# Out:
#    timestamp
# 1 2013-01-03
# 2 2013-01-04
# 3 2013-01-03

# %%
pd.to_datetime('2023-4-21')
# Out:
# Timestamp('2023-04-21 00:00:00')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
pd.to_datetime(df.release_date)
# Out:
# 0      2015-02-20
# 1      2004-08-06
# 2      2014-10-10
# 3      2012-03-09
# 4      2009-02-05
#           ...
# 2995   1994-04-22
# 2996   2013-03-28
# 2997   1996-10-11
# 2998   2004-01-16
# 2999   2011-09-22
# Name: release_date, Length: 3000, dtype: datetime64[ns]

# %%
x='2015-02-20'
pd.to_datetime(x)
# Out:
# Timestamp('2015-02-20 00:00:00')

# %%
pd.to_timestamp(x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 pd.to_timestamp(x)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\__init__.py:261, in __getattr__(name)
#     257     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     259     return _SparseArray
# --> 261 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'to_timestamp'

# %%
pd.Timestamp(x)
# Out:
# Timestamp('2015-02-20 00:00:00')

# %%
df['date'] = pd.to_datetime(df.release_date)

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue',
#        'date'],
#       dtype='object')

# %%
(df.date[0] - df.date[1])
# Out:
# Timedelta('3850 days 00:00:00')

# %%
from datetime import timedelta

# %%
pd.Timedelta(df.date[0]-df.date[1]).seconds
# Out:
# 0

# %%
d1=pd.to_datetime('2023-04-22 1:44:20')
d2=pd.to_datetime('2023-04-21 0:00:00')

# %%
d1-d2
# Out:
# Timedelta('1 days 01:44:20')

# %%
(d1-d2).seconds
# Out:
# 6260

# %%
df.status.unique()
# Out:
# array(['Released', 'Rumored'], dtype=object)

# %%
df['original_language'].unique()
# Out:
# array(['en', 'hi', 'ko', 'sr', 'fr', 'it', 'nl', 'zh', 'es', 'cs', 'ta',
#        'cn', 'ru', 'tr', 'ja', 'fa', 'sv', 'de', 'te', 'pt', 'mr', 'da',
#        'fi', 'el', 'ur', 'he', 'no', 'ar', 'nb', 'ro', 'vi', 'pl', 'hu',
#        'ml', 'bn', 'id'], dtype=object)

# %%
df['original_language'].value_counts(ascending = False)
# Out:
# en    2575
# fr      78
# ru      47
# es      43
# hi      42
# ja      37
# it      24
# cn      20
# ko      20
# zh      19
# de      18
# ta      16
# sv       8
# nl       6
# pt       6
# fa       5
# da       5
# ro       4
# hu       3
# tr       3
# no       2
# ml       2
# pl       2
# te       2
# fi       2
# ur       1
# he       1
# el       1
# ar       1
# nb       1
# vi       1
# mr       1
# cs       1
# sr       1
# bn       1
# id       1
# Name: original_language, dtype: int64

# %%
df.original_language.nunique()
# Out:
# 36

# %%
df.status.value_counts(ascending = True)
# Out:
# Rumored        4
# Released    2996
# Name: status, dtype: int64

# %%
df['runtime'].unique()
# Out:
# array([ 93., 113., 105., 122., 118.,  83.,  92.,  84., 100.,  91., 119.,
#         98., 145.,  97.,  85., 111.,  96.,  87., 130.,  95., 116., 110.,
#         89., 112., 117., 106., 125.,  94., 127.,  90., 123., 126., 108.,
#         88., 167., 102., 160., 107., 144., 124., 115., 133., 129., 104.,
#        103., 157., 109., 135., 147.,  72., 158., 120., 121., 177., 189.,
#        178.,  86.,  79., 176., 101.,  99.,  74., 141.,  65., 136., 143.,
#        132.,  53., 139., 114., 140., 156., 148., 137., 168., 154.,  77.,
#         76., 163.,   0., 155.,  82., 150., 149., 170.,  80., 152., 128.,
#        131., 220., 181., 179., 180.,  81., 161., 162., 134., 193.,  71.,
#        188., 212., 142., 146., 151., 171.,  75.,  40., 165.,  78., 185.,
#        138., 153.,  60., 175., 338., 219.,  nan, 183.,  73., 186., 199.,
#         68., 214., 248., 159., 207., 187., 197., 164., 169., 172.,  66.,
#         63., 213.,  62.,  11., 174.,  69., 191., 182.])

# %%
df.runtime.nunique()
# Out:
# 139

# %%
df.runtime.value_counts()
# Out:
# 90.0     100
# 100.0     99
# 105.0     91
# 95.0      89
# 98.0      85
#         ...
# 220.0      1
# 60.0       1
# 53.0       1
# 185.0      1
# 182.0      1
# Name: runtime, Length: 139, dtype: int64

# %%
df.homepage.isnull().value_counts()
# Out:
# True     2054
# False     946
# Name: homepage, dtype: int64

# %%
df['homepage'].isnull().sum()
# Out:
# 2054

# %%
~df['homepage'].isnull().sum()
# Out:
# -2055

# %%
df.homepage.notnull().sum()
# Out:
# 946

# %%
df.homepage.isnull().sum()
# Out:
# 2054

# %%
df[df.notnull()]
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
df.homepage.isnull().sum()
# Out:
# 2054

# %%
df[~df.homepage.isnull()]
# Out:
#         id                              belongs_to_collection    budget  \
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 6        7                                                NaN  14000000
# 12      13                                                NaN  15000000
# 15      16                                                NaN    500000
# ...    ...                                                ...       ...
# 2984  2985  [{'id': 221111, 'name': 'S.W.A.T. Collection',...  80000000
# 2985  2986                                                NaN  37665000
# 2993  2994                                                NaN  60000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
df[df.homepage.notnull()]
# Out:
#         id                              belongs_to_collection    budget  \
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 6        7                                                NaN  14000000
# 12      13                                                NaN  15000000
# 15      16                                                NaN    500000
# ...    ...                                                ...       ...
# 2984  2985  [{'id': 221111, 'name': 'S.W.A.T. Collection',...  80000000
# 2985  2986                                                NaN  37665000
# 2993  2994                                                NaN  60000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
df.budget.isnull().sum()
# Out:
# 0

# %%
df.revenue.isnull().sum()
# Out:
# 0

# %%
df[~df.homepage.isnull()].sum()
# Out:
# C:\Users\Deepu\AppData\Local\Temp\ipykernel_13844\137541245.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df[~df.homepage.isnull()].sum()
# id                                                             1412016
# budget                                                     34093135115
# homepage             http://sonyclassics.com/whiplash/http://kahaan...
# imdb_id              tt2582802tt1821480tt0431021tt0169547tt1129437t...
# original_language    enhienensrenenenfrenenenenenenennlenfrenenenes...
# original_title       WhiplashKahaaniThe PossessionAmerican BeautyŠi...
# overview             Under the direction of a ruthless instructor, ...
# popularity                                                10786.294673
# poster_path          /lIv1QinFqz4dlp5U4lQ6HaiskOZ.jpg/aTXRaPrWSinhc...
# ...

# %%
df.dropna(axis = 0)
# Out:
#         id                              belongs_to_collection     budget  \
# 22      23  [{'id': 207621, 'name': 'V/H/S Collection', 'p...          0
# 40      41  [{'id': 376970, 'name': 'Cocaine Cowboys', 'po...          0
# 46      47  [{'id': 8354, 'name': 'Ice Age Collection', 'p...   80000000
# 60      61  [{'id': 645, 'name': 'James Bond Collection', ...  150000000
# 69      70  [{'id': 9485, 'name': 'The Fast and the Furiou...   85000000
# ...    ...                                                ...        ...
# 2904  2905  [{'id': 424202, 'name': 'Trainspotting Collect...    4000000
# 2927  2928  [{'id': 645, 'name': 'James Bond Collection', ...  140000000
# 2938  2939  [{'id': 135416, 'name': 'Prometheus Collection...  130000000
# 2968  2969  [{'id': 97307, 'name': 'BloodRayne Collection'...   25000000
# 2984  2985  [{'id': 221111, 'name': 'S.W.A.T. Collection',...   80000000
#
#                                                  genres  \
# ...

# %%
df.dropna(axis = 1)
# Out:
#         id    budget    imdb_id original_language  \
# 0        1  14000000  tt2637294                en
# 1        2  40000000  tt0368933                en
# 2        3   3300000  tt2582802                en
# 3        4   1200000  tt1821480                hi
# 4        5         0  tt1380152                ko
# ...    ...       ...        ...               ...
# 2995  2996         0  tt0109403                en
# 2996  2997         0  tt2364975                sv
# 2997  2998  65000000  tt0116908                en
# 2998  2999  42000000  tt0343135                en
# 2999  3000  35000000  tt1600195                en
#
#                                 original_title  popularity release_date  \
# 0                       Hot Tub Time Machine 2    6.575393      2/20/15
# 1     The Princess Diaries 2: Royal Engagement    8.248895       8/6/04
# 2                                     Whiplash   64.299990     10/10/14
# ...

# %%
df.belongs_to_collection.isnull().sum()
# Out:
# 2396

# %%
df.belongs_to_collection.notnull().sum()
# Out:
# 604

# %%
df[~df.belongs_to_collection.isnull()]
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 8        9  [{'id': 256377, 'name': 'The Muppet Collection...         0
# 10      11  [{'id': 1575, 'name': 'Rocky Collection', 'pos...   1000000
# 11      12  [{'id': 48190, 'name': 'Revenge of the Nerds C...         0
# ...    ...                                                ...       ...
# 2967  2968  [{'id': 387219, 'name': 'The Hustler Collectio...   2000000
# 2968  2969  [{'id': 97307, 'name': 'BloodRayne Collection'...  25000000
# 2974  2975  [{'id': 149704, 'name': 'Alone in the Dark Col...  20000000
# 2984  2985  [{'id': 221111, 'name': 'S.W.A.T. Collection',...  80000000
# 2991  2992  [{'id': 107469, 'name': 'Save The Last Dance C...  13000000
#
#                                                  genres  \
# ...

# %%
df.homepage.isnull().sum()
# Out:
# 2054

# %%
df.homepage.fillna('no link available')
# Out:
# 0                       no link available
# 1                       no link available
# 2       http://sonyclassics.com/whiplash/
# 3              http://kahaanithefilm.com/
# 4                       no link available
#                       ...
# 2995                    no link available
# 2996                    no link available
# 2997                    no link available
# 2998       http://www.alongcamepolly.com/
# 2999     http://www.abductionthefilm.com/
# Name: homepage, Length: 3000, dtype: object

# %%
df.homepage.fillna(df.budget.mean())
# Out:
# 0                             22531334.11
# 1                             22531334.11
# 2       http://sonyclassics.com/whiplash/
# 3              http://kahaanithefilm.com/
# 4                             22531334.11
#                       ...
# 2995                          22531334.11
# 2996                          22531334.11
# 2997                          22531334.11
# 2998       http://www.alongcamepolly.com/
# 2999     http://www.abductionthefilm.com/
# Name: homepage, Length: 3000, dtype: object

# %% [markdown]
# # Sort values ascending/descending

# %%
df.sort_values('runtime',ascending = True)
# Out:
#         id                              belongs_to_collection    budget  \
# 2785  2786                                                NaN         0
# 2865  2866  [{'id': 188197, 'name': 'Cetto La Qualunque - ...   5579750
# 2645  2646                                                NaN         0
# 591    592                                                NaN         0
# 390    391                                                NaN   6843500
# ...    ...                                                ...       ...
# 523    524                                                NaN  13000000
# 1922  1923                                                NaN  31115000
# 1211  1212                                                NaN  18000000
# 1335  1336                                                NaN   6000000
# 2302  2303                                                NaN         0
#
#                                                  genres homepage    imdb_id  \
# ...

# %%
df.set_index('imdb_id',inplace = True)

# %%
df
# Out:
#              id                              belongs_to_collection    budget  \
# imdb_id
# tt2637294     1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# tt0368933     2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# tt2582802     3                                                NaN   3300000
# tt1821480     4                                                NaN   1200000
# tt1380152     5                                                NaN         0
# ...         ...                                                ...       ...
# tt0109403  2996                                                NaN         0
# tt2364975  2997                                                NaN         0
# tt0116908  2998                                                NaN  65000000
# tt0343135  2999                                                NaN  42000000
# tt1600195  3000                                                NaN  35000000
#
# ...

# %%
df.loc['tt0116908':'tt1600195',:]
# Out:
#              id belongs_to_collection    budget  \
# imdb_id
# tt0116908  2998                   NaN  65000000
# tt0343135  2999                   NaN  42000000
# tt1600195  3000                   NaN  35000000
#
#                                                       genres  \
# imdb_id
# tt0116908  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# tt0343135  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# tt1600195  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                                    homepage original_language  \
# imdb_id
# tt0116908                               NaN                en
# tt0343135    http://www.alongcamepolly.com/                en
# tt1600195  http://www.abductionthefilm.com/                en
#
#                     original_title  \
# imdb_id
# tt0116908  The Long Kiss Goodnight
# tt0343135         Along Came Polly
# tt1600195                Abduction
#
#                                                     overview  popularity  \
# ...

# %%
df.drop_index('imdb_id')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [133], in <cell line: 1>()
# ----> 1 df.drop_index('imdb_id')
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'drop_index'

# %%
df.reset_index(drop = 'imdb_id',inplace = True)

# %%
df.drop(['id'],axis = 1)
# Out:
#                                   belongs_to_collection    budget  \
# 0     [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1     [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2                                                   NaN   3300000
# 3                                                   NaN   1200000
# 4                                                   NaN         0
# ...                                                 ...       ...
# 2995                                                NaN         0
# 2996                                                NaN         0
# 2997                                                NaN  65000000
# 2998                                                NaN  42000000
# 2999                                                NaN  35000000
#
#                                                  genres  \
# 0                        [{'id': 35, 'name': 'Comedy'}]
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# ...

# %%
df[df.budget>df.revenue]
# Out:
#         id belongs_to_collection    budget  \
# 5        6                   NaN   8000000
# 15      16                   NaN    500000
# 18      19                   NaN   8000000
# 27      28                   NaN  11000000
# 28      29                   NaN   6000000
# ...    ...                   ...       ...
# 2977  2978                   NaN  53000000
# 2982  2983                   NaN    500000
# 2983  2984                   NaN  35000000
# 2985  2986                   NaN  37665000
# 2986  2987                   NaN  20000000
#
#                                                  genres  \
# 5     [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 15    [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 18    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 27    [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 28                    [{'id': 16, 'name': 'Animation'}]
# ...                                                 ...
# ...

# %%
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
df.iloc[1,2]
# Out:
# 40000000

# %%
df.iloc[1:3,1:4]
# Out:
#                                belongs_to_collection    budget  \
# 1  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2                                                NaN   3300000
#
#                                               genres
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]

# %%
df.loc[1:4,['revenue','budget']]
# Out:
#     revenue    budget
# 1  95149435  40000000
# 2  13092000   3300000
# 3  16000000   1200000
# 4   3923970         0

# %%
df.loc[:5,['homepage':]]
# Out:
#   Input In [14]
#     df.loc[:5,['homepage':]]
#                          ^
# SyntaxError: invalid syntax

# %%
df.loc[:5,'homepage':]
# Out:
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
# 5                                NaN  tt0093743                en
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
# 5    Pinocchio and the Emperor of the Night
#
#                                             overview  popularity  \
# 0  When Lou, who has become the "father of the In...    6.575393
# ...

# %%
df.loc[1:2,'homepage':'popularity']
# Out:
#                             homepage    imdb_id original_language  \
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
#
#                              original_title  \
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
#
#                                             overview  popularity
# 1  Mia Thermopolis is now a college graduate and ...    8.248895
# 2  Under the direction of a ruthless instructor, ...   64.299990

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
df.loc[1:2,'homepage':'budget':-1]
# Out:
#                             homepage  \
# 1                                NaN
# 2  http://sonyclassics.com/whiplash/
#
#                                               genres    budget
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  40000000
# 2                      [{'id': 18, 'name': 'Drama'}]   3300000

# %%
df.loc[10:20,['revenue','budget','homepage','original_title']]
# Out:
#       revenue     budget                               homepage  \
# 10  117235147    1000000                                    NaN
# 11   22642033          0                                    NaN
# 12  356296601   15000000          http://www.dreamworks.com/ab/
# 13   95226116   53000000                                    NaN
# 14  358372926  102000000                                    NaN
# 15        198     500000  http://skinningmovie.com/synopsis.htm
# 16   57891803   26000000                                    NaN
# 17    1234254          0                                    NaN
# 18    1749457    8000000                                    NaN
# 19   85167639   32000000                                    NaN
# 20  136159423   80000000                                    NaN
#
#                                 original_title
# 10                                       Rocky
# 11  Revenge of the Nerds II: Nerds in Paradise
# 12                             American Beauty
# ...

# %%
df[:]
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
df['original_title']
# Out:
# 0                         Hot Tub Time Machine 2
# 1       The Princess Diaries 2: Royal Engagement
# 2                                       Whiplash
# 3                                        Kahaani
# 4                                           마린보이
#                           ...
# 2995                                     Chasers
# 2996                                 Vi är bäst!
# 2997                     The Long Kiss Goodnight
# 2998                            Along Came Polly
# 2999                                   Abduction
# Name: original_title, Length: 3000, dtype: object

# %%
df[['original_title','original_language','budget','revenue']]
# Out:
#                                 original_title original_language    budget  \
# 0                       Hot Tub Time Machine 2                en  14000000
# 1     The Princess Diaries 2: Royal Engagement                en  40000000
# 2                                     Whiplash                en   3300000
# 3                                      Kahaani                hi   1200000
# 4                                         마린보이                ko         0
# ...                                        ...               ...       ...
# 2995                                   Chasers                en         0
# 2996                               Vi är bäst!                sv         0
# 2997                   The Long Kiss Goodnight                en  65000000
# 2998                          Along Came Polly                en  42000000
# 2999                                 Abduction                en  35000000
#
#         revenue
# 0      12314651
# 1      95149435
# ...

# %%
df[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df[2:5]
# Out:
#    id belongs_to_collection   budget  \
# 2   3                   NaN  3300000
# 3   4                   NaN  1200000
# 4   5                   NaN        0
#
#                                               genres  \
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#   original_title                                           overview  \
# 2       Whiplash  Under the direction of a ruthless instructor, ...
# 3        Kahaani  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...
# 4           마린보이  Marine Boy is the story of a former national s...
#
#    popularity  ... release_date runtime  \
# ...

# %%
df[['homepage','budget']]
# Out:
#                                homepage    budget
# 0                                   NaN  14000000
# 1                                   NaN  40000000
# 2     http://sonyclassics.com/whiplash/   3300000
# 3            http://kahaanithefilm.com/   1200000
# 4                                   NaN         0
# ...                                 ...       ...
# 2995                                NaN         0
# 2996                                NaN         0
# 2997                                NaN  65000000
# 2998     http://www.alongcamepolly.com/  42000000
# 2999   http://www.abductionthefilm.com/  35000000
#
# [3000 rows x 2 columns]

# %%
df[2:5]
# Out:
#    id belongs_to_collection   budget  \
# 2   3                   NaN  3300000
# 3   4                   NaN  1200000
# 4   5                   NaN        0
#
#                                               genres  \
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#   original_title                                           overview  \
# 2       Whiplash  Under the direction of a ruthless instructor, ...
# 3        Kahaani  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...
# 4           마린보이  Marine Boy is the story of a former national s...
#
#    popularity  ... release_date runtime  \
# ...

# %%
df.loc[df['original_language'] == 'en',['original_title','original_language']]
# Out:
#                                 original_title original_language
# 0                       Hot Tub Time Machine 2                en
# 1     The Princess Diaries 2: Royal Engagement                en
# 2                                     Whiplash                en
# 5       Pinocchio and the Emperor of the Night                en
# 6                               The Possession                en
# ...                                        ...               ...
# 2994                               School Ties                en
# 2995                                   Chasers                en
# 2997                   The Long Kiss Goodnight                en
# 2998                          Along Came Polly                en
# 2999                                 Abduction                en
#
# [2575 rows x 2 columns]

# %%
df[(df['original_language'] == 'en') & (df['runtime'] == 120)]
# Out:
#         id                              belongs_to_collection     budget  \
# 99     100                                                NaN    6000000
# 129    130                                                NaN    2400000
# 230    231                                                NaN  110000000
# 279    280                                                NaN   65000000
# 351    352  [{'id': 645, 'name': 'James Bond Collection', ...    7200000
# 470    471                                                NaN    2000000
# 551    552                                                NaN   49000000
# 596    597  [{'id': 107725, 'name': 'Creepshow Collection'...    8000000
# 712    713                                                NaN   40000000
# 837    838  [{'id': 8945, 'name': 'Mad Max Collection', 'p...  150000000
# 846    847                                                NaN   20000000
# 914    915                                                NaN    9000000
# ...

# %%
df[1:2] = np.nan

# %%
df[1:2]
# Out:
#    id belongs_to_collection  budget genres homepage imdb_id original_language  \
# 1 NaN                   NaN     NaN    NaN      NaN     NaN               NaN
#
#   original_title overview  popularity  ... release_date runtime  \
# 1            NaN      NaN         NaN  ...          NaN     NaN
#
#   spoken_languages status  tagline title Keywords cast crew revenue
# 1              NaN    NaN      NaN   NaN      NaN  NaN  NaN     NaN
#
# [1 rows x 23 columns]

# %%
df.budget.max()
# Out:
# 380000000

# %%
df.budget.min()
# Out:
# 0

# %%
df['budget'].unique()
# Out:
# array([ 14000000,  40000000,   3300000,   1200000,         0,   8000000,
#          6000000,   1000000,  15000000,  53000000, 102000000,    500000,
#         26000000,  32000000,  80000000,   4000000,  10000000,  11000000,
#         45000000,  13000000,  90000000, 140000000,  30000000,  50000000,
#          3800000,   3000000,  25000000,   3906840,  44000000,  38000000,
#           560000,  12000000,  20000000, 125000000, 150000000,   5000000,
#          1500000,   2000000,  85000000,  29000000,    445000,  17000000,
#         10284523,  43000000,  28000000,   7500000,  35000000,   2500000,
#         10500000,   7000000,  60000000,  10900000,  31000000,  72000000,
#         75000000, 100000000,  93000000,  12716953,  18000000,   2400000,
#         65000000,   9000000, 110000000,  14320000,   3500000,  39200000,
#         63600000,    125000,  19000000,  12468389,  82500000,    259000,
#        180000000,   4500000,  24000000,  12600000,  55000000,   3200000,
# ...

# %%
df.original_language.unique()
# Out:
# array(['en', 'hi', 'ko', 'sr', 'fr', 'it', 'nl', 'zh', 'es', 'cs', 'ta',
#        'cn', 'ru', 'tr', 'ja', 'fa', 'sv', 'de', 'te', 'pt', 'mr', 'da',
#        'fi', 'el', 'ur', 'he', 'no', 'ar', 'nb', 'ro', 'vi', 'pl', 'hu',
#        'ml', 'bn', 'id'], dtype=object)

# %%
df.original_language.nunique()
# Out:
# 36

# %%
df['original_language'].value_counts(ascending = True)
# Out:
# id       1
# mr       1
# bn       1
# he       1
# el       1
# ar       1
# cs       1
# nb       1
# ur       1
# vi       1
# sr       1
# pl       2
# te       2
# ml       2
# fi       2
# no       2
# tr       3
# hu       3
# ro       4
# fa       5
# da       5
# nl       6
# pt       6
# sv       8
# ta      16
# de      18
# zh      19
# cn      20
# ko      20
# it      24
# ja      37
# hi      42
# es      43
# ru      47
# fr      78
# en    2575
# Name: original_language, dtype: int64

# %%
df['profit'] = df['revenue'] - df['budget']

# %%
df['profit']
# Out:
# 0        -1685349
# 1        55149435
# 2         9792000
# 3        14800000
# 4         3923970
#           ...
# 2995      1596687
# 2996       180590
# 2997     24456761
# 2998    129963386
# 2999     47087155
# Name: profit, Length: 3000, dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue',
#        'profit'],
#       dtype='object')

# %%
df.roi = df.revenue/df.budget
# Out:
# C:\Users\Deepu\AppData\Local\Temp\ipykernel_10028\3895919879.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.roi = df.revenue/df.budget

# %%
df['roi'] = df['revenue']/df['budget']

# %%
df.roi
# Out:
# 0        0.879618
# 1        2.378736
# 2        3.967273
# 3       13.333333
# 4             inf
#           ...
# 2995          inf
# 2996          inf
# 2997     1.376258
# 2998     4.094366
# 2999     2.345347
# Length: 3000, dtype: float64

# %%
df['halftime'] = df['runtime']*0.5

# %%
df.halftime
# Out:
# 0       46.5
# 1       56.5
# 2       52.5
# 3       61.0
# 4       59.0
#         ...
# 2995    51.0
# 2996    51.0
# 2997    60.0
# 2998    45.0
# 2999    53.0
# Name: halftime, Length: 3000, dtype: float64

# %%
df.drop(['halftime','roi','profit',],axis = 1,inplace = True)

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
df[(df.original_language == 'en') | (df.original_language == 'hi')]
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 5        6                                                NaN   8000000
# ...    ...                                                ...       ...
# 2994  2995                                                NaN         0
# 2995  2996                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
df[df['original_language'] != 'en']
# Out:
#         id belongs_to_collection    budget  \
# 3        4                   NaN   1200000
# 4        5                   NaN         0
# 15      16                   NaN    500000
# 30      31                   NaN  13000000
# 31      32                   NaN         0
# ...    ...                   ...       ...
# 2963  2964                   NaN         0
# 2972  2973                   NaN         0
# 2980  2981                   NaN    300000
# 2988  2989                   NaN         0
# 2996  2997                   NaN         0
#
#                                                  genres  \
# 3     [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4     [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 15    [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 30    [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 31    [{'id': 9648, 'name': 'Mystery'}, {'id': 18, '...
# ...                                                 ...
# ...

# %%
df.loc[((df['original_language'] == 'en')| (df['original_language'] == 'hi')),['original_title','original_language']].sort_values('original_language',ascending = False)
# Out:
#                             original_title original_language
# 1004                                 Dabba                hi
# 1732                           Grand Masti                hi
# 2480                              Cocktail                hi
# 2567                        Gabbar Is Back                hi
# 419                   Atithi Tum Kab Jaoge                hi
# ...                                    ...               ...
# 1008  Friday the 13th Part VI: Jason Lives                en
# 1009                             Tombstone                en
# 1010                            Trainwreck                en
# 1011                            Pale Rider                en
# 2999                             Abduction                en
#
# [2617 rows x 2 columns]

# %%
df.budget.mean()
# Out:
# 22531334.11

# %%
df.budget.sum()
# Out:
# 67594002330

# %%
df.budget.median()
# Out:
# 8000000.0

# %%
df.budget.variance
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [88], in <cell line: 1>()
# ----> 1 df.budget.variance
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'variance'

# %%
df.homepage[1:3]
# Out:
# 1                                  NaN
# 2    http://sonyclassics.com/whiplash/
# Name: homepage, dtype: object

# %%
df.homepage[1] = 'https://www.hbo.com/movies/hot-tub-time-machine'
# Out:
# C:\Users\Deepu\AppData\Local\Temp\ipykernel_10028\2250937011.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.homepage[1] = 'https://www.hbo.com/movies/hot-tub-time-machine'

# %%
df.homepage[1]
# Out:
# 'https://www.hbo.com/movies/hot-tub-time-machine'

# %%
df.set_index('imdb_id',drop = 'id')
# Out:
#              id                              belongs_to_collection    budget  \
# imdb_id
# tt2637294     1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# tt0368933     2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# tt2582802     3                                                NaN   3300000
# tt1821480     4                                                NaN   1200000
# tt1380152     5                                                NaN         0
# ...         ...                                                ...       ...
# tt0109403  2996                                                NaN         0
# tt2364975  2997                                                NaN         0
# tt0116908  2998                                                NaN  65000000
# tt0343135  2999                                                NaN  42000000
# tt1600195  3000                                                NaN  35000000
#
# ...

# %%
df.reset_index(drop = 'imdb_id')
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
df.runtime.min()
# Out:
# 0.0

# %%
df.runtime.max()
# Out:
# 338.0

# %%
df[df.runtime == 338]
# Out:
#         id belongs_to_collection    budget  \
# 1211  1212                   NaN  18000000
#
#                                                  genres homepage    imdb_id  \
# 1211  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...      NaN  tt1321865
#
#      original_language original_title  \
# 1211                en         Carlos
#
#                                                overview  popularity  ...  \
# 1211  The story of Venezuelan revolutionary, Ilich R...    4.558075  ...
#
#      release_date runtime                                   spoken_languages  \
# 1211      5/19/10   338.0  [{'iso_639_1': 'fr', 'name': 'Français'}, {'is...
#
#         status                         tagline   title  \
# 1211  Released  The man who hijacked the world  Carlos
#
#                                                Keywords  \
# 1211  [{'id': 1419, 'name': 'gun'}, {'id': 7336, 'na...
#
#                                                    cast  \
# ...

# %%
df[df['runtime'] == 0]['runtime'].count()
# Out:
# 12

# %%
def c_profit(a):
    try:
        y = ((a.revenue - a.budget)/a.revenue)*100
        return y
    
    except:
        y = np.nan
        return y

# %%
df.apply(c_profit,axis = 1)
# Out:
# 0       -13.685723
# 1        57.960864
# 2        74.793767
# 3        92.500000
# 4       100.000000
#            ...
# 2995    100.000000
# 2996    100.000000
# 2997     27.339198
# 2998     75.576196
# 2999     57.362391
# Length: 3000, dtype: float64

# %%
def g_profit(cp,sp):
    try:
        y = ((sp - cp)/cp)*100
        return round(y)
    except:
        y = np.nan
        return y

# %%
df.apply(lambda x: g_profit(x['budget'],x['revenue']),axis = 1)
# Out:
# 0        -12.0
# 1        138.0
# 2        297.0
# 3       1233.0
# 4          NaN
#          ...
# 2995       NaN
# 2996       NaN
# 2997      38.0
# 2998     309.0
# 2999     135.0
# Length: 3000, dtype: float64

# %%
df.apply(lambda x: ((x.budget - x.revenue)/x.budget)*100 if x.budget != 0 else np.nan, axis = 1)
# Out:
# 0         12.038207
# 1       -137.873588
# 2       -296.727273
# 3      -1233.333333
# 4               NaN
#            ...
# 2995            NaN
# 2996            NaN
# 2997     -37.625786
# 2998    -309.436633
# 2999    -134.534729
# Length: 3000, dtype: float64

# %%
from datetime import date

# %%
date(2023,4,23)
# Out:
# datetime.date(2023, 4, 23)

# %%
date.today()
# Out:
# datetime.date(2023, 4, 23)

# %%
date.today()
# Out:
# datetime.date(2023, 4, 23)

# %%
d = date.today()

# %%
d.year,d.day,d.month
# Out:
# (2023, 23, 4)

# %%
s = str(d)

# %%
s
# Out:
# '2023-04-23'

# %%
date.strftime(d,'%Y/%m/%d')
# Out:
# '2023/04/23'

# %%
date.strptime(s,'%Y-%m-%d')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [133], in <cell line: 1>()
# ----> 1 date.strptime(s,'%Y-%m-%d')
#
# AttributeError: type object 'datetime.date' has no attribute 'strptime'

# %%
from datetime import datetime
datetime.strptime(s,'%Y-%m-%d')
# Out:
# datetime.datetime(2023, 4, 23, 0, 0)

# %%
date(2023,4,23)
# Out:
# datetime.date(2023, 4, 23)

# %%
date.isoformat(d)
# Out:
# '2023-04-23'

# %%
date(2023,4,23)
# Out:
# datetime.date(2023, 4, 23)

# %%
d = date(2023,4,23)

# %%
d.year,d.month,d.day
# Out:
# (2023, 4, 23)

# %%
date.isoformat(d)
# Out:
# '2023-04-23'

# %%
datetime.strptime(s,'%Y-%m-%d')
# Out:
# datetime.datetime(2023, 4, 23, 0, 0)

# %%
the_meet = date(2022,11,30)

# %%
the_meet.year,the_meet.month,the_meet.day
# Out:
# (2022, 11, 30)

# %%
date.isoformat(the_meet)
# Out:
# '2022-11-30'

# %%
date.strftime(the_meet,'%Y-%m-%d')
# Out:
# '2022-11-30'

# %%
import time

# %%
a=time.localtime()

# %%
from datetime import time

# %%
print(time(4,1,0))
# Out:
# 04:01:00

# %%
t = time(4,20,0)
time.strftime(t,'%H:%M:%S')
# Out:
# '04:20:00'

# %%
t.hour
# Out:
# 4

# %%
t.minute,t.second
# Out:
# (20, 0)

# %%
time.strftime("%H:%M:%S",a)
# Out:
# '16:05:04'

# %%
a
# Out:
# time.struct_time(tm_year=2023, tm_mon=4, tm_mday=23, tm_hour=16, tm_min=5, tm_sec=4, tm_wday=6, tm_yday=113, tm_isdst=0)

# %%
current_time = time.localtime()

# %%
current_time
# Out:
# time.struct_time(tm_year=2023, tm_mon=4, tm_mday=23, tm_hour=16, tm_min=10, tm_sec=12, tm_wday=6, tm_yday=113, tm_isdst=0)

# %%
time.strftime('%H:%M:%S',current_time)
# Out:
# '16:10:12'

# %%
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2023, 4, 23, 16, 15, 33, 673164)

# %%
d = datetime(2023,4,23,15,22,5)

# %%
d
# Out:
# datetime.datetime(2023, 4, 23, 15, 22, 5)

# %%
d.date()
# Out:
# datetime.date(2023, 4, 23)

# %%
d.time()
# Out:
# datetime.time(15, 22, 5)

# %%
d.year
# Out:
# 2023

# %%
d.month,d.day,d.hour,d.minute,d.second
# Out:
# (4, 23, 15, 22, 5)

# %%
datetime.now().date()
# Out:
# datetime.date(2023, 4, 23)

# %%
x = datetime.now()

# %%
y=str(x)
y
# Out:
# '2023-04-23 16:17:11.897139'

# %%
datetime.strftime(x,'Date is %Y-%m-%d time is %H:%M:%S')
# Out:
# 'Date is 2023-04-23 time is 16:17:11'

# %%
datetime.strptime(y,'%Y-%m-%d %H:%M:%S.%f')
# Out:
# datetime.datetime(2023, 4, 23, 16, 17, 11, 897139)

# %%
datetime.now().date()
# Out:
# datetime.date(2023, 4, 23)

# %%
datetime.isoformat(x)
# Out:
# '2023-04-23T16:17:11.897139'

# %%
d1 = date(2023,12,1)
d2 = date(2023,12,2)
d1-d2
# Out:
# datetime.timedelta(days=-1)

# %%
from datetime import timedelta

# %%
d = d1 + timedelta(days = 2)

# %%
d
# Out:
# datetime.date(2023, 12, 3)

# %%
c = d1 + timedelta(hours = 1)

# %%
c
# Out:
# datetime.date(2023, 12, 1)

# %%
pd.to_datetime(df.release_date)
# Out:
# 0      2015-02-20
# 1      2004-08-06
# 2      2014-10-10
# 3      2012-03-09
# 4      2009-02-05
#           ...
# 2995   1994-04-22
# 2996   2013-03-28
# 2997   1996-10-11
# 2998   2004-01-16
# 2999   2011-09-22
# Name: release_date, Length: 3000, dtype: datetime64[ns]

# %%
df['month'] = df.release_date.apply(lambda x: pd.to_datetime(x).year)

# %%
df['month'].value_counts(ascending = False)
# Out:
# 2013    141
# 2015    128
# 2010    126
# 2012    125
# 2016    125
#        ...
# 2035      1
# 2038      1
# 2030      1
# 2026      1
# 2024      1
# Name: month, Length: 90, dtype: int64

# %%
df.original_language.unique()
# Out:
# array(['en', 'hi', 'ko', 'sr', 'fr', 'it', 'nl', 'zh', 'es', 'cs', 'ta',
#        'cn', 'ru', 'tr', 'ja', 'fa', 'sv', 'de', 'te', 'pt', 'mr', 'da',
#        'fi', 'el', 'ur', 'he', 'no', 'ar', 'nb', 'ro', 'vi', 'pl', 'hu',
#        'ml', 'bn', 'id'], dtype=object)

# %%
df.original_language.value_counts()
# Out:
# en    2575
# fr      78
# ru      47
# es      43
# hi      42
# ja      37
# it      24
# cn      20
# ko      20
# zh      19
# de      18
# ta      16
# sv       8
# nl       6
# pt       6
# fa       5
# da       5
# ro       4
# hu       3
# tr       3
# no       2
# ml       2
# pl       2
# te       2
# fi       2
# ur       1
# he       1
# el       1
# ar       1
# nb       1
# vi       1
# mr       1
# cs       1
# sr       1
# bn       1
# id       1
# Name: original_language, dtype: int64

# %%
df.original_language.nunique()
# Out:
# 36

# %%
df.homepage.isnull().sum()
# Out:
# 2053

# %%
~df.homepage.isnull().sum()
# Out:
# -2054

# %%
df.homepage.notnull().sum()
# Out:
# 947

# %%
df.dropna(axis = 0).shape
# Out:
# (204, 24)

# %%
df[df.homepage.isnull()]
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 4        5                                                NaN         0
# 5        6                                                NaN   8000000
# 7        8                                                NaN         0
# 8        9  [{'id': 256377, 'name': 'The Muppet Collection...         0
# ...    ...                                                ...       ...
# 2992  2993                                                NaN   1135654
# 2994  2995                                                NaN         0
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
#
#                                                  genres homepage    imdb_id  \
# ...

# %%
df[df.homepage.notnull()]
# Out:
#         id                              belongs_to_collection    budget  \
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 6        7                                                NaN  14000000
# 12      13                                                NaN  15000000
# ...    ...                                                ...       ...
# 2984  2985  [{'id': 221111, 'name': 'S.W.A.T. Collection',...  80000000
# 2985  2986                                                NaN  37665000
# 2993  2994                                                NaN  60000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
df[~df.homepage.isnull()]
# Out:
#         id                              belongs_to_collection    budget  \
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 6        7                                                NaN  14000000
# 12      13                                                NaN  15000000
# ...    ...                                                ...       ...
# 2984  2985  [{'id': 221111, 'name': 'S.W.A.T. Collection',...  80000000
# 2985  2986                                                NaN  37665000
# 2993  2994                                                NaN  60000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
(~df.homepage.isnull()).sum()
# Out:
# 947

# %%
df.original_title.isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# id                          0
# belongs_to_collection    2396
# budget                      0
# genres                      7
# homepage                 2053
# imdb_id                     0
# original_language           0
# original_title              0
# overview                    8
# popularity                  0
# poster_path                 1
# production_companies      156
# production_countries       55
# release_date                0
# runtime                     2
# spoken_languages           20
# status                      0
# tagline                   597
# title                       0
# Keywords                  276
# cast                       13
# crew                       16
# revenue                     0
# month                       0
# dtype: int64

# %%
df.cast.isnull().sum()
# Out:
# 13

# %%
(~df['cast'].isnull()).sum()
# Out:
# 2987

# %%
df.dropna(axis = 1)
# Out:
#         id    budget    imdb_id original_language  \
# 0        1  14000000  tt2637294                en
# 1        2  40000000  tt0368933                en
# 2        3   3300000  tt2582802                en
# 3        4   1200000  tt1821480                hi
# 4        5         0  tt1380152                ko
# ...    ...       ...        ...               ...
# 2995  2996         0  tt0109403                en
# 2996  2997         0  tt2364975                sv
# 2997  2998  65000000  tt0116908                en
# 2998  2999  42000000  tt0343135                en
# 2999  3000  35000000  tt1600195                en
#
#                                 original_title  popularity release_date  \
# 0                       Hot Tub Time Machine 2    6.575393      2/20/15
# 1     The Princess Diaries 2: Royal Engagement    8.248895       8/6/04
# 2                                     Whiplash   64.299990     10/10/14
# ...

# %%
df.dropna(axis = 0)
# Out:
#         id                              belongs_to_collection     budget  \
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...   40000000
# 22      23  [{'id': 207621, 'name': 'V/H/S Collection', 'p...          0
# 40      41  [{'id': 376970, 'name': 'Cocaine Cowboys', 'po...          0
# 46      47  [{'id': 8354, 'name': 'Ice Age Collection', 'p...   80000000
# 60      61  [{'id': 645, 'name': 'James Bond Collection', ...  150000000
# ...    ...                                                ...        ...
# 2904  2905  [{'id': 424202, 'name': 'Trainspotting Collect...    4000000
# 2927  2928  [{'id': 645, 'name': 'James Bond Collection', ...  140000000
# 2938  2939  [{'id': 135416, 'name': 'Prometheus Collection...  130000000
# 2968  2969  [{'id': 97307, 'name': 'BloodRayne Collection'...   25000000
# 2984  2985  [{'id': 221111, 'name': 'S.W.A.T. Collection',...   80000000
#
#                                                  genres  \
# ...

# %%
df[~df.belongs_to_collection.isnull()]
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 8        9  [{'id': 256377, 'name': 'The Muppet Collection...         0
# 10      11  [{'id': 1575, 'name': 'Rocky Collection', 'pos...   1000000
# 11      12  [{'id': 48190, 'name': 'Revenge of the Nerds C...         0
# ...    ...                                                ...       ...
# 2967  2968  [{'id': 387219, 'name': 'The Hustler Collectio...   2000000
# 2968  2969  [{'id': 97307, 'name': 'BloodRayne Collection'...  25000000
# 2974  2975  [{'id': 149704, 'name': 'Alone in the Dark Col...  20000000
# 2984  2985  [{'id': 221111, 'name': 'S.W.A.T. Collection',...  80000000
# 2991  2992  [{'id': 107469, 'name': 'Save The Last Dance C...  13000000
#
#                                                  genres  \
# ...

# %%
df[1:2] = np.nan

# %%
df[1:2]
# Out:
#    id belongs_to_collection  budget genres homepage imdb_id original_language  \
# 1 NaN                   NaN     NaN    NaN      NaN     NaN               NaN
#
#   original_title overview  popularity  ... runtime spoken_languages status  \
# 1            NaN      NaN         NaN  ...     NaN              NaN    NaN
#
#   tagline  title Keywords cast crew revenue month
# 1     NaN    NaN      NaN  NaN  NaN     NaN   NaN
#
# [1 rows x 24 columns]

# %%
df[1:2] = df.budget.mean()

# %%
df[1:2]
# Out:
#              id belongs_to_collection        budget          genres  \
# 1  2.252551e+07        22525509.27976  2.252551e+07  22525509.27976
#
#          homepage         imdb_id original_language  original_title  \
# 1  22525509.27976  22525509.27976    22525509.27976  22525509.27976
#
#          overview    popularity  ...       runtime spoken_languages  \
# 1  22525509.27976  2.252551e+07  ...  2.252551e+07   22525509.27976
#
#            status         tagline           title        Keywords  \
# 1  22525509.27976  22525509.27976  22525509.27976  22525509.27976
#
#              cast            crew       revenue         month
# 1  22525509.27976  22525509.27976  2.252551e+07  2.252551e+07
#
# [1 rows x 24 columns]

# %%
df[1:2] = np.nan

# %%
df[1:2].fillna('not present')
# Out:
#             id belongs_to_collection       budget       genres     homepage  \
# 1  not present           not present  not present  not present  not present
#
#        imdb_id original_language original_title     overview   popularity  \
# 1  not present       not present    not present  not present  not present
#
#    ...      runtime spoken_languages       status      tagline        title  \
# 1  ...  not present      not present  not present  not present  not present
#
#       Keywords         cast         crew      revenue        month
# 1  not present  not present  not present  not present  not present
#
# [1 rows x 24 columns]

# %%
df.homepage.fillna('not available')
# Out:
# 0                           not available
# 1                           not available
# 2       http://sonyclassics.com/whiplash/
# 3              http://kahaanithefilm.com/
# 4                           not available
#                       ...
# 2995                        not available
# 2996                        not available
# 2997                        not available
# 2998       http://www.alongcamepolly.com/
# 2999     http://www.abductionthefilm.com/
# Name: homepage, Length: 3000, dtype: object

# %%
df.sort_values('budget',ascending = True)
# Out:
#           id                              belongs_to_collection       budget  \
# 2678  2679.0                                                NaN          0.0
# 1178  1179.0                                                NaN          0.0
# 1175  1176.0                                                NaN          0.0
# 1174  1175.0                                                NaN          0.0
# 1173  1174.0                                                NaN          0.0
# ...      ...                                                ...          ...
# 1425  1426.0  [{'id': 8537, 'name': 'Superman Collection', '...  270000000.0
# 2770  2771.0  [{'id': 86311, 'name': 'The Avengers Collectio...  280000000.0
# 2209  2210.0  [{'id': 295, 'name': 'Pirates of the Caribbean...  300000000.0
# 2135  2136.0  [{'id': 295, 'name': 'Pirates of the Caribbean...  380000000.0
# 1        NaN                                                NaN          NaN
#
# ...

# %%
imdb = df.copy()

# %%
imdb.drop('id', axis = 1, inplace = True)

# %%
english_movies=imdb[imdb['original_language'] == 'en']

# %%
english_movies
# Out:
#                                   belongs_to_collection    budget  \
# 0     [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1     [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2                                                   NaN   3300000
# 5                                                   NaN   8000000
# 6                                                   NaN  14000000
# ...                                                 ...       ...
# 2994                                                NaN         0
# 2995                                                NaN         0
# 2997                                                NaN  65000000
# 2998                                                NaN  42000000
# 2999                                                NaN  35000000
#
#                                                  genres  \
# 0                        [{'id': 35, 'name': 'Comedy'}]
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# ...
